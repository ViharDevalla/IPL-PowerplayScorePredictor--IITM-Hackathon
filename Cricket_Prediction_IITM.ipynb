# %% [markdown]
# # Imports

# %%
# !pip install scikit-learn==0.24.1
# Out:
# Collecting scikit-learn==0.24.1
#   Downloading https://files.pythonhosted.org/packages/f3/74/eb899f41d55f957e2591cde5528e75871f817d9fb46d4732423ecaca736d/scikit_learn-0.24.1-cp37-cp37m-manylinux2010_x86_64.whl (22.3MB)
#      |████████████████████████████████| 22.3MB 10.4MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.1) (1.0.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.1) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.1) (1.4.1)
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-0.24.1 threadpoolctl-2.1.0

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
import os
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import keras
from keras import layers
from keras import layers
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Flatten
from keras.optimizers import Adam
from keras.layers import Bidirectional
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# !gdown --id "1TBxr27T0vdOagjDLvKlio-MDiWDpqHCb"   #ipl_csv2.zip
# !gdown --id "1AN4kUrHQN72iDQFSwEwI6i7gbGJQ3LTr"   #submissionFormat.zip   
# !gdown --id "1TCqabv-mePLDkj2qKIxQecCuB_ZwO4Gk"   #input_test_data.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TBxr27T0vdOagjDLvKlio-MDiWDpqHCb
# To: /content/ipl_csv2.zip
# 3.24MB [00:00, 98.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1AN4kUrHQN72iDQFSwEwI6i7gbGJQ3LTr
# To: /content/submissionFormat.zip
# 100% 1.00k/1.00k [00:00<00:00, 1.80MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TCqabv-mePLDkj2qKIxQecCuB_ZwO4Gk
# To: /content/input_test_data.csv
# 100% 193/193 [00:00<00:00, 320kB/s]

# %%
# !unzip /content/ipl_csv2.zip -d dataset
# !unzip /content/submissionFormat.zip -d submission
# Out:
# Archive:  /content/ipl_csv2.zip
#   inflating: dataset/README.txt
#   inflating: dataset/all_matches.csv
#   inflating: dataset/335982.csv
#   inflating: dataset/335983.csv
#   inflating: dataset/335984.csv
#   inflating: dataset/335986.csv
#   inflating: dataset/335985.csv
#   inflating: dataset/335987.csv
#   inflating: dataset/335988.csv
#   inflating: dataset/335989.csv
#   inflating: dataset/335990.csv
#   inflating: dataset/335991.csv
#   inflating: dataset/335993.csv
#   inflating: dataset/335992.csv
#   inflating: dataset/335994.csv
#   inflating: dataset/335995.csv
#   inflating: dataset/335996.csv
#   inflating: dataset/335997.csv
#   inflating: dataset/335998.csv
#   inflating: dataset/336000.csv
#   inflating: dataset/335999.csv
#   inflating: dataset/336001.csv
#   inflating: dataset/336003.csv
#   inflating: dataset/336034.csv
#   inflating: dataset/336005.csv
#   inflating: dataset/336004.csv
#   inflating: dataset/336006.csv
#   inflating: dataset/336007.csv
#   inflating: dataset/336008.csv
#   inflating: dataset/336009.csv
#   inflating: dataset/336010.csv
#   inflating: dataset/336011.csv
#   inflating: dataset/336013.csv
#   inflating: dataset/336014.csv
#   inflating: dataset/336015.csv
#   inflating: dataset/336016.csv
#   inflating: dataset/336017.csv
#   inflating: dataset/336018.csv
#   inflating: dataset/336020.csv
#   inflating: dataset/336021.csv
#   inflating: dataset/336023.csv
#   inflating: dataset/336022.csv
#   inflating: dataset/336024.csv
#   inflating: dataset/336025.csv
#   inflating: dataset/336026.csv
#   inflating: dataset/336027.csv
#   inflating: dataset/336028.csv
#   inflating: dataset/336029.csv
#   inflating: dataset/336031.csv
#   inflating: dataset/336032.csv
#   inflating: dataset/336033.csv
#   inflating: dataset/336002.csv
#   inflating: dataset/336035.csv
#   inflating: dataset/336036.csv
#   inflating: dataset/336037.csv
#   inflating: dataset/336012.csv
#   inflating: dataset/336019.csv
#   inflating: dataset/336038.csv
#   inflating: dataset/336039.csv
#   inflating: dataset/336040.csv
#   inflating: dataset/392182.csv
#   inflating: dataset/392181.csv
#   inflating: dataset/392183.csv
#   inflating: dataset/392184.csv
#   inflating: dataset/392185.csv
#   inflating: dataset/392186.csv
#   inflating: dataset/392188.csv
#   inflating: dataset/392189.csv
#   inflating: dataset/392190.csv
#   inflating: dataset/392191.csv
#   inflating: dataset/392192.csv
#   inflating: dataset/392194.csv
#   inflating: dataset/392195.csv
#   inflating: dataset/392196.csv
#   inflating: dataset/392197.csv
#   inflating: dataset/392198.csv
#   inflating: dataset/392199.csv
#   inflating: dataset/392200.csv
#   inflating: dataset/392202.csv
#   inflating: dataset/392201.csv
#   inflating: dataset/392203.csv
#   inflating: dataset/392204.csv
#   inflating: dataset/392206.csv
#   inflating: dataset/392205.csv
#   inflating: dataset/392207.csv
#   inflating: dataset/392208.csv
#   inflating: dataset/392209.csv
#   inflating: dataset/392210.csv
#   inflating: dataset/392211.csv
#   inflating: dataset/392212.csv
#   inflating: dataset/392213.csv
#   inflating: dataset/392214.csv
#   inflating: dataset/392215.csv
#   inflating: dataset/392217.csv
#   inflating: dataset/392216.csv
#   inflating: dataset/392219.csv
#   inflating: dataset/392218.csv
#   inflating: dataset/392220.csv
#   inflating: dataset/392222.csv
#   inflating: dataset/392221.csv
#   inflating: dataset/392223.csv
#   inflating: dataset/392225.csv
#   inflating: dataset/392224.csv
#   inflating: dataset/392226.csv
#   inflating: dataset/392227.csv
#   inflating: dataset/392228.csv
#   inflating: dataset/392230.csv
#   inflating: dataset/392229.csv
#   inflating: dataset/392231.csv
#   inflating: dataset/392232.csv
#   inflating: dataset/392233.csv
#   inflating: dataset/392234.csv
#   inflating: dataset/392236.csv
#   inflating: dataset/392235.csv
#   inflating: dataset/392237.csv
#   inflating: dataset/392238.csv
#   inflating: dataset/392239.csv
#   inflating: dataset/419106.csv
#   inflating: dataset/419108.csv
#   inflating: dataset/419107.csv
#   inflating: dataset/419110.csv
#   inflating: dataset/419109.csv
#   inflating: dataset/419111.csv
#   inflating: dataset/419112.csv
#   inflating: dataset/419113.csv
#   inflating: dataset/419114.csv
#   inflating: dataset/419115.csv
#   inflating: dataset/419116.csv
#   inflating: dataset/419117.csv
#   inflating: dataset/419118.csv
#   inflating: dataset/419119.csv
#   inflating: dataset/419120.csv
#   inflating: dataset/419121.csv
#   inflating: dataset/419122.csv
#   inflating: dataset/419123.csv
#   inflating: dataset/419124.csv
#   inflating: dataset/419125.csv
#   inflating: dataset/419128.csv
#   inflating: dataset/419126.csv
#   inflating: dataset/419127.csv
#   inflating: dataset/419129.csv
#   inflating: dataset/419130.csv
#   inflating: dataset/419131.csv
#   inflating: dataset/419132.csv
#   inflating: dataset/419133.csv
#   inflating: dataset/419134.csv
#   inflating: dataset/419135.csv
#   inflating: dataset/419136.csv
#   inflating: dataset/419138.csv
#   inflating: dataset/419137.csv
#   inflating: dataset/419139.csv
#   inflating: dataset/419140.csv
#   inflating: dataset/419141.csv
#   inflating: dataset/419142.csv
#   inflating: dataset/419143.csv
#   inflating: dataset/419144.csv
#   inflating: dataset/419145.csv
#   inflating: dataset/419146.csv
#   inflating: dataset/419148.csv
#   inflating: dataset/419147.csv
#   inflating: dataset/419150.csv
#   inflating: dataset/419149.csv
#   inflating: dataset/419151.csv
#   inflating: dataset/419153.csv
#   inflating: dataset/419152.csv
#   inflating: dataset/419154.csv
#   inflating: dataset/419155.csv
#   inflating: dataset/419156.csv
#   inflating: dataset/419158.csv
#   inflating: dataset/419157.csv
#   inflating: dataset/419159.csv
#   inflating: dataset/419160.csv
#   inflating: dataset/419161.csv
#   inflating: dataset/419162.csv
#   inflating: dataset/419163.csv
#   inflating: dataset/419164.csv
#   inflating: dataset/419165.csv
#   inflating: dataset/501198.csv
#   inflating: dataset/501199.csv
#   inflating: dataset/501200.csv
#   inflating: dataset/501202.csv
#   inflating: dataset/501201.csv
#   inflating: dataset/501203.csv
#   inflating: dataset/501204.csv
#   inflating: dataset/501205.csv
#   inflating: dataset/501207.csv
#   inflating: dataset/501206.csv
#   inflating: dataset/501208.csv
#   inflating: dataset/501209.csv
#   inflating: dataset/501210.csv
#   inflating: dataset/501211.csv
#   inflating: dataset/501212.csv
#   inflating: dataset/501213.csv
#   inflating: dataset/501214.csv
#   inflating: dataset/501215.csv
#   inflating: dataset/501216.csv
#   inflating: dataset/501218.csv
#   inflating: dataset/501219.csv
#   inflating: dataset/501220.csv
#   inflating: dataset/501222.csv
#   inflating: dataset/501221.csv
#   inflating: dataset/501223.csv
#   inflating: dataset/501225.csv
#   inflating: dataset/501224.csv
#   inflating: dataset/501226.csv
#   inflating: dataset/501227.csv
#   inflating: dataset/501228.csv
#   inflating: dataset/501229.csv
#   inflating: dataset/501230.csv
#   inflating: dataset/501232.csv
#   inflating: dataset/501231.csv
#   inflating: dataset/501233.csv
#   inflating: dataset/501234.csv
#   inflating: dataset/501236.csv
#   inflating: dataset/501235.csv
#   inflating: dataset/501237.csv
#   inflating: dataset/501238.csv
#   inflating: dataset/501239.csv
#   inflating: dataset/501240.csv
#   inflating: dataset/501241.csv
#   inflating: dataset/501242.csv
#   inflating: dataset/501243.csv
#   inflating: dataset/501244.csv
#   inflating: dataset/501245.csv
#   inflating: dataset/501246.csv
#   inflating: dataset/501248.csv
#   inflating: dataset/501247.csv
#   inflating: dataset/501249.csv
#   inflating: dataset/501251.csv
#   inflating: dataset/501250.csv
#   inflating: dataset/501252.csv
#   inflating: dataset/501253.csv
#   inflating: dataset/501254.csv
#   inflating: dataset/501256.csv
#   inflating: dataset/501255.csv
#   inflating: dataset/501257.csv
#   inflating: dataset/501258.csv
#   inflating: dataset/501259.csv
#   inflating: dataset/501260.csv
#   inflating: dataset/501261.csv
#   inflating: dataset/501262.csv
#   inflating: dataset/501263.csv
#   inflating: dataset/501264.csv
#   inflating: dataset/501265.csv
#   inflating: dataset/501266.csv
#   inflating: dataset/501267.csv
#   inflating: dataset/501268.csv
#   inflating: dataset/501269.csv
#   inflating: dataset/501270.csv
#   inflating: dataset/501271.csv
#   inflating: dataset/548306.csv
#   inflating: dataset/548307.csv
#   inflating: dataset/548308.csv
#   inflating: dataset/548309.csv
#   inflating: dataset/548311.csv
#   inflating: dataset/548310.csv
#   inflating: dataset/548313.csv
#   inflating: dataset/548312.csv
#   inflating: dataset/548314.csv
#   inflating: dataset/548315.csv
#   inflating: dataset/548316.csv
#   inflating: dataset/548317.csv
#   inflating: dataset/548318.csv
#   inflating: dataset/548319.csv
#   inflating: dataset/548320.csv
#   inflating: dataset/548322.csv
#   inflating: dataset/548323.csv
#   inflating: dataset/548324.csv
#   inflating: dataset/548325.csv
#   inflating: dataset/548326.csv
#   inflating: dataset/548327.csv
#   inflating: dataset/548328.csv
#   inflating: dataset/548330.csv
#   inflating: dataset/548321.csv
#   inflating: dataset/548331.csv
#   inflating: dataset/548333.csv
#   inflating: dataset/548332.csv
#   inflating: dataset/548335.csv
#   inflating: dataset/548334.csv
#   inflating: dataset/548336.csv
#   inflating: dataset/548337.csv
#   inflating: dataset/548339.csv
#   inflating: dataset/548341.csv
#   inflating: dataset/548342.csv
#   inflating: dataset/548344.csv
#   inflating: dataset/548343.csv
#   inflating: dataset/548345.csv
#   inflating: dataset/548346.csv
#   inflating: dataset/548347.csv
#   inflating: dataset/548349.csv
#   inflating: dataset/548348.csv
#   inflating: dataset/548350.csv
#   inflating: dataset/548351.csv
#   inflating: dataset/548352.csv
#   inflating: dataset/548354.csv
#   inflating: dataset/548353.csv
#   inflating: dataset/548355.csv
#   inflating: dataset/548356.csv
#   inflating: dataset/548357.csv
#   inflating: dataset/548359.csv
#   inflating: dataset/548358.csv
#   inflating: dataset/548360.csv
#   inflating: dataset/548329.csv
#   inflating: dataset/548361.csv
#   inflating: dataset/548362.csv
#   inflating: dataset/548364.csv
#   inflating: dataset/548363.csv
#   inflating: dataset/548366.csv
#   inflating: dataset/548365.csv
#   inflating: dataset/548367.csv
#   inflating: dataset/548368.csv
#   inflating: dataset/548369.csv
#   inflating: dataset/548370.csv
#   inflating: dataset/548372.csv
#   inflating: dataset/548371.csv
#   inflating: dataset/548373.csv
#   inflating: dataset/548374.csv
#   inflating: dataset/548375.csv
#   inflating: dataset/548376.csv
#   inflating: dataset/548377.csv
#   inflating: dataset/548378.csv
#   inflating: dataset/548379.csv
#   inflating: dataset/548380.csv
#   inflating: dataset/548381.csv
#   inflating: dataset/597998.csv
#   inflating: dataset/597999.csv
#   inflating: dataset/598000.csv
#   inflating: dataset/598001.csv
#   inflating: dataset/598002.csv
#   inflating: dataset/598004.csv
#   inflating: dataset/598003.csv
#   inflating: dataset/598005.csv
#   inflating: dataset/598048.csv
#   inflating: dataset/598006.csv
#   inflating: dataset/598007.csv
#   inflating: dataset/598008.csv
#   inflating: dataset/598009.csv
#   inflating: dataset/598010.csv
#   inflating: dataset/598011.csv
#   inflating: dataset/598012.csv
#   inflating: dataset/598014.csv
#   inflating: dataset/598013.csv
#   inflating: dataset/598015.csv
#   inflating: dataset/598016.csv
#   inflating: dataset/598017.csv
#   inflating: dataset/598018.csv
#   inflating: dataset/598019.csv
#   inflating: dataset/598020.csv
#   inflating: dataset/598021.csv
#   inflating: dataset/598023.csv
#   inflating: dataset/598022.csv
#   inflating: dataset/598024.csv
#   inflating: dataset/598025.csv
#   inflating: dataset/598026.csv
#   inflating: dataset/598059.csv
#   inflating: dataset/598027.csv
#   inflating: dataset/598029.csv
#   inflating: dataset/598030.csv
#   inflating: dataset/598031.csv
#   inflating: dataset/598032.csv
#   inflating: dataset/598033.csv
#   inflating: dataset/598035.csv
#   inflating: dataset/598034.csv
#   inflating: dataset/598037.csv
#   inflating: dataset/598036.csv
#   inflating: dataset/598038.csv
#   inflating: dataset/598040.csv
#   inflating: dataset/598039.csv
#   inflating: dataset/598041.csv
#   inflating: dataset/598042.csv
#   inflating: dataset/598043.csv
#   inflating: dataset/598044.csv
#   inflating: dataset/598046.csv
#   inflating: dataset/598047.csv
#   inflating: dataset/598064.csv
#   inflating: dataset/598049.csv
#   inflating: dataset/598050.csv
#   inflating: dataset/598051.csv
#   inflating: dataset/598052.csv
#   inflating: dataset/598053.csv
#   inflating: dataset/598054.csv
#   inflating: dataset/598055.csv
#   inflating: dataset/598056.csv
#   inflating: dataset/598058.csv
#   inflating: dataset/598057.csv
#   inflating: dataset/598060.csv
#   inflating: dataset/598045.csv
#   inflating: dataset/598062.csv
#   inflating: dataset/598063.csv
#   inflating: dataset/598061.csv
#   inflating: dataset/598028.csv
#   inflating: dataset/598065.csv
#   inflating: dataset/598068.csv
#   inflating: dataset/598066.csv
#   inflating: dataset/598067.csv
#   inflating: dataset/598069.csv
#   inflating: dataset/598070.csv
#   inflating: dataset/598071.csv
#   inflating: dataset/598072.csv
#   inflating: dataset/598073.csv
#   inflating: dataset/729279.csv
#   inflating: dataset/729281.csv
#   inflating: dataset/729283.csv
#   inflating: dataset/729285.csv
#   inflating: dataset/729289.csv
#   inflating: dataset/729287.csv
#   inflating: dataset/729291.csv
#   inflating: dataset/729293.csv
#   inflating: dataset/729295.csv
#   inflating: dataset/729297.csv
#   inflating: dataset/729299.csv
#   inflating: dataset/729303.csv
#   inflating: dataset/729301.csv
#   inflating: dataset/729307.csv
#   inflating: dataset/729305.csv
#   inflating: dataset/729309.csv
#   inflating: dataset/729311.csv
#   inflating: dataset/729313.csv
#   inflating: dataset/729315.csv
#   inflating: dataset/729317.csv
#   inflating: dataset/733971.csv
#   inflating: dataset/733973.csv
#   inflating: dataset/733975.csv
#   inflating: dataset/733977.csv
#   inflating: dataset/733981.csv
#   inflating: dataset/733979.csv
#   inflating: dataset/733983.csv
#   inflating: dataset/733985.csv
#   inflating: dataset/733987.csv
#   inflating: dataset/733989.csv
#   inflating: dataset/733991.csv
#   inflating: dataset/733995.csv
#   inflating: dataset/733993.csv
#   inflating: dataset/733999.csv
#   inflating: dataset/733997.csv
#   inflating: dataset/734001.csv
#   inflating: dataset/734003.csv
#   inflating: dataset/734005.csv
#   inflating: dataset/734009.csv
#   inflating: dataset/734007.csv
#   inflating: dataset/734011.csv
#   inflating: dataset/734015.csv
#   inflating: dataset/734013.csv
#   inflating: dataset/734019.csv
#   inflating: dataset/734017.csv
#   inflating: dataset/734021.csv
#   inflating: dataset/734023.csv
#   inflating: dataset/734025.csv
#   inflating: dataset/734029.csv
#   inflating: dataset/734027.csv
#   inflating: dataset/734031.csv
#   inflating: dataset/734033.csv
#   inflating: dataset/734035.csv
#   inflating: dataset/734037.csv
#   inflating: dataset/734041.csv
#   inflating: dataset/734039.csv
#   inflating: dataset/734043.csv
#   inflating: dataset/734045.csv
#   inflating: dataset/734047.csv
#   inflating: dataset/734049.csv
#   inflating: dataset/829733.csv
#   inflating: dataset/829735.csv
#   inflating: dataset/829737.csv
#   inflating: dataset/829739.csv
#   inflating: dataset/829741.csv
#   inflating: dataset/829743.csv
#   inflating: dataset/829745.csv
#   inflating: dataset/829747.csv
#   inflating: dataset/829749.csv
#   inflating: dataset/829705.csv
#   inflating: dataset/829707.csv
#   inflating: dataset/829709.csv
#   inflating: dataset/829713.csv
#   inflating: dataset/829711.csv
#   inflating: dataset/829715.csv
#   inflating: dataset/829717.csv
#   inflating: dataset/829719.csv
#   inflating: dataset/829721.csv
#   inflating: dataset/829725.csv
#   inflating: dataset/829727.csv
#   inflating: dataset/829729.csv
#   inflating: dataset/829731.csv
#   inflating: dataset/829751.csv
#   inflating: dataset/829753.csv
#   inflating: dataset/829757.csv
#   inflating: dataset/829759.csv
#   inflating: dataset/829765.csv
#   inflating: dataset/829723.csv
#   inflating: dataset/829763.csv
#   inflating: dataset/829767.csv
#   inflating: dataset/829769.csv
#   inflating: dataset/829771.csv
#   inflating: dataset/829773.csv
#   inflating: dataset/829775.csv
#   inflating: dataset/829777.csv
#   inflating: dataset/829779.csv
#   inflating: dataset/829781.csv
#   inflating: dataset/829783.csv
#   inflating: dataset/829785.csv
#   inflating: dataset/829787.csv
#   inflating: dataset/829761.csv
#   inflating: dataset/829789.csv
#   inflating: dataset/829791.csv
#   inflating: dataset/829793.csv
#   inflating: dataset/829795.csv
#   inflating: dataset/829797.csv
#   inflating: dataset/829799.csv
#   inflating: dataset/829801.csv
#   inflating: dataset/829803.csv
#   inflating: dataset/829805.csv
#   inflating: dataset/829807.csv
#   inflating: dataset/829809.csv
#   inflating: dataset/829811.csv
#   inflating: dataset/829813.csv
#   inflating: dataset/829815.csv
#   inflating: dataset/829817.csv
#   inflating: dataset/829819.csv
#   inflating: dataset/829821.csv
#   inflating: dataset/829823.csv
#   inflating: dataset/980901.csv
#   inflating: dataset/980903.csv
#   inflating: dataset/980905.csv
#   inflating: dataset/980907.csv
#   inflating: dataset/980909.csv
#   inflating: dataset/980911.csv
#   inflating: dataset/980913.csv
#   inflating: dataset/980915.csv
#   inflating: dataset/980917.csv
#   inflating: dataset/980919.csv
#   inflating: dataset/980921.csv
#   inflating: dataset/980923.csv
#   inflating: dataset/980925.csv
#   inflating: dataset/980927.csv
#   inflating: dataset/980929.csv
#   inflating: dataset/980931.csv
#   inflating: dataset/980933.csv
#   inflating: dataset/980935.csv
#   inflating: dataset/980937.csv
#   inflating: dataset/980939.csv
#   inflating: dataset/980941.csv
#   inflating: dataset/980943.csv
#   inflating: dataset/980945.csv
#   inflating: dataset/980947.csv
#   inflating: dataset/980949.csv
#   inflating: dataset/980951.csv
#   inflating: dataset/980953.csv
#   inflating: dataset/980955.csv
#   inflating: dataset/980957.csv
#   inflating: dataset/980959.csv
#   inflating: dataset/980961.csv
#   inflating: dataset/980963.csv
#   inflating: dataset/980965.csv
#   inflating: dataset/980967.csv
#   inflating: dataset/980969.csv
#   inflating: dataset/980971.csv
#   inflating: dataset/980973.csv
#   inflating: dataset/980975.csv
#   inflating: dataset/980977.csv
#   inflating: dataset/980979.csv
#   inflating: dataset/980981.csv
#   inflating: dataset/980983.csv
#   inflating: dataset/980985.csv
#   inflating: dataset/980987.csv
#   inflating: dataset/980989.csv
#   inflating: dataset/980991.csv
#   inflating: dataset/980993.csv
#   inflating: dataset/980995.csv
#   inflating: dataset/980997.csv
#   inflating: dataset/980999.csv
#   inflating: dataset/981001.csv
#   inflating: dataset/981003.csv
#   inflating: dataset/981005.csv
#   inflating: dataset/981007.csv
#   inflating: dataset/981009.csv
#   inflating: dataset/981011.csv
#   inflating: dataset/981013.csv
#   inflating: dataset/981015.csv
#   inflating: dataset/981017.csv
#   inflating: dataset/981019.csv
#   inflating: dataset/1082591.csv
#   inflating: dataset/1082592.csv
#   inflating: dataset/1082593.csv
#   inflating: dataset/1082595.csv
#   inflating: dataset/1082594.csv
#   inflating: dataset/1082596.csv
#   inflating: dataset/1082597.csv
#   inflating: dataset/1082598.csv
#   inflating: dataset/1082599.csv
#   inflating: dataset/1082600.csv
#   inflating: dataset/1082601.csv
#   inflating: dataset/1082602.csv
#   inflating: dataset/1082603.csv
#   inflating: dataset/1082604.csv
#   inflating: dataset/1082605.csv
#   inflating: dataset/1082606.csv
#   inflating: dataset/1082607.csv
#   inflating: dataset/1082608.csv
#   inflating: dataset/1082609.csv
#   inflating: dataset/1082610.csv
#   inflating: dataset/1082611.csv
#   inflating: dataset/1082612.csv
#   inflating: dataset/1082613.csv
#   inflating: dataset/1082614.csv
#   inflating: dataset/1082615.csv
#   inflating: dataset/1082616.csv
#   inflating: dataset/1082617.csv
#   inflating: dataset/1082618.csv
#   inflating: dataset/1082620.csv
#   inflating: dataset/1082621.csv
#   inflating: dataset/1082622.csv
#   inflating: dataset/1082623.csv
#   inflating: dataset/1082624.csv
#   inflating: dataset/1082625.csv
#   inflating: dataset/1082626.csv
#   inflating: dataset/1082627.csv
#   inflating: dataset/1082628.csv
#   inflating: dataset/1082629.csv
#   inflating: dataset/1082630.csv
#   inflating: dataset/1082631.csv
#   inflating: dataset/1082632.csv
#   inflating: dataset/1082633.csv
#   inflating: dataset/1082634.csv
#   inflating: dataset/1082635.csv
#   inflating: dataset/1082636.csv
#   inflating: dataset/1082637.csv
#   inflating: dataset/1082638.csv
#   inflating: dataset/1082639.csv
#   inflating: dataset/1082640.csv
#   inflating: dataset/1082641.csv
#   inflating: dataset/1082642.csv
#   inflating: dataset/1082643.csv
#   inflating: dataset/1082644.csv
#   inflating: dataset/1082645.csv
#   inflating: dataset/1082646.csv
#   inflating: dataset/1082647.csv
#   inflating: dataset/1082648.csv
#   inflating: dataset/1082649.csv
#   inflating: dataset/1082650.csv
#   inflating: dataset/1175356.csv
#   inflating: dataset/1175357.csv
#   inflating: dataset/1175358.csv
#   inflating: dataset/1175359.csv
#   inflating: dataset/1175360.csv
#   inflating: dataset/1175361.csv
#   inflating: dataset/1175362.csv
#   inflating: dataset/1175363.csv
#   inflating: dataset/1175364.csv
#   inflating: dataset/1175365.csv
#   inflating: dataset/1175366.csv
#   inflating: dataset/1175367.csv
#   inflating: dataset/1175368.csv
#   inflating: dataset/1175369.csv
#   inflating: dataset/1175370.csv
#   inflating: dataset/1175371.csv
#   inflating: dataset/1175372.csv
#   inflating: dataset/1178393.csv
#   inflating: dataset/1178394.csv
#   inflating: dataset/1178395.csv
#   inflating: dataset/1178396.csv
#   inflating: dataset/1178397.csv
#   inflating: dataset/1178398.csv
#   inflating: dataset/1178399.csv
#   inflating: dataset/1178400.csv
#   inflating: dataset/1178401.csv
#   inflating: dataset/1178402.csv
#   inflating: dataset/1178403.csv
#   inflating: dataset/1178404.csv
#   inflating: dataset/1178405.csv
#   inflating: dataset/1178406.csv
#   inflating: dataset/1178407.csv
#   inflating: dataset/1178408.csv
#   inflating: dataset/1136561.csv
#   inflating: dataset/1136562.csv
#   inflating: dataset/1136563.csv
#   inflating: dataset/1136564.csv
#   inflating: dataset/1136565.csv
#   inflating: dataset/1136566.csv
#   inflating: dataset/1136567.csv
#   inflating: dataset/1136568.csv
#   inflating: dataset/1136569.csv
#   inflating: dataset/1136570.csv
#   inflating: dataset/1136571.csv
#   inflating: dataset/1136572.csv
#   inflating: dataset/1136573.csv
#   inflating: dataset/1136574.csv
#   inflating: dataset/1136575.csv
#   inflating: dataset/1136576.csv
#   inflating: dataset/1136577.csv
#   inflating: dataset/1136578.csv
#   inflating: dataset/1136579.csv
#   inflating: dataset/1136580.csv
#   inflating: dataset/1136581.csv
#   inflating: dataset/1136582.csv
#   inflating: dataset/1136583.csv
#   inflating: dataset/1136584.csv
#   inflating: dataset/1136585.csv
#   inflating: dataset/1136586.csv
#   inflating: dataset/1136587.csv
#   inflating: dataset/1136588.csv
#   inflating: dataset/1136589.csv
#   inflating: dataset/1136590.csv
#   inflating: dataset/1136591.csv
#   inflating: dataset/1136592.csv
#   inflating: dataset/1136593.csv
#   inflating: dataset/1136594.csv
#   inflating: dataset/1136595.csv
#   inflating: dataset/1136596.csv
#   inflating: dataset/1136597.csv
#   inflating: dataset/1136598.csv
#   inflating: dataset/1136599.csv
#   inflating: dataset/1136600.csv
#   inflating: dataset/1136601.csv
#   inflating: dataset/1136602.csv
#   inflating: dataset/1136603.csv
#   inflating: dataset/1136604.csv
#   inflating: dataset/1136605.csv
#   inflating: dataset/1136606.csv
#   inflating: dataset/1136607.csv
#   inflating: dataset/1136608.csv
#   inflating: dataset/1136609.csv
#   inflating: dataset/1136610.csv
#   inflating: dataset/1136611.csv
#   inflating: dataset/1136612.csv
#   inflating: dataset/1136613.csv
#   inflating: dataset/1136614.csv
#   inflating: dataset/1136615.csv
#   inflating: dataset/1136616.csv
#   inflating: dataset/1136617.csv
#   inflating: dataset/1136618.csv
#   inflating: dataset/1136619.csv
#   inflating: dataset/1136620.csv
#   inflating: dataset/1178409.csv
#   inflating: dataset/1178410.csv
#   inflating: dataset/1178411.csv
#   inflating: dataset/1178412.csv
#   inflating: dataset/1178413.csv
#   inflating: dataset/1178414.csv
#   inflating: dataset/1178415.csv
#   inflating: dataset/1178416.csv
#   inflating: dataset/1178417.csv
#   inflating: dataset/1178418.csv
#   inflating: dataset/1178419.csv
#   inflating: dataset/1178420.csv
#   inflating: dataset/1178421.csv
#   inflating: dataset/1178422.csv
#   inflating: dataset/1178423.csv
#   inflating: dataset/1178424.csv
#   inflating: dataset/1178425.csv
#   inflating: dataset/1178426.csv
#   inflating: dataset/1178427.csv
#   inflating: dataset/1178428.csv
#   inflating: dataset/1178429.csv
#   inflating: dataset/1178430.csv
#   inflating: dataset/1178431.csv
#   inflating: dataset/1181764.csv
#   inflating: dataset/1181766.csv
#   inflating: dataset/1181767.csv
#   inflating: dataset/1181768.csv
#   inflating: dataset/1216492.csv
#   inflating: dataset/1216493.csv
#   inflating: dataset/1216534.csv
#   inflating: dataset/1216496.csv
#   inflating: dataset/1216508.csv
#   inflating: dataset/1216539.csv
#   inflating: dataset/1216510.csv
#   inflating: dataset/1216545.csv
#   inflating: dataset/1216527.csv
#   inflating: dataset/1216504.csv
#   inflating: dataset/1216532.csv
#   inflating: dataset/1216547.csv
#   inflating: dataset/1216503.csv
#   inflating: dataset/1216516.csv
#   inflating: dataset/1216514.csv
#   inflating: dataset/1216515.csv
#   inflating: dataset/1216513.csv
#   inflating: dataset/1216538.csv
#   inflating: dataset/1216519.csv
#   inflating: dataset/1216511.csv
#   inflating: dataset/1216501.csv
#   inflating: dataset/1216542.csv
#   inflating: dataset/1216500.csv
#   inflating: dataset/1216523.csv
#   inflating: dataset/1216525.csv
#   inflating: dataset/1216507.csv
#   inflating: dataset/1216529.csv
#   inflating: dataset/1216540.csv
#   inflating: dataset/1216528.csv
#   inflating: dataset/1216543.csv
#   inflating: dataset/1216531.csv
#   inflating: dataset/1216526.csv
#   inflating: dataset/1216509.csv
#   inflating: dataset/1216522.csv
#   inflating: dataset/1216512.csv
#   inflating: dataset/1216517.csv
#   inflating: dataset/1216533.csv
#   inflating: dataset/1216546.csv
#   inflating: dataset/1216494.csv
#   inflating: dataset/1216518.csv
#   inflating: dataset/1216521.csv
#   inflating: dataset/1216497.csv
#   inflating: dataset/1216498.csv
#   inflating: dataset/1216541.csv
#   inflating: dataset/1216544.csv
#   inflating: dataset/1216520.csv
#   inflating: dataset/1216524.csv
#   inflating: dataset/1216499.csv
#   inflating: dataset/1216536.csv
#   inflating: dataset/1216537.csv
#   inflating: dataset/1216502.csv
#   inflating: dataset/1216505.csv
#   inflating: dataset/1216506.csv
#   inflating: dataset/1216530.csv
#   inflating: dataset/1216535.csv
#   inflating: dataset/1216495.csv
#   inflating: dataset/1237177.csv
#   inflating: dataset/1237178.csv
#   inflating: dataset/1237180.csv
#   inflating: dataset/1237181.csv
#   inflating: dataset/1254058.csv
#   inflating: dataset/1254059.csv
#   inflating: dataset/1254060.csv
# Archive:  /content/submissionFormat.zip
#   inflating: submission/inputFile.csv
#   inflating: submission/main.py
#   inflating: submission/predictor.py

# %%
# !mv /content/dataset/all_matches.csv .

# %%
df = pd.read_csv('all_matches.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 194354

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv('all_matches.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.isnull().sum()
# Out:
# match_id                       0
# season                         0
# start_date                     0
# venue                          0
# innings                        0
# ball                           0
# batting_team                   0
# bowling_team                   0
# striker                        0
# non_striker                    0
# bowler                         0
# runs_off_bat                   0
# extras                         0
# wides                     188470
# noballs                   193580
# byes                      193843
# legbyes                   191236
# penalty                   194352
# wicket_type               184794
# player_dismissed          184794
# other_wicket_type         194354
# other_player_dismissed    194354
# dtype: int64

# %%
df = df.drop(columns=['other_player_dismissed','other_wicket_type','penalty'])

# %%
df.isnull().sum()
# Out:
# match_id                 0
# season                   0
# start_date               0
# venue                    0
# innings                  0
# ball                     0
# batting_team             0
# bowling_team             0
# striker                  0
# non_striker              0
# bowler                   0
# runs_off_bat             0
# extras                   0
# wides               188470
# noballs             193580
# byes                193843
# legbyes             191236
# wicket_type         184794
# player_dismissed    184794
# dtype: int64

# %%
df['byes'] = df['byes'].fillna(0)
df['noballs'] = df['noballs'].fillna(0)
df['wides'] = df['wides'].fillna(0)
df['legbyes'] = df['legbyes'].fillna(0)
df['player_dismissed'] = df['player_dismissed'].fillna('notout')
df['wicket_type'] = df['wicket_type'].fillna('nowicket')

# %%
df = df.replace(['M Chinnaswamy Stadium',"M.Chinnaswamy Stadium"],"M Chinnaswamy Stadium")
df = df.replace(['MA Chidambaram Stadium, Chepauk',"MA Chidambaram Stadium, Chepauk, Chennai"],"MA Chidambaram Stadium")
df = df.replace(["Punjab Cricket Association IS Bindra Stadium, Mohali","Punjab Cricket Association IS Bindra Stadium","Punjab Cricket Association Stadium, Mohali"],"Punjab Cricket Association Stadium, Mohali")
df = df.replace(['Wankhede Stadium',"Wankhede Stadium, Mumbai","Maharashtra Cricket Association Stadium"],"Wankhede Stadium")
df = df.replace(['Rajiv Gandhi International Stadium, Uppal',"Rajiv Gandhi International Stadium"],"Rajiv Gandhi International Stadium")
df = df.replace(['Rajiv Gandhi International Stadium, Uppal',"Rajiv Gandhi International Stadium"],"Rajiv Gandhi International Stadium")
df = df.replace(["Feroz Shah Kotla"],"Arun Jaitley Stadium")
df = df.replace(['Delhi Daredevils'],"Delhi Capitals")
df = df.replace(['Deccan Chargers'],"Sunrisers Hyderabad")
df = df.replace(['Rising Pune Supergiant'],'Rising Pune Supergiants')
df = df.replace(['Kings XI Punjab'],'Punjab Kings')
df = df.replace(['Sardar Patel Stadium, Motera'],'Narendra Modi Stadium')

# %%
df['season'].astype(str)
df = df.replace(['2007/08'],'2008')
df = df.replace(['2009/10'],'2010')
df = df.replace(['2020/21'],'2020')
df = df.replace([2012],'2012')
df = df.replace([2018],'2018')
df = df.replace([2019],'2019')
df = df.replace([2013],'2013')
df = df.replace([2014],'2014')
df = df.replace([2015],'2015')
df = df.replace([2016],'2016')
df = df.replace([2017],'2017')
df['season'].astype(str)
# Out:
# 0         2008
# 1         2008
# 2         2008
# 3         2008
# 4         2008
#           ...
# 194349    2021
# 194350    2021
# 194351    2021
# 194352    2021
# 194353    2021
# Name: season, Length: 194354, dtype: object

# %% [markdown]
# # EDA

# %%
df = df[(df['season'] == '2016') | (df['season'] == '2017') | (df['season'] == '2018') | (df['season'] == '2019') | (df['season'] == '2020')]
#df = df.drop(index = list(range(176428,176443)))
#df = df.drop(index = list(range(57068,57131)))
#df = df.drop(index = list(range(115599,115727)))

# %%
match1 = df[(df['match_id'] == 335982) & (df['innings'] == 1) & (df['ball'] < 6.0)]
match1['striker'].unique()
# Out:
# array([], dtype=object)

# %%
powerplay = df[(df['ball'] < 6.0)]

# %%
powerplay.head(100)
# Out:
#         match_id season  start_date  ... legbyes  wicket_type  player_dismissed
# 122502    980901   2016  2016-04-09  ...     0.0     nowicket            notout
# 122503    980901   2016  2016-04-09  ...     0.0     nowicket            notout
# 122504    980901   2016  2016-04-09  ...     0.0     nowicket            notout
# 122505    980901   2016  2016-04-09  ...     0.0     nowicket            notout
# 122506    980901   2016  2016-04-09  ...     0.0     nowicket            notout
# ...          ...    ...         ...  ...     ...          ...               ...
# 122738    980903   2016  2016-04-10  ...     0.0          lbw           SS Iyer
# 122739    980903   2016  2016-04-10  ...     0.0     nowicket            notout
# 122740    980903   2016  2016-04-10  ...     0.0     nowicket            notout
# 122741    980903   2016  2016-04-10  ...     0.0     nowicket            notout
# 122742    980903   2016  2016-04-10  ...     0.0     nowicket            notout
#
# [100 rows x 19 columns]

# %%
match_id =list(df['match_id'].unique())

# %%
finaldata = pd.DataFrame(columns=['match_id','venue','innings','batting_team','bowling_team','batsmen','bowlers'])

# %%
for match in match_id:
  #match = 501264
  venue = list(df[(df['match_id'] == match) &(df['innings'] == 1)]['venue'].unique())[0]
  batting_team = list(df[(df['match_id'] == match)  & (df['innings'] == 1)]['batting_team'].unique())[0]
  bowling_team = list(df[(df['match_id'] == match)  & (df['innings'] == 1)]['bowling_team'].unique())[0]
  batsmen = ','.join(list(df[(df['match_id'] == match)  & (df['innings'] == 1)]['striker'].unique()))
  bowlers = ','.join(list(df[(df['match_id'] == match)  & (df['innings'] == 1)]['bowler'].unique()))
  runs = df[(df['match_id'] == match) & (df['innings'] == 1)]['runs_off_bat'].sum() + df[(df['match_id'] == match) & (df['innings'] == 1)]['extras'].sum()
  wickets = len(df[(df['match_id'] == match)& (df['innings'] == 1) & (df['player_dismissed'] != 'notout')])
  #print(match,venue)
  #print(match,venue,1,batting_team,bowling_team,batsmen,bowlers)
  finaldata = finaldata.append({'match_id':match,'venue':venue,'innings':1,'batting_team':batting_team,'bowling_team':bowling_team,'batsmen':batsmen,'bowlers':bowlers,'ppruns':runs,'ppwickets':wickets}, ignore_index=True)

# %%
for match in match_id:
  #print(match)
  venue = df[(df['match_id'] == match)  &(df['innings'] == 2)]['venue'].unique()[0]
  batting_team = list(df[(df['match_id'] == match)  &(df['innings'] == 2)]['batting_team'].unique())[0]
  bowling_team = list(df[(df['match_id'] == match)  &(df['innings'] == 2)]['bowling_team'].unique())[0]
  batsmen = ','.join(list(df[(df['match_id'] == match)  &(df['innings'] == 2)]['striker'].unique()))
  bowlers = ','.join(list(df[(df['match_id'] == match)  &(df['innings'] == 2)]['bowler'].unique()))
  runs = df[(df['match_id'] == match)  &(df['innings'] == 2)]['runs_off_bat'].sum() + df[(df['match_id'] == match) & (df['innings'] == 2)]['extras'].sum()
  wickets = len(df[(df['match_id'] == match)  & (df['innings'] == 2) & (df['player_dismissed'] != 'notout')])
  #print(match,venue)
  #print(match,venue,1,batting_team,bowling_team,batsmen,bowlers)
  finaldata = finaldata.append({'match_id':match,'venue':venue,'innings':2,'batting_team':batting_team,'bowling_team':bowling_team,'batsmen':batsmen,'bowlers':bowlers,'ppruns':runs,'ppwickets':wickets}, ignore_index=True)

# %%
finaldata2=finaldata

# %%
finaldata2.sort_values(by=['match_id','innings'], inplace=True)

# %%
finaldata2
# Out:
#     match_id                                       venue  ... ppruns ppwickets
# 0     980901                            Wankhede Stadium  ...  121.0       8.0
# 299   980901                            Wankhede Stadium  ...  126.0       1.0
# 1     980903                                Eden Gardens  ...   98.0      10.0
# 300   980903                                Eden Gardens  ...   99.0       1.0
# 2     980905  Punjab Cricket Association Stadium, Mohali  ...  161.0       6.0
# ..       ...                                         ...  ...    ...       ...
# 595  1237178                        Sheikh Zayed Stadium  ...  132.0       4.0
# 297  1237180                        Sheikh Zayed Stadium  ...  189.0       3.0
# 596  1237180                        Sheikh Zayed Stadium  ...  172.0       8.0
# 298  1237181         Dubai International Cricket Stadium  ...  156.0       7.0
# 597  1237181         Dubai International Cricket Stadium  ...  157.0       5.0
#
# [598 rows x 9 columns]

# %% [markdown]
# # Player Index

# %%
indexdata = df[(df['innings'] < 3)]

# %%
indexdata['season'].unique()
# Out:
# array(['2016', '2017', '2019', '2018', '2020'], dtype=object)

# %%
season_list = list(df['season'].unique())

# %%
df['season'].unique()
# Out:
# array(['2016', '2017', '2019', '2018', '2020'], dtype=object)

# %%
df['season'].unique()
# Out:
# array(['2016', '2017', '2019', '2018', '2020'], dtype=object)

# %%
season_list
# Out:
# ['2016', '2017', '2019', '2018', '2020']

# %%
season_list = list(df['season'].unique())
for season in season_list:
  print(season,'---',len(df[df['season']==season]['match_id'].unique()))
# Out:
# 2016 --- 60
# 2017 --- 59
# 2019 --- 60
# 2018 --- 60
# 2020 --- 60

# %%
indexdata19to20 = indexdata[(indexdata['season'] == '2016') | (indexdata['season'] == '2017') | (indexdata['season'] == '2018') | (indexdata['season'] == '2019') | (indexdata['season'] == '2020')]
indexdata19to20 = indexdata19to20[(indexdata19to20['innings'] < 3)]

# %% [markdown]
# ## Venue Stats

# %%
indexdata19to20.shape
# Out:
# (71034, 19)

# %% [markdown]
# ### All seasons

# %%
venuedata = pd.DataFrame(columns=['venue','runs','wickets','matches','balls','index1','index2'])
venue_list = list(indexdata['venue'].unique())
for venue in venue_list:  #innings diff
  venue_runs = indexdata[(indexdata['venue'] == venue) ]['runs_off_bat'].sum() + indexdata[(indexdata['venue'] == venue) ]['extras'].sum()
  venue_runs_1 = indexdata[(indexdata['venue'] == venue) & (indexdata['innings']==1)]['runs_off_bat'].sum() + indexdata[(indexdata['venue'] == venue) & (indexdata['innings']==1)]['extras'].sum()
  venue_runs_2 = indexdata[(indexdata['venue'] == venue) & (indexdata['innings']==2)]['runs_off_bat'].sum() + indexdata[(indexdata['venue'] == venue) & (indexdata['innings']==2)]['extras'].sum()
  venue_wicket = len(indexdata[(indexdata['venue'] == venue) & (indexdata['player_dismissed'] != 'notout')])
  balls = len(indexdata[indexdata['venue'] == venue])
  matches = len(indexdata[indexdata['venue'] == venue]['match_id'].unique())
  print(venue,"\n\tRuns : ",venue_runs,'runs',venue_runs,'runs_1',venue_runs_1,'runs_2',venue_runs_2,"\tWickets : ",venue_wicket,"\tBalls played",balls,"\tMatches played : ",matches,'\nIndex1 : ',venue_runs_1/(matches),'\nIndex2 : ',venue_runs_2/(matches))
  venuedata = venuedata.append({'venue':venue,'runs':venue_runs,'wickets':venue_wicket,'matches':matches,'balls':balls,'index1':venue_runs_1/(matches),'index2':venue_runs_2/(matches)}, ignore_index=True)
  print()
# Out:
# Wankhede Stadium
# 	Runs :  14873 runs 14873 runs_1 7631 runs_2 7242 	Wickets :  522 	Balls played 10908 	Matches played :  45
# Index1 :  169.57777777777778
# Index2 :  160.93333333333334
#
# Eden Gardens
# 	Runs :  9803 runs 9803 runs_1 5147 runs_2 4656 	Wickets :  347 	Balls played 6963 	Matches played :  30
# Index1 :  171.56666666666666
# Index2 :  155.2
#
# Punjab Cricket Association Stadium, Mohali
# 	Runs :  7021 runs 7021 runs_1 3561 runs_2 3460 	Wickets :  219 	Balls played 5003 	Matches played :  21
# Index1 :  169.57142857142858
# Index2 :  164.76190476190476
#
# M Chinnaswamy Stadium
# 	Runs :  10210 runs 10210 runs_1 5347 runs_2 4863 	Wickets :  373 	Balls played 7166 	Matches played :  31
# Index1 :  172.48387096774192
# Index2 :  156.8709677419355
#
# Saurashtra Cricket Association Stadium
# 	Runs :  3316 runs 3316 runs_1 1689 runs_2 1627 	Wickets :  107 	Balls played 2368 	Matches played :  10
# Index1 :  168.9
# Index2 :  162.7
#
# Arun Jaitley Stadium
# 	Runs :  9088 runs 9088 runs_1 4765 runs_2 4323 	Wickets :  348 	Balls played 6694 	Matches played :  28
# Index1 :  170.17857142857142
# Index2 :  154.39285714285714
#
# Rajiv Gandhi International Stadium
# 	Runs :  9154 runs 9154 runs_1 4766 runs_2 4388 	Wickets :  361 	Balls played 7176 	Matches played :  30
# Index1 :  158.86666666666667
# Index2 :  146.26666666666668
#
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium
# 	Runs :  2289 runs 2289 runs_1 1246 runs_2 1043 	Wickets :  104 	Balls played 1869 	Matches played :  8
# Index1 :  155.75
# Index2 :  130.375
#
# Green Park
# 	Runs :  1298 runs 1298 runs_1 645 runs_2 653 	Wickets :  49 	Balls played 921 	Matches played :  4
# Index1 :  161.25
# Index2 :  163.25
#
# Shaheed Veer Narayan Singh International Stadium
# 	Runs :  596 runs 596 runs_1 296 runs_2 300 	Wickets :  23 	Balls played 483 	Matches played :  2
# Index1 :  148.0
# Index2 :  150.0
#
# Holkar Cricket Stadium
# 	Runs :  2318 runs 2318 runs_1 1168 runs_2 1150 	Wickets :  69 	Balls played 1557 	Matches played :  7
# Index1 :  166.85714285714286
# Index2 :  164.28571428571428
#
# MA Chidambaram Stadium
# 	Runs :  2563 runs 2563 runs_1 1355 runs_2 1208 	Wickets :  100 	Balls played 2130 	Matches played :  9
# Index1 :  150.55555555555554
# Index2 :  134.22222222222223
#
# Sawai Mansingh Stadium
# 	Runs :  4403 runs 4403 runs_1 2273 runs_2 2130 	Wickets :  156 	Balls played 3286 	Matches played :  14
# Index1 :  162.35714285714286
# Index2 :  152.14285714285714
#
# Sheikh Zayed Stadium
# 	Runs :  6919 runs 6919 runs_1 3575 runs_2 3344 	Wickets :  231 	Balls played 5294 	Matches played :  22
# Index1 :  162.5
# Index2 :  152.0
#
# Dubai International Cricket Stadium
# 	Runs :  8338 runs 8338 runs_1 4460 runs_2 3878 	Wickets :  306 	Balls played 6338 	Matches played :  26
# Index1 :  171.53846153846155
# Index2 :  149.15384615384616
#
# Sharjah Cricket Stadium
# 	Runs :  4095 runs 4095 runs_1 2135 runs_2 1960 	Wickets :  131 	Balls played 2878 	Matches played :  12
# Index1 :  177.91666666666666
# Index2 :  163.33333333333334

# %%
venuedata
# Out:
#                                                 venue  ...      index2
# 0                                    Wankhede Stadium  ...  160.933333
# 1                                        Eden Gardens  ...  155.200000
# 2          Punjab Cricket Association Stadium, Mohali  ...  164.761905
# 3                               M Chinnaswamy Stadium  ...  156.870968
# 4              Saurashtra Cricket Association Stadium  ...  162.700000
# 5                                Arun Jaitley Stadium  ...  154.392857
# 6                  Rajiv Gandhi International Stadium  ...  146.266667
# 7   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  ...  130.375000
# 8                                          Green Park  ...  163.250000
# 9    Shaheed Veer Narayan Singh International Stadium  ...  150.000000
# 10                             Holkar Cricket Stadium  ...  164.285714
# 11                             MA Chidambaram Stadium  ...  134.222222
# 12                             Sawai Mansingh Stadium  ...  152.142857
# 13                               Sheikh Zayed Stadium  ...  152.000000
# 14                Dubai International Cricket Stadium  ...  149.153846
# 15                            Sharjah Cricket Stadium  ...  163.333333
#
# [16 rows x 7 columns]

# %%
indexdata['innings'].value_counts()
# Out:
# 1    36808
# 2    34226
# Name: innings, dtype: int64

# %% [markdown]
# ### Venue wise stats for from 2019

# %%
venue_list = list(indexdata19to20['venue'].unique())

# %%
len(indexdata19to20['match_id'].unique())
# Out:
# 299

# %%
for venue in venue_list:  #innings diff
  venue_runs = indexdata19to20[indexdata19to20['venue'] == venue]['runs_off_bat'].sum() + indexdata19to20[(indexdata19to20['venue'] == venue) ]['extras'].sum()
  venue_runs_1 = indexdata19to20[(indexdata19to20['venue'] == venue) & (indexdata19to20['innings'] == 1)]['runs_off_bat'].sum() + indexdata19to20[(indexdata19to20['venue'] == venue) & (indexdata19to20['innings'] == 1)]['extras'].sum()
  venue_runs_2 = indexdata19to20[(indexdata19to20['venue'] == venue) & (indexdata19to20['innings'] == 2)]['runs_off_bat'].sum() + indexdata19to20[(indexdata19to20['venue'] == venue) & (indexdata19to20['innings'] == 2)]['extras'].sum()
  venue_wicket = len(indexdata19to20[(indexdata19to20['venue'] == venue) & (indexdata19to20['player_dismissed'] != 'notout')])
  balls = len(indexdata19to20[indexdata19to20['venue'] == venue])
  matches = len(indexdata19to20[indexdata19to20['venue'] == venue]['match_id'].unique())
  print(venue,"\n\tRuns : ",venue_runs,"\n\tRuns_1 : ",venue_runs_1,"\n\tRuns_2 : ",venue_runs_2,"\tWickets : ",venue_wicket,"\tBalls played",balls,"\tMatches played : ",matches,'\nIndex : ',venue_runs/math.ceil(balls/6))
  print()
# Out:
# Wankhede Stadium
# 	Runs :  14873
# 	Runs_1 :  7631
# 	Runs_2 :  7242 	Wickets :  522 	Balls played 10908 	Matches played :  45
# Index :  8.18096809680968
#
# Eden Gardens
# 	Runs :  9803
# 	Runs_1 :  5147
# 	Runs_2 :  4656 	Wickets :  347 	Balls played 6963 	Matches played :  30
# Index :  8.443583118001722
#
# Punjab Cricket Association Stadium, Mohali
# 	Runs :  7021
# 	Runs_1 :  3561
# 	Runs_2 :  3460 	Wickets :  219 	Balls played 5003 	Matches played :  21
# Index :  8.418465227817746
#
# M Chinnaswamy Stadium
# 	Runs :  10210
# 	Runs_1 :  5347
# 	Runs_2 :  4863 	Wickets :  373 	Balls played 7166 	Matches played :  31
# Index :  8.543933054393305
#
# Saurashtra Cricket Association Stadium
# 	Runs :  3316
# 	Runs_1 :  1689
# 	Runs_2 :  1627 	Wickets :  107 	Balls played 2368 	Matches played :  10
# Index :  8.39493670886076
#
# Arun Jaitley Stadium
# 	Runs :  9088
# 	Runs_1 :  4765
# 	Runs_2 :  4323 	Wickets :  348 	Balls played 6694 	Matches played :  28
# Index :  8.14336917562724
#
# Rajiv Gandhi International Stadium
# 	Runs :  9154
# 	Runs_1 :  4766
# 	Runs_2 :  4388 	Wickets :  361 	Balls played 7176 	Matches played :  30
# Index :  7.653846153846154
#
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium
# 	Runs :  2289
# 	Runs_1 :  1246
# 	Runs_2 :  1043 	Wickets :  104 	Balls played 1869 	Matches played :  8
# Index :  7.336538461538462
#
# Green Park
# 	Runs :  1298
# 	Runs_1 :  645
# 	Runs_2 :  653 	Wickets :  49 	Balls played 921 	Matches played :  4
# Index :  8.428571428571429
#
# Shaheed Veer Narayan Singh International Stadium
# 	Runs :  596
# 	Runs_1 :  296
# 	Runs_2 :  300 	Wickets :  23 	Balls played 483 	Matches played :  2
# Index :  7.3580246913580245
#
# Holkar Cricket Stadium
# 	Runs :  2318
# 	Runs_1 :  1168
# 	Runs_2 :  1150 	Wickets :  69 	Balls played 1557 	Matches played :  7
# Index :  8.915384615384616
#
# MA Chidambaram Stadium
# 	Runs :  2563
# 	Runs_1 :  1355
# 	Runs_2 :  1208 	Wickets :  100 	Balls played 2130 	Matches played :  9
# Index :  7.219718309859155
#
# Sawai Mansingh Stadium
# 	Runs :  4403
# 	Runs_1 :  2273
# 	Runs_2 :  2130 	Wickets :  156 	Balls played 3286 	Matches played :  14
# Index :  8.034671532846716
#
# Sheikh Zayed Stadium
# 	Runs :  6919
# 	Runs_1 :  3575
# 	Runs_2 :  3344 	Wickets :  231 	Balls played 5294 	Matches played :  22
# Index :  7.835787089467724
#
# Dubai International Cricket Stadium
# 	Runs :  8338
# 	Runs_1 :  4460
# 	Runs_2 :  3878 	Wickets :  306 	Balls played 6338 	Matches played :  26
# Index :  7.888363292336802
#
# Sharjah Cricket Stadium
# 	Runs :  4095
# 	Runs_1 :  2135
# 	Runs_2 :  1960 	Wickets :  131 	Balls played 2878 	Matches played :  12
# Index :  8.53125

# %% [markdown]
# ## Team Stats

# %% [markdown]
# ### All seasons

# %%
teamdata = pd.DataFrame(columns=['team','runs','wickets','matches','matches_1','matches_2','balls','batindex_1','batindex_2','bowlindex_1','bowlindex_2'])
team_list = list(indexdata['batting_team'].unique())
for team in team_list:
  team_runs = indexdata[indexdata['batting_team'] == team]['runs_off_bat'].sum() +  indexdata[indexdata['batting_team'] == team]['extras'].sum()
  team_runs_1 = indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==1)]['runs_off_bat'].sum() +  indexdata[indexdata['batting_team'] == team]['extras'].sum()
  team_runs_2 = indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==2)]['runs_off_bat'].sum() +  indexdata[indexdata['batting_team'] == team]['extras'].sum()

  team_wicket = len(indexdata[(indexdata['batting_team'] == team) & (indexdata['player_dismissed'] != 'notout')])
  team_wicket_1 = len(indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==1) & (indexdata['player_dismissed'] != 'notout')])
  team_wicket_2 = len(indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==2) & (indexdata['player_dismissed'] != 'notout')])
  balls = len(indexdata[(indexdata['batting_team'] == team)])
  balls_1 = len(indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==1)])
  balls_2 = len(indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==2)])
  
  matches = len(indexdata[(indexdata['batting_team'] == team) ]['match_id'].unique())
  matches_1 = len(indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==1)]['match_id'].unique())
  matches_2 = len(indexdata[(indexdata['batting_team'] == team) & (indexdata['innings']==2)]['match_id'].unique())

  print(team,"\n\tRuns : ",team_runs,"\tWickets : ",team_wicket,"\tBalls played",balls,"\tMatches played 1 : ",matches_1,"\tMatches played 2 : ",matches_2,'\nBatIndex1 : ',team_runs_1/(matches_1),'\nBatIndex2 : ',team_runs_2/(matches_2),'\nBowlIndex1 : ',balls_1/team_wicket_1,'\nBowlIndex2 : ',balls_2/team_wicket_2)
  teamdata = teamdata.append({'team':team,'runs':team_runs,'wickets':team_wicket,'matches':matches,'matches_1':matches_1,'matches_2':matches_2,'balls':balls,'batindex_1':team_runs_1/(matches_1),'batindex_2':team_runs_2/(matches_2),'bowlindex_1':balls_1/team_wicket_1,'bowlindex_2':balls_2/team_wicket_2}, ignore_index=True)
  print()
# Out:
# Mumbai Indians
# 	Runs :  12759 	Wickets :  445 	Balls played 9250 	Matches played 1 :  41 	Matches played 2 :  36
# BatIndex1 :  177.5609756097561
# BatIndex2 :  168.72222222222223
# BowlIndex1 :  20.10236220472441
# BowlIndex2 :  21.69633507853403
#
# Rising Pune Supergiants
# 	Runs :  4533 	Wickets :  158 	Balls played 3480 	Matches played 1 :  15 	Matches played 2 :  15
# BatIndex1 :  168.53333333333333
# BatIndex2 :  147.06666666666666
# BowlIndex1 :  21.68235294117647
# BowlIndex2 :  22.424657534246574
#
# Delhi Capitals
# 	Runs :  11962 	Wickets :  461 	Balls played 8904 	Matches played 1 :  38 	Matches played 2 :  37
# BatIndex1 :  172.28947368421052
# BatIndex2 :  160.1891891891892
# BowlIndex1 :  20.142241379310345
# BowlIndex2 :  18.475982532751093
#
# Kolkata Knight Riders
# 	Runs :  12191 	Wickets :  442 	Balls played 8800 	Matches played 1 :  38 	Matches played 2 :  37
# BatIndex1 :  176.5
# BatIndex2 :  163.72972972972974
# BowlIndex1 :  18.733067729083665
# BowlIndex2 :  21.455497382198953
#
# Punjab Kings
# 	Runs :  11315 	Wickets :  413 	Balls played 8303 	Matches played 1 :  36 	Matches played 2 :  34
# BatIndex1 :  172.58333333333334
# BatIndex2 :  163.97058823529412
# BowlIndex1 :  19.674107142857142
# BowlIndex2 :  20.613756613756614
#
# Gujarat Lions
# 	Runs :  4856 	Wickets :  188 	Balls played 3558 	Matches played 1 :  14 	Matches played 2 :  16
# BatIndex1 :  171.64285714285714
# BatIndex2 :  167.625
# BowlIndex1 :  17.26
# BowlIndex2 :  20.818181818181817
#
# Royal Challengers Bangalore
# 	Runs :  11634 	Wickets :  417 	Balls played 8491 	Matches played 1 :  43 	Matches played 2 :  29
# BatIndex1 :  173.46511627906978
# BatIndex2 :  160.6551724137931
# BowlIndex1 :  21.497925311203318
# BowlIndex2 :  18.806818181818183
#
# Sunrisers Hyderabad
# 	Runs :  12722 	Wickets :  425 	Balls played 9488 	Matches played 1 :  41 	Matches played 2 :  38
# BatIndex1 :  175.46341463414635
# BatIndex2 :  160.5
# BowlIndex1 :  21.752136752136753
# BowlIndex2 :  23.026178010471206
#
# Chennai Super Kings
# 	Runs :  7473 	Wickets :  232 	Balls played 5706 	Matches played 1 :  16 	Matches played 2 :  31
# BatIndex1 :  180.1875
# BatIndex2 :  158.83870967741936
# BowlIndex1 :  26.17105263157895
# BowlIndex2 :  23.826923076923077
#
# Rajasthan Royals
# 	Runs :  6839 	Wickets :  265 	Balls played 5054 	Matches played 1 :  17 	Matches played 2 :  26
# BatIndex1 :  171.7058823529412
# BatIndex2 :  160.8846153846154
# BowlIndex1 :  19.009090909090908
# BowlIndex2 :  19.116129032258065

# %%
teamdata
# Out:
#                           team   runs  ... bowlindex_1 bowlindex_2
# 0               Mumbai Indians  12759  ...   20.102362   21.696335
# 1      Rising Pune Supergiants   4533  ...   21.682353   22.424658
# 2               Delhi Capitals  11962  ...   20.142241   18.475983
# 3        Kolkata Knight Riders  12191  ...   18.733068   21.455497
# 4                 Punjab Kings  11315  ...   19.674107   20.613757
# 5                Gujarat Lions   4856  ...   17.260000   20.818182
# 6  Royal Challengers Bangalore  11634  ...   21.497925   18.806818
# 7          Sunrisers Hyderabad  12722  ...   21.752137   23.026178
# 8          Chennai Super Kings   7473  ...   26.171053   23.826923
# 9             Rajasthan Royals   6839  ...   19.009091   19.116129
#
# [10 rows x 11 columns]

# %% [markdown]
# ### Team wise stats from 2019

# %%
team_list = list(indexdata19to20['batting_team'].unique())
for team in team_list:
  team_runs = indexdata19to20[indexdata19to20['batting_team'] == team]['runs_off_bat'].sum() + indexdata19to20[indexdata19to20['batting_team'] == team]['extras'].sum()
  team_wicket = len(indexdata19to20[(indexdata19to20['batting_team'] == team) & (indexdata19to20['player_dismissed'] != 'notout')])
  balls = len(indexdata19to20[(indexdata19to20['batting_team'] == team)])
  matches = len(indexdata19to20[indexdata19to20['batting_team'] == team]['match_id'].unique())
  print(team,"\n\tRuns : ",team_runs,"\tWickets : ",team_wicket,"\tBalls played",balls,"\tMatches played : ",matches,'\nBatIndex : ',team_runs/matches,'\nBowlIndex : ',balls/team_wicket)
  print()
# Out:
# Mumbai Indians
# 	Runs :  12759 	Wickets :  445 	Balls played 9250 	Matches played :  77
# BatIndex :  165.7012987012987
# BowlIndex :  20.786516853932586
#
# Rising Pune Supergiants
# 	Runs :  4533 	Wickets :  158 	Balls played 3480 	Matches played :  30
# BatIndex :  151.1
# BowlIndex :  22.025316455696203
#
# Delhi Capitals
# 	Runs :  11962 	Wickets :  461 	Balls played 8904 	Matches played :  75
# BatIndex :  159.49333333333334
# BowlIndex :  19.314533622559654
#
# Kolkata Knight Riders
# 	Runs :  12191 	Wickets :  442 	Balls played 8800 	Matches played :  75
# BatIndex :  162.54666666666665
# BowlIndex :  19.90950226244344
#
# Punjab Kings
# 	Runs :  11315 	Wickets :  413 	Balls played 8303 	Matches played :  70
# BatIndex :  161.64285714285714
# BowlIndex :  20.10411622276029
#
# Gujarat Lions
# 	Runs :  4856 	Wickets :  188 	Balls played 3558 	Matches played :  30
# BatIndex :  161.86666666666667
# BowlIndex :  18.925531914893618
#
# Royal Challengers Bangalore
# 	Runs :  11634 	Wickets :  417 	Balls played 8491 	Matches played :  72
# BatIndex :  161.58333333333334
# BowlIndex :  20.362110311750598
#
# Sunrisers Hyderabad
# 	Runs :  12722 	Wickets :  425 	Balls played 9488 	Matches played :  79
# BatIndex :  161.0379746835443
# BowlIndex :  22.32470588235294
#
# Chennai Super Kings
# 	Runs :  7473 	Wickets :  232 	Balls played 5706 	Matches played :  47
# BatIndex :  159.0
# BowlIndex :  24.594827586206897
#
# Rajasthan Royals
# 	Runs :  6839 	Wickets :  265 	Balls played 5054 	Matches played :  43
# BatIndex :  159.04651162790697
# BowlIndex :  19.071698113207546

# %% [markdown]
# ## Player Stats

# %% [markdown]
# ### All Seasons

# %%
batsmandata = pd.DataFrame(columns=['batsman','runs','matches','balls','strike_1','strike_2','index_1','index_2'])
bowlerdata = pd.DataFrame(columns=['bowler','wickets','matches','balls','A1index','A2index'])

# %%
batsman_list = list(indexdata['striker'].unique())
bowler_list = list(indexdata['bowler'].unique())

# %%
for batsman in batsman_list:
  runs = indexdata[indexdata['striker']==batsman]['runs_off_bat'].sum()
  runs_1 = indexdata[(indexdata['striker']==batsman) & (indexdata['innings']==1)]['runs_off_bat'].sum()
  runs_2 = indexdata[(indexdata['striker']==batsman) & (indexdata['innings']==2)]['runs_off_bat'].sum()
  
  matches = len(indexdata[indexdata['striker']==batsman]['match_id'].unique())
  matches_1 = len(indexdata[(indexdata['striker']==batsman) & (indexdata['innings']==1)]['match_id'].unique())
  matches_2 = len(indexdata[(indexdata['striker']==batsman) & (indexdata['innings']==2)]['match_id'].unique())

  balls = len(indexdata[(indexdata['striker']==batsman)])
  balls_1 = len(indexdata[(indexdata['striker']==batsman) & (indexdata['innings']==1)])
  balls_2 = len(indexdata[(indexdata['striker']==batsman) & (indexdata['innings']==2)])


  strike_1 = (runs_1/balls_1)*100
  strike_2 = (runs_2/balls_2)*100
  index_1 = (runs_1/matches_1)
  index_2 = (runs_2/matches_2)
  print(batsman,"\nRuns : ",runs,'\tMatches : ',matches,'\tBalls : ',balls,"\nstrike1 : ",strike_1,'\tstrike_2',strike_2,'\tindex_1',index_1,'\tindex_2',index_2)
  batsmandata = batsmandata.append({'batsman':batsman,'runs':runs,'matches':matches,'balls':balls,'strike_1':strike_1,'strike_2':strike_2,'index_1':index_1,'index_2':index_2}, ignore_index=True)
  print()
# Out:
# LMP Simmons
# Runs :  145 	Matches :  8 	Balls :  124
# strike1 :  111.42857142857143 	strike_2 124.07407407407408 	index_1 15.6 	index_2 22.333333333333332
#
# RG Sharma
# Runs :  1845 	Matches :  71 	Balls :  1464
# strike1 :  125.33692722371967 	strike_2 126.73130193905817 	index_1 23.25 	index_2 29.516129032258064
#
# HH Pandya
# Runs :  1237 	Matches :  66 	Balls :  829
# strike1 :  154.43298969072166 	strike_2 141.86046511627907 	index_1 20.243243243243242 	index_2 16.82758620689655
#
# JC Buttler
# Runs :  1714 	Matches :  57 	Balls :  1184
# strike1 :  128.13953488372093 	strike_2 154.24403183023873 	index_1 25.045454545454547 	index_2 33.22857142857143
#
# AT Rayudu
# Runs :  1668 	Matches :  61 	Balls :  1370
# strike1 :  130.33268101761252 	strike_2 116.64726426076835 	index_1 26.64 	index_2 27.833333333333332
#
# KA Pollard
# Runs :  1272 	Matches :  60 	Balls :  883
# strike1 :  136.55913978494624 	strike_2 152.39234449760767 	index_1 18.676470588235293 	index_2 24.5
#
# S Gopal
# Runs :  152 	Matches :  17 	Balls :  150
# strike1 :  96.15384615384616 	strike_2 106.94444444444444 	index_1 12.5 	index_2 7.0
#
# Harbhajan Singh
# Runs :  138 	Matches :  18 	Balls :  149
# strike1 :  105.71428571428572 	strike_2 81.0126582278481 	index_1 10.571428571428571 	index_2 5.818181818181818
#
# R Vinay Kumar
# Runs :  19 	Matches :  3 	Balls :  16
# strike1 :  108.33333333333333 	strike_2 150.0 	index_1 6.5 	index_2 6.0
#
# MJ McClenaghan
# Runs :  72 	Matches :  17 	Balls :  67
# strike1 :  80.76923076923077 	strike_2 124.39024390243902 	index_1 2.1 	index_2 7.285714285714286
#
# AM Rahane
# Runs :  1738 	Matches :  65 	Balls :  1438
# strike1 :  120.73863636363636 	strike_2 120.98092643051773 	index_1 27.419354838709676 	index_2 26.11764705882353
#
# F du Plessis
# Runs :  1221 	Matches :  38 	Balls :  961
# strike1 :  126.21359223300972 	strike_2 127.68670309653916 	index_1 34.666666666666664 	index_2 30.47826086956522
#
# KP Pietersen
# Runs :  73 	Matches :  4 	Balls :  61
# strike1 :  113.04347826086956 	strike_2 140.0 	index_1 26.0 	index_2 10.5
#
# MA Agarwal
# Runs :  929 	Matches :  41 	Balls :  673
# strike1 :  139.29824561403507 	strike_2 137.11340206185568 	index_1 22.055555555555557 	index_2 23.130434782608695
#
# Q de Kock
# Runs :  1678 	Matches :  53 	Balls :  1273
# strike1 :  130.70866141732282 	strike_2 132.9153605015674 	index_1 29.642857142857142 	index_2 33.92
#
# SS Iyer
# Runs :  1761 	Matches :  64 	Balls :  1442
# strike1 :  123.53643966547192 	strike_2 120.16528925619834 	index_1 29.542857142857144 	index_2 25.06896551724138
#
# KK Nair
# Runs :  960 	Matches :  41 	Balls :  778
# strike1 :  123.30827067669172 	strike_2 123.48284960422164 	index_1 24.6 	index_2 22.285714285714285
#
# SV Samson
# Runs :  1835 	Matches :  68 	Balls :  1345
# strike1 :  142.11409395973155 	strike_2 131.90921228304407 	index_1 31.37037037037037 	index_2 24.097560975609756
#
# P Negi
# Runs :  213 	Matches :  22 	Balls :  194
# strike1 :  114.7887323943662 	strike_2 96.15384615384616 	index_1 10.866666666666667 	index_2 7.142857142857143
#
# CR Brathwaite
# Runs :  181 	Matches :  14 	Balls :  120
# strike1 :  163.33333333333334 	strike_2 113.33333333333333 	index_1 14.7 	index_2 8.5
#
# CH Morris
# Runs :  461 	Matches :  29 	Balls :  296
# strike1 :  153.50318471337582 	strike_2 158.27338129496403 	index_1 14.176470588235293 	index_2 18.333333333333332
#
# NM Coulter-Nile
# Runs :  48 	Matches :  7 	Balls :  42
# strike1 :  114.28571428571428 	strike_2 nan 	index_1 6.857142857142857 	index_2 nan
#
# A Mishra
# Runs :  75 	Matches :  13 	Balls :  98
# strike1 :  78.78787878787878 	strike_2 75.38461538461539 	index_1 6.5 	index_2 5.444444444444445
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# Z Khan
# Runs :  10 	Matches :  5 	Balls :  26
# strike1 :  44.44444444444444 	strike_2 35.294117647058826 	index_1 4.0 	index_2 1.5
#
# RV Uthappa
# Runs :  1611 	Matches :  67 	Balls :  1237
# strike1 :  128.51919561243145 	strike_2 131.59420289855072 	index_1 25.107142857142858 	index_2 23.28205128205128
#
# G Gambhir
# Runs :  1084 	Matches :  36 	Balls :  920
# strike1 :  117.3913043478261 	strike_2 118.1159420289855 	index_1 28.8 	index_2 31.047619047619047
#
# MK Pandey
# Runs :  1697 	Matches :  62 	Balls :  1379
# strike1 :  127.05718270571826 	strike_2 118.7311178247734 	index_1 30.366666666666667 	index_2 24.5625
#
# M Vijay
# Runs :  561 	Matches :  20 	Balls :  489
# strike1 :  120.39800995024876 	strike_2 110.76388888888889 	index_1 26.88888888888889 	index_2 29.0
#
# M Vohra
# Runs :  445 	Matches :  20 	Balls :  356
# strike1 :  118.75 	strike_2 132.3170731707317 	index_1 22.8 	index_2 21.7
#
# DA Miller
# Runs :  531 	Matches :  30 	Balls :  461
# strike1 :  125.77777777777779 	strike_2 105.08474576271188 	index_1 18.866666666666667 	index_2 16.533333333333335
#
# GJ Maxwell
# Runs :  766 	Matches :  46 	Balls :  549
# strike1 :  134.71698113207546 	strike_2 144.01408450704224 	index_1 13.73076923076923 	index_2 20.45
#
# WP Saha
# Runs :  926 	Matches :  42 	Balls :  730
# strike1 :  126.59574468085107 	strike_2 127.30769230769229 	index_1 23.8 	index_2 19.470588235294116
#
# MP Stoinis
# Runs :  825 	Matches :  42 	Balls :  623
# strike1 :  132.61390887290167 	strike_2 132.03883495145632 	index_1 19.75 	index_2 19.428571428571427
#
# AR Patel
# Runs :  645 	Matches :  52 	Balls :  503
# strike1 :  127.73722627737227 	strike_2 128.82096069868996 	index_1 12.068965517241379 	index_2 12.826086956521738
#
# AJ Finch
# Runs :  1094 	Matches :  46 	Balls :  853
# strike1 :  123.27365728900254 	strike_2 132.46753246753246 	index_1 19.28 	index_2 29.142857142857142
#
# BB McCullum
# Runs :  800 	Matches :  33 	Balls :  587
# strike1 :  127.56410256410255 	strike_2 146.1818181818182 	index_1 24.875 	index_2 23.647058823529413
#
# SK Raina
# Runs :  1669 	Matches :  61 	Balls :  1306
# strike1 :  127.3031825795645 	strike_2 128.20874471086037 	index_1 29.23076923076923 	index_2 25.97142857142857
#
# KD Karthik
# Runs :  1616 	Matches :  70 	Balls :  1204
# strike1 :  133.37988826815644 	strike_2 135.45081967213116 	index_1 24.487179487179485 	index_2 21.322580645161292
#
# RA Jadeja
# Runs :  776 	Matches :  53 	Balls :  623
# strike1 :  133.206106870229 	strike_2 118.2825484764543 	index_1 17.45 	index_2 12.93939393939394
#
# Ishan Kishan
# Runs :  1211 	Matches :  46 	Balls :  907
# strike1 :  129.3666026871401 	strike_2 139.11917098445596 	index_1 25.923076923076923 	index_2 26.85
#
# DJ Bravo
# Runs :  327 	Matches :  32 	Balls :  255
# strike1 :  116.3265306122449 	strike_2 135.66878980891718 	index_1 10.363636363636363 	index_2 10.142857142857142
#
# CH Gayle
# Runs :  1573 	Matches :  50 	Balls :  1153
# strike1 :  139.59827833572453 	strike_2 131.57894736842107 	index_1 37.42307692307692 	index_2 25.0
#
# V Kohli
# Runs :  2741 	Matches :  69 	Balls :  2029
# strike1 :  134.58096013018715 	strike_2 135.875 	index_1 40.34146341463415 	index_2 38.82142857142857
#
# AB de Villiers
# Runs :  2279 	Matches :  63 	Balls :  1452
# strike1 :  160.04319654427647 	strike_2 151.5209125475285 	index_1 40.054054054054056 	index_2 30.653846153846153
#
# SR Watson
# Runs :  1502 	Matches :  65 	Balls :  1158
# strike1 :  125.26096033402922 	strike_2 132.8424153166421 	index_1 20.689655172413794 	index_2 25.055555555555557
#
# KM Jadhav
# Runs :  557 	Matches :  34 	Balls :  490
# strike1 :  144.87179487179486 	strike_2 99.10179640718563 	index_1 16.142857142857142 	index_2 16.55
#
# SN Khan
# Runs :  330 	Matches :  18 	Balls :  249
# strike1 :  158.77862595419847 	strike_2 103.38983050847457 	index_1 20.8 	index_2 15.25
#
# DA Warner
# Runs :  2729 	Matches :  59 	Balls :  1959
# strike1 :  138.69485294117646 	strike_2 140.06888633754306 	index_1 50.3 	index_2 42.06896551724138
#
# S Dhawan
# Runs :  2616 	Matches :  80 	Balls :  2024
# strike1 :  125.41196877710321 	strike_2 134.32835820895522 	index_1 32.86363636363637 	index_2 32.5
#
# MC Henriques
# Runs :  459 	Matches :  26 	Balls :  367
# strike1 :  137.17277486910996 	strike_2 111.93181818181819 	index_1 17.466666666666665 	index_2 17.90909090909091
#
# NV Ojha
# Runs :  216 	Matches :  19 	Balls :  216
# strike1 :  108.10810810810811 	strike_2 82.35294117647058 	index_1 13.333333333333334 	index_2 8.0
#
# DJ Hooda
# Runs :  474 	Matches :  41 	Balls :  405
# strike1 :  132.0855614973262 	strike_2 104.12844036697248 	index_1 11.227272727272727 	index_2 11.947368421052632
#
# EJG Morgan
# Runs :  606 	Matches :  24 	Balls :  479
# strike1 :  130.44982698961937 	strike_2 120.52631578947368 	index_1 26.928571428571427 	index_2 22.9
#
# A Ashish Reddy
# Runs :  47 	Matches :  3 	Balls :  30
# strike1 :  125.0 	strike_2 177.77777777777777 	index_1 7.5 	index_2 32.0
#
# KV Sharma
# Runs :  85 	Matches :  9 	Balls :  76
# strike1 :  66.66666666666666 	strike_2 120.3125 	index_1 2.6666666666666665 	index_2 12.833333333333334
#
# AD Russell
# Runs :  1131 	Matches :  44 	Balls :  657
# strike1 :  180.5352798053528 	strike_2 158.130081300813 	index_1 29.68 	index_2 20.473684210526315
#
# YK Pathan
# Runs :  804 	Matches :  44 	Balls :  637
# strike1 :  112.74238227146813 	strike_2 143.84057971014494 	index_1 16.958333333333332 	index_2 19.85
#
# C Munro
# Runs :  177 	Matches :  11 	Balls :  144
# strike1 :  134.0909090909091 	strike_2 105.35714285714286 	index_1 16.857142857142858 	index_2 14.75
#
# SA Yadav
# Runs :  1703 	Matches :  62 	Balls :  1295
# strike1 :  130.7116104868914 	strike_2 132.7935222672065 	index_1 26.846153846153847 	index_2 28.52173913043478
#
# PA Patel
# Runs :  1098 	Matches :  46 	Balls :  851
# strike1 :  122.06896551724138 	strike_2 136.2980769230769 	index_1 27.94736842105263 	index_2 21.0
#
# SPD Smith
# Runs :  1372 	Matches :  46 	Balls :  1114
# strike1 :  132.16168717047452 	strike_2 113.76146788990826 	index_1 37.6 	index_2 23.846153846153847
#
# MS Dhoni
# Runs :  1645 	Matches :  66 	Balls :  1294
# strike1 :  133.1511839708561 	strike_2 122.68456375838926 	index_1 24.366666666666667 	index_2 25.38888888888889
#
# MR Marsh
# Runs :  7 	Matches :  2 	Balls :  12
# strike1 :  63.63636363636363 	strike_2 0.0 	index_1 7.0 	index_2 0.0
#
# R Bhatia
# Runs :  50 	Matches :  6 	Balls :  37
# strike1 :  144.44444444444443 	strike_2 132.14285714285714 	index_1 3.25 	index_2 18.5
#
# SE Marsh
# Runs :  423 	Matches :  14 	Balls :  332
# strike1 :  119.83471074380165 	strike_2 147.77777777777777 	index_1 26.363636363636363 	index_2 44.333333333333336
#
# MG Johnson
# Runs :  41 	Matches :  6 	Balls :  42
# strike1 :  82.35294117647058 	strike_2 162.5 	index_1 7.0 	index_2 6.5
#
# MM Sharma
# Runs :  93 	Matches :  17 	Balls :  94
# strike1 :  94.23076923076923 	strike_2 104.76190476190477 	index_1 4.9 	index_2 6.285714285714286
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# P Sahu
# Runs :  19 	Matches :  2 	Balls :  13
# strike1 :  146.15384615384613 	strike_2 nan 	index_1 9.5 	index_2 nan
#
# Sandeep Sharma
# Runs :  33 	Matches :  16 	Balls :  39
# strike1 :  40.0 	strike_2 91.17647058823529 	index_1 0.5 	index_2 2.5833333333333335
#
# B Kumar
# Runs :  72 	Matches :  19 	Balls :  71
# strike1 :  116.66666666666667 	strike_2 52.94117647058824 	index_1 4.5 	index_2 1.8
#
# KH Pandya
# Runs :  1000 	Matches :  57 	Balls :  727
# strike1 :  134.85193621867882 	strike_2 141.66666666666669 	index_1 16.914285714285715 	index_2 18.545454545454547
#
# TG Southee
# Runs :  98 	Matches :  10 	Balls :  78
# strike1 :  142.85714285714286 	strike_2 81.81818181818183 	index_1 11.428571428571429 	index_2 6.0
#
# AD Nath
# Runs :  90 	Matches :  10 	Balls :  99
# strike1 :  97.05882352941177 	strike_2 77.41935483870968 	index_1 11.0 	index_2 6.0
#
# JP Faulkner
# Runs :  131 	Matches :  11 	Balls :  120
# strike1 :  102.59740259740259 	strike_2 120.93023255813952 	index_1 11.285714285714286 	index_2 13.0
#
# P Kumar
# Runs :  32 	Matches :  8 	Balls :  36
# strike1 :  94.11764705882352 	strike_2 84.21052631578947 	index_1 3.2 	index_2 5.333333333333333
#
# DS Kulkarni
# Runs :  42 	Matches :  10 	Balls :  30
# strike1 :  135.29411764705884 	strike_2 146.15384615384613 	index_1 3.8333333333333335 	index_2 4.75
#
# NLTC Perera
# Runs :  150 	Matches :  10 	Balls :  97
# strike1 :  126.53061224489797 	strike_2 183.33333333333331 	index_1 10.333333333333334 	index_2 22.0
#
# IK Pathan
# Runs :  13 	Matches :  4 	Balls :  17
# strike1 :  78.57142857142857 	strike_2 66.66666666666666 	index_1 3.6666666666666665 	index_2 2.0
#
# R Ashwin
# Runs :  222 	Matches :  25 	Balls :  176
# strike1 :  120.83333333333333 	strike_2 132.5 	index_1 7.733333333333333 	index_2 10.6
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# D Wiese
# Runs :  5 	Matches :  1 	Balls :  4
# strike1 :  125.0 	strike_2 nan 	index_1 5.0 	index_2 nan
#
# JP Duminy
# Runs :  227 	Matches :  10 	Balls :  203
# strike1 :  122.22222222222223 	strike_2 103.53982300884957 	index_1 27.5 	index_2 19.5
#
# MJ Guptill
# Runs :  270 	Matches :  13 	Balls :  196
# strike1 :  123.80952380952381 	strike_2 179.59183673469389 	index_1 18.2 	index_2 29.333333333333332
#
# KJ Abbott
# Runs :  13 	Matches :  3 	Balls :  8
# strike1 :  185.71428571428572 	strike_2 0.0 	index_1 6.5 	index_2 0.0
#
# Shakib Al Hasan
# Runs :  363 	Matches :  22 	Balls :  323
# strike1 :  112.93103448275863 	strike_2 110.98901098901099 	index_1 16.375 	index_2 16.833333333333332
#
# KL Rahul
# Runs :  2319 	Matches :  54 	Balls :  1675
# strike1 :  134.35828877005346 	strike_2 141.74757281553397 	index_1 37.22222222222222 	index_2 48.666666666666664
#
# TM Head
# Runs :  205 	Matches :  10 	Balls :  151
# strike1 :  145.21739130434784 	strike_2 105.55555555555556 	index_1 23.857142857142858 	index_2 12.666666666666666
#
# STR Binny
# Runs :  255 	Matches :  22 	Balls :  199
# strike1 :  117.33333333333333 	strike_2 134.6774193548387 	index_1 9.777777777777779 	index_2 12.846153846153847
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# KW Richardson
# Runs :  1 	Matches :  1 	Balls :  1
# strike1 :  100.0 	strike_2 nan 	index_1 1.0 	index_2 nan
#
# DW Steyn
# Runs :  2 	Matches :  2 	Balls :  4
# strike1 :  50.0 	strike_2 50.0 	index_1 1.0 	index_2 1.0
#
# Ankit Sharma
# Runs :  28 	Matches :  2 	Balls :  19
# strike1 :  156.25 	strike_2 100.0 	index_1 25.0 	index_2 3.0
#
# M Ashwin
# Runs :  8 	Matches :  6 	Balls :  12
# strike1 :  75.0 	strike_2 50.0 	index_1 2.0 	index_2 0.6666666666666666
#
# NS Naik
# Runs :  31 	Matches :  4 	Balls :  53
# strike1 :  61.702127659574465 	strike_2 33.33333333333333 	index_1 14.5 	index_2 1.0
#
# R Dhawan
# Runs :  14 	Matches :  2 	Balls :  6
# strike1 :  233.33333333333334 	strike_2 nan 	index_1 7.0 	index_2 nan
#
# AP Tare
# Runs :  26 	Matches :  5 	Balls :  40
# strike1 :  40.0 	strike_2 90.0 	index_1 4.0 	index_2 6.0
#
# DR Smith
# Runs :  563 	Matches :  23 	Balls :  384
# strike1 :  145.08670520231215 	strike_2 147.86729857819904 	index_1 22.818181818181817 	index_2 26.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# JA Morkel
# Runs :  16 	Matches :  1 	Balls :  9
# strike1 :  177.77777777777777 	strike_2 nan 	index_1 16.0 	index_2 nan
#
# R Sathish
# Runs :  24 	Matches :  3 	Balls :  24
# strike1 :  nan 	strike_2 100.0 	index_1 nan 	index_2 8.0
#
# PP Chawla
# Runs :  98 	Matches :  14 	Balls :  106
# strike1 :  86.36363636363636 	strike_2 102.49999999999999 	index_1 6.333333333333333 	index_2 8.2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# UT Yadav
# Runs :  47 	Matches :  17 	Balls :  59
# strike1 :  33.33333333333333 	strike_2 127.58620689655173 	index_1 1.1111111111111112 	index_2 4.625
#
# Bipul Sharma
# Runs :  82 	Matches :  7 	Balls :  50
# strike1 :  152.94117647058823 	strike_2 169.6969696969697 	index_1 6.5 	index_2 18.666666666666668
#
# RR Pant
# Runs :  2079 	Matches :  68 	Balls :  1416
# strike1 :  151.00864553314122 	strike_2 142.79778393351802 	index_1 30.823529411764707 	index_2 30.323529411764707
#
# CA Lynn
# Runs :  1216 	Matches :  38 	Balls :  876
# strike1 :  130.272952853598 	strike_2 146.08879492600423 	index_1 30.88235294117647 	index_2 32.904761904761905
#
# SS Tiwary
# Runs :  325 	Matches :  13 	Balls :  276
# strike1 :  121.875 	strike_2 100.0 	index_1 30.333333333333332 	index_2 13.0
#
# SW Billings
# Runs :  334 	Matches :  19 	Balls :  256
# strike1 :  122.85714285714286 	strike_2 146.9135802469136 	index_1 19.545454545454547 	index_2 14.875
#
# Mohammed Shami
# Runs :  48 	Matches :  13 	Balls :  39
# strike1 :  42.857142857142854 	strike_2 168.0 	index_1 1.0 	index_2 6.0
#
# JO Holder
# Runs :  88 	Matches :  8 	Balls :  74
# strike1 :  133.33333333333331 	strike_2 116.12903225806453 	index_1 8.0 	index_2 12.0
#
# SP Narine
# Runs :  852 	Matches :  50 	Balls :  529
# strike1 :  152.03252032520325 	strike_2 168.90459363957598 	index_1 15.583333333333334 	index_2 18.384615384615383
#
# KS Williamson
# Runs :  1588 	Matches :  50 	Balls :  1193
# strike1 :  135.74660633484163 	strike_2 129.81132075471697 	index_1 32.142857142857146 	index_2 31.272727272727273
#
# Sachin Baby
# Runs :  134 	Matches :  9 	Balls :  99
# strike1 :  136.5079365079365 	strike_2 133.33333333333331 	index_1 21.5 	index_2 9.6
#
# Parvez Rasool
# Runs :  10 	Matches :  1 	Balls :  9
# strike1 :  nan 	strike_2 111.11111111111111 	index_1 nan 	index_2 10.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# Gurkeerat Singh
# Runs :  282 	Matches :  14 	Balls :  243
# strike1 :  122.34042553191489 	strike_2 112.08053691275168 	index_1 16.428571428571427 	index_2 23.857142857142858
#
# KC Cariappa
# Runs :  24 	Matches :  5 	Balls :  21
# strike1 :  166.66666666666669 	strike_2 93.33333333333333 	index_1 5.0 	index_2 4.666666666666667
#
# PSP Handscomb
# Runs :  6 	Matches :  1 	Balls :  12
# strike1 :  50.0 	strike_2 nan 	index_1 6.0 	index_2 nan
#
# Swapnil Singh
# Runs :  12 	Matches :  3 	Balls :  20
# strike1 :  63.1578947368421 	strike_2 0.0 	index_1 6.0 	index_2 0.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# J Yadav
# Runs :  6 	Matches :  2 	Balls :  12
# strike1 :  50.0 	strike_2 nan 	index_1 3.0 	index_2 nan
#
# UT Khawaja
# Runs :  127 	Matches :  6 	Balls :  105
# strike1 :  160.8695652173913 	strike_2 109.75609756097562 	index_1 18.5 	index_2 22.5
#
# Yuvraj Singh
# Runs :  651 	Matches :  31 	Balls :  528
# strike1 :  132.40740740740742 	strike_2 108.8235294117647 	index_1 20.428571428571427 	index_2 22.2
#
# GJ Bailey
# Runs :  84 	Matches :  5 	Balls :  99
# strike1 :  113.79310344827587 	strike_2 72.85714285714285 	index_1 16.5 	index_2 17.0
#
# HM Amla
# Runs :  577 	Matches :  16 	Balls :  418
# strike1 :  148.95104895104896 	strike_2 114.3939393939394 	index_1 53.25 	index_2 18.875
#
# JJ Bumrah
# Runs :  39 	Matches :  9 	Balls :  38
# strike1 :  100.0 	strike_2 103.7037037037037 	index_1 2.75 	index_2 5.6
#
# F Behardien
# Runs :  14 	Matches :  3 	Balls :  13
# strike1 :  100.0 	strike_2 112.5 	index_1 5.0 	index_2 4.5
#
# BB Sran
# Runs :  10 	Matches :  7 	Balls :  14
# strike1 :  66.66666666666666 	strike_2 72.72727272727273 	index_1 0.6666666666666666 	index_2 2.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# A Zampa
# Runs :  5 	Matches :  2 	Balls :  8
# strike1 :  nan 	strike_2 62.5 	index_1 nan 	index_2 2.5
#
# N Rana
# Runs :  1437 	Matches :  55 	Balls :  1093
# strike1 :  129.77867203219316 	strike_2 132.88590604026845 	index_1 22.24137931034483 	index_2 30.46153846153846
#
# A Nehra
# Runs :  1 	Matches :  1 	Balls :  1
# strike1 :  100.0 	strike_2 nan 	index_1 1.0 	index_2 nan
#
# UBT Chand
# Runs :  0 	Matches :  1 	Balls :  5
# strike1 :  0.0 	strike_2 nan 	index_1 0.0 	index_2 nan
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# PV Tambe
# Runs :  7 	Matches :  1 	Balls :  19
# strike1 :  nan 	strike_2 36.84210526315789 	index_1 nan 	index_2 7.0
#
# S Kaushik
# Runs :  0 	Matches :  1 	Balls :  1
# strike1 :  nan 	strike_2 0.0 	index_1 nan 	index_2 0.0
#
# BCJ Cutting
# Runs :  230 	Matches :  16 	Balls :  140
# strike1 :  167.0731707317073 	strike_2 160.3448275862069 	index_1 13.7 	index_2 15.5
#
# S Nadeem
# Runs :  16 	Matches :  7 	Balls :  30
# strike1 :  0.0 	strike_2 55.172413793103445 	index_1 0.0 	index_2 2.6666666666666665
#
# Imran Tahir
# Runs :  20 	Matches :  4 	Balls :  21
# strike1 :  130.0 	strike_2 63.63636363636363 	index_1 13.0 	index_2 2.3333333333333335
#
# M Morkel
# Runs :  1 	Matches :  1 	Balls :  1
# strike1 :  100.0 	strike_2 nan 	index_1 1.0 	index_2 nan
#
# ER Dwivedi
# Runs :  24 	Matches :  2 	Balls :  15
# strike1 :  160.0 	strike_2 nan 	index_1 12.0 	index_2 nan
#
# SB Jakati
# Runs :  1 	Matches :  1 	Balls :  2
# strike1 :  50.0 	strike_2 nan 	index_1 1.0 	index_2 nan
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# Iqbal Abdulla
# Runs :  42 	Matches :  3 	Balls :  34
# strike1 :  71.42857142857143 	strike_2 137.03703703703704 	index_1 5.0 	index_2 18.5
#
# CJ Jordan
# Runs :  32 	Matches :  6 	Balls :  38
# strike1 :  55.00000000000001 	strike_2 116.66666666666667 	index_1 3.6666666666666665 	index_2 7.0
#
# Mandeep Singh
# Runs :  735 	Matches :  42 	Balls :  604
# strike1 :  120.72072072072073 	strike_2 122.87822878228782 	index_1 17.47826086956522 	index_2 17.526315789473685
#
# S Aravind
# Runs :  32 	Matches :  6 	Balls :  40
# strike1 :  56.25 	strike_2 95.83333333333334 	index_1 9.0 	index_2 4.6
#
# YS Chahal
# Runs :  20 	Matches :  12 	Balls :  51
# strike1 :  40.0 	strike_2 38.88888888888889 	index_1 2.0 	index_2 1.5555555555555556
#
# TS Mills
# Runs :  8 	Matches :  3 	Balls :  11
# strike1 :  0.0 	strike_2 100.0 	index_1 0.0 	index_2 4.0
#
# A Choudhary
# Runs :  25 	Matches :  3 	Balls :  20
# strike1 :  125.0 	strike_2 125.0 	index_1 15.0 	index_2 5.0
#
# BA Stokes
# Runs :  920 	Matches :  40 	Balls :  700
# strike1 :  115.46391752577318 	strike_2 142.78728606356967 	index_1 18.666666666666668 	index_2 26.545454545454547
#
# JJ Roy
# Runs :  179 	Matches :  8 	Balls :  139
# strike1 :  107.40740740740742 	strike_2 158.6206896551724 	index_1 14.5 	index_2 46.0
#
# Vishnu Vinod
# Runs :  19 	Matches :  3 	Balls :  26
# strike1 :  73.07692307692307 	strike_2 nan 	index_1 6.333333333333333 	index_2 nan
#
# PJ Cummins
# Runs :  223 	Matches :  18 	Balls :  174
# strike1 :  114.65517241379311 	strike_2 155.17241379310346 	index_1 13.3 	index_2 11.25
#
# MK Tiwary
# Runs :  371 	Matches :  17 	Balls :  287
# strike1 :  134.17085427135677 	strike_2 118.18181818181819 	index_1 29.666666666666668 	index_2 13.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# DT Christian
# Runs :  105 	Matches :  12 	Balls :  85
# strike1 :  129.41176470588235 	strike_2 114.70588235294117 	index_1 9.428571428571429 	index_2 7.8
#
# Basil Thampi
# Runs :  32 	Matches :  7 	Balls :  37
# strike1 :  87.5 	strike_2 84.61538461538461 	index_1 4.2 	index_2 5.5
#
# CR Woakes
# Runs :  63 	Matches :  11 	Balls :  66
# strike1 :  89.47368421052632 	strike_2 103.57142857142858 	index_1 6.8 	index_2 4.833333333333333
#
# CJ Anderson
# Runs :  159 	Matches :  14 	Balls :  152
# strike1 :  90.41095890410958 	strike_2 117.72151898734178 	index_1 11.0 	index_2 11.625
#
# RA Tripathi
# Runs :  988 	Matches :  44 	Balls :  756
# strike1 :  130.06993006993005 	strike_2 131.49847094801223 	index_1 22.32 	index_2 22.63157894736842
#
# DL Chahar
# Runs :  78 	Matches :  10 	Balls :  58
# strike1 :  28.57142857142857 	strike_2 149.01960784313727 	index_1 1.0 	index_2 9.5
#
# AB Dinda
# Runs :  7 	Matches :  1 	Balls :  8
# strike1 :  nan 	strike_2 87.5 	index_1 nan 	index_2 7.0
#
# V Shankar
# Runs :  654 	Matches :  32 	Balls :  528
# strike1 :  135.9683794466403 	strike_2 112.72727272727272 	index_1 21.5 	index_2 19.375
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# Rashid Khan
# Runs :  139 	Matches :  23 	Balls :  99
# strike1 :  150.0 	strike_2 132.0754716981132 	index_1 6.2727272727272725 	index_2 5.833333333333333
#
# VR Aaron
# Runs :  8 	Matches :  5 	Balls :  28
# strike1 :  38.88888888888889 	strike_2 10.0 	index_1 2.3333333333333335 	index_2 0.5
#
# SN Thakur
# Runs :  41 	Matches :  8 	Balls :  36
# strike1 :  47.82608695652174 	strike_2 230.76923076923075 	index_1 2.75 	index_2 7.5
#
# RD Chahar
# Runs :  17 	Matches :  6 	Balls :  17
# strike1 :  100.0 	strike_2 100.0 	index_1 3.75 	index_2 1.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# LH Ferguson
# Runs :  44 	Matches :  3 	Balls :  30
# strike1 :  146.66666666666666 	strike_2 nan 	index_1 14.666666666666666 	index_2 nan
#
# C de Grandhomme
# Runs :  303 	Matches :  21 	Balls :  229
# strike1 :  168.35443037974684 	strike_2 113.33333333333333 	index_1 13.3 	index_2 15.454545454545455
#
# JD Unadkat
# Runs :  61 	Matches :  9 	Balls :  59
# strike1 :  106.06060606060606 	strike_2 100.0 	index_1 7.0 	index_2 6.5
#
# AF Milne
# Runs :  7 	Matches :  3 	Balls :  12
# strike1 :  0.0 	strike_2 63.63636363636363 	index_1 0.0 	index_2 3.5
#
# S Badree
# Runs :  13 	Matches :  5 	Balls :  25
# strike1 :  100.0 	strike_2 45.45454545454545 	index_1 3.0 	index_2 2.5
#
# AD Mathews
# Runs :  32 	Matches :  2 	Balls :  28
# strike1 :  25.0 	strike_2 129.16666666666669 	index_1 1.0 	index_2 31.0
#
# Mohammad Nabi
# Runs :  146 	Matches :  11 	Balls :  102
# strike1 :  147.45762711864407 	strike_2 137.2093023255814 	index_1 10.875 	index_2 19.666666666666668
#
# I Sharma
# Runs :  18 	Matches :  4 	Balls :  16
# strike1 :  137.5 	strike_2 87.5 	index_1 5.5 	index_2 3.5
#
# AJ Tye
# Runs :  91 	Matches :  13 	Balls :  79
# strike1 :  95.0 	strike_2 135.8974358974359 	index_1 5.428571428571429 	index_2 8.833333333333334
#
# K Rabada
# Runs :  125 	Matches :  13 	Balls :  135
# strike1 :  81.08108108108108 	strike_2 96.93877551020408 	index_1 6.0 	index_2 11.875
#
# Kuldeep Yadav
# Runs :  57 	Matches :  10 	Balls :  76
# strike1 :  82.35294117647058 	strike_2 69.04761904761905 	index_1 5.6 	index_2 5.8
#
# Washington Sundar
# Runs :  186 	Matches :  21 	Balls :  154
# strike1 :  114.08450704225352 	strike_2 126.50602409638554 	index_1 7.363636363636363 	index_2 10.5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# DM Bravo
# Runs :  6 	Matches :  1 	Balls :  5
# strike1 :  nan 	strike_2 120.0 	index_1 nan 	index_2 6.0
#
# AR Bawne
# Runs :  12 	Matches :  1 	Balls :  12
# strike1 :  100.0 	strike_2 nan 	index_1 12.0 	index_2 nan
#
# SP Jackson
# Runs :  38 	Matches :  3 	Balls :  31
# strike1 :  111.11111111111111 	strike_2 127.27272727272727 	index_1 10.0 	index_2 14.0
#
# Anureet Singh
# Runs :  18 	Matches :  2 	Balls :  16
# strike1 :  75.0 	strike_2 125.0 	index_1 3.0 	index_2 15.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# Ankit Soni
# Runs :  7 	Matches :  3 	Balls :  9
# strike1 :  77.77777777777779 	strike_2 nan 	index_1 2.3333333333333335 	index_2 nan
#
# SL Malinga
# Runs :  7 	Matches :  2 	Balls :  3
# strike1 :  nan 	strike_2 233.33333333333334 	index_1 nan 	index_2 3.5
#
# PJ Sangwan
# Runs :  2 	Matches :  4 	Balls :  9
# strike1 :  22.22222222222222 	strike_2 nan 	index_1 0.5 	index_2 nan
#
# S Kaul
# Runs :  3 	Matches :  5 	Balls :  17
# strike1 :  30.0 	strike_2 0.0 	index_1 1.5 	index_2 0.0
#
# MN Samuels
# Runs :  29 	Matches :  4 	Balls :  32
# strike1 :  122.72727272727273 	strike_2 20.0 	index_1 27.0 	index_2 0.6666666666666666
#
# R Tewatia
# Runs :  350 	Matches :  22 	Balls :  267
# strike1 :  149.3827160493827 	strike_2 123.11827956989248 	index_1 11.0 	index_2 20.818181818181817
#
# MM Patel
# Runs :  0 	Matches :  1 	Balls :  1
# strike1 :  0.0 	strike_2 nan 	index_1 0.0 	index_2 nan
#
# TA Boult
# Runs :  12 	Matches :  5 	Balls :  15
# strike1 :  150.0 	strike_2 54.54545454545454 	index_1 3.0 	index_2 2.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# IR Jaggi
# Runs :  33 	Matches :  2 	Balls :  40
# strike1 :  87.5 	strike_2 62.5 	index_1 28.0 	index_2 5.0
#
# AS Rajpoot
# Runs :  24 	Matches :  6 	Balls :  35
# strike1 :  43.75 	strike_2 89.47368421052632 	index_1 2.3333333333333335 	index_2 5.666666666666667
#
# MM Ali
# Runs :  309 	Matches :  17 	Balls :  199
# strike1 :  170.44025157232704 	strike_2 95.0 	index_1 24.636363636363637 	index_2 6.333333333333333
#
# SO Hetmyer
# Runs :  275 	Matches :  16 	Balls :  203
# strike1 :  129.90654205607478 	strike_2 141.66666666666669 	index_1 13.9 	index_2 22.666666666666668
#
# S Dube
# Runs :  169 	Matches :  13 	Balls :  142
# strike1 :  120.0 	strike_2 117.3076923076923 	index_1 13.5 	index_2 12.2
#
# NA Saini
# Runs :  29 	Matches :  5 	Balls :  31
# strike1 :  91.66666666666666 	strike_2 94.73684210526315 	index_1 3.6666666666666665 	index_2 9.0
#
# Mohammed Siraj
# Runs :  46 	Matches :  9 	Balls :  52
# strike1 :  69.56521739130434 	strike_2 103.44827586206897 	index_1 3.2 	index_2 7.5
#
# JM Bairstow
# Runs :  790 	Matches :  21 	Balls :  576
# strike1 :  134.29752066115702 	strike_2 139.22155688622755 	index_1 36.111111111111114 	index_2 38.75
#
# Shubman Gill
# Runs :  939 	Matches :  37 	Balls :  766
# strike1 :  120.81545064377683 	strike_2 125.33333333333334 	index_1 24.47826086956522 	index_2 26.857142857142858
#
# PP Shaw
# Runs :  826 	Matches :  38 	Balls :  605
# strike1 :  138.50415512465375 	strike_2 133.60655737704917 	index_1 22.727272727272727 	index_2 20.375
#
# CA Ingram
# Runs :  184 	Matches :  12 	Balls :  157
# strike1 :  130.0 	strike_2 111.21495327102804 	index_1 16.25 	index_2 14.875
#
# KMA Paul
# Runs :  18 	Matches :  5 	Balls :  26
# strike1 :  59.09090909090909 	strike_2 125.0 	index_1 3.25 	index_2 5.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# Rasikh Salam
# Runs :  5 	Matches :  1 	Balls :  4
# strike1 :  nan 	strike_2 125.0 	index_1 nan 	index_2 5.0
#
# N Pooran
# Runs :  521 	Matches :  20 	Balls :  323
# strike1 :  142.02898550724638 	strike_2 175.67567567567568 	index_1 21.77777777777778 	index_2 29.545454545454547
#
# K Gowtham
# Runs :  186 	Matches :  19 	Balls :  113
# strike1 :  135.13513513513513 	strike_2 178.94736842105263 	index_1 6.25 	index_2 12.363636363636363
#
# JC Archer
# Runs :  195 	Matches :  21 	Balls :  128
# strike1 :  148.14814814814815 	strike_2 155.4054054054054 	index_1 8.88888888888889 	index_2 9.583333333333334
#
# M Markande
# Runs :  27 	Matches :  7 	Balls :  30
# strike1 :  135.29411764705884 	strike_2 30.76923076923077 	index_1 4.6 	index_2 2.0
#
# GH Vihari
# Runs :  4 	Matches :  2 	Balls :  8
# strike1 :  nan 	strike_2 50.0 	index_1 nan 	index_2 2.0
#
# P Ray Barman
# Runs :  19 	Matches :  1 	Balls :  25
# strike1 :  nan 	strike_2 76.0 	index_1 nan 	index_2 19.0
#
# SM Curran
# Runs :  281 	Matches :  19 	Balls :  200
# strike1 :  131.25 	strike_2 164.28571428571428 	index_1 21.0 	index_2 9.2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# GC Viljoen
# Runs :  3 	Matches :  3 	Balls :  7
# strike1 :  50.0 	strike_2 0.0 	index_1 1.5 	index_2 0.0
#
# HV Patel
# Runs :  81 	Matches :  5 	Balls :  61
# strike1 :  139.6551724137931 	strike_2 0.0 	index_1 20.25 	index_2 0.0
#
# Avesh Khan
# Runs :  4 	Matches :  1 	Balls :  3
# strike1 :  nan 	strike_2 133.33333333333331 	index_1 nan 	index_2 4.0
#
# S Lamichhane
# Runs :  0 	Matches :  1 	Balls :  1
# strike1 :  nan 	strike_2 0.0 	index_1 nan 	index_2 0.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# M Prasidh Krishna
# Runs :  3 	Matches :  4 	Balls :  11
# strike1 :  0.0 	strike_2 37.5 	index_1 0.0 	index_2 1.5
#
# HF Gurney
# Runs :  1 	Matches :  1 	Balls :  5
# strike1 :  20.0 	strike_2 nan 	index_1 1.0 	index_2 nan
#
# SD Lad
# Runs :  15 	Matches :  1 	Balls :  13
# strike1 :  nan 	strike_2 115.38461538461537 	index_1 nan 	index_2 15.0
#
# AS Joseph
# Runs :  15 	Matches :  1 	Balls :  13
# strike1 :  nan 	strike_2 115.38461538461537 	index_1 nan 	index_2 15.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# R Parag
# Runs :  246 	Matches :  13 	Balls :  214
# strike1 :  105.66037735849056 	strike_2 124.07407407407408 	index_1 18.666666666666668 	index_2 19.142857142857142
#
# MJ Santner
# Runs :  32 	Matches :  2 	Balls :  25
# strike1 :  nan 	strike_2 128.0 	index_1 nan 	index_2 16.0
#
# JL Denly
# Runs :  0 	Matches :  1 	Balls :  1
# strike1 :  0.0 	strike_2 nan 	index_1 0.0 	index_2 nan
#
# LS Livingstone
# Runs :  70 	Matches :  4 	Balls :  48
# strike1 :  107.6923076923077 	strike_2 160.0 	index_1 14.0 	index_2 18.666666666666668
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# RK Bhui
# Runs :  7 	Matches :  2 	Balls :  18
# strike1 :  nan 	strike_2 38.88888888888889 	index_1 nan 	index_2 3.5
#
# Abhishek Sharma
# Runs :  143 	Matches :  13 	Balls :  104
# strike1 :  152.0 	strike_2 100.0 	index_1 14.25 	index_2 5.8
#
# KK Ahmed
# Runs :  0 	Matches :  2 	Balls :  3
# strike1 :  nan 	strike_2 0.0 	index_1 nan 	index_2 0.0
#
# Mujeeb Ur Rahman
# Runs :  11 	Matches :  5 	Balls :  14
# strike1 :  0.0 	strike_2 100.0 	index_1 0.0 	index_2 3.6666666666666665
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# AJ Turner
# Runs :  3 	Matches :  4 	Balls :  11
# strike1 :  0.0 	strike_2 30.0 	index_1 0.0 	index_2 1.0
#
# E Lewis
# Runs :  430 	Matches :  16 	Balls :  343
# strike1 :  133.7719298245614 	strike_2 108.69565217391303 	index_1 27.727272727272727 	index_2 25.0
#
# MA Wood
# Runs :  1 	Matches :  1 	Balls :  5
# strike1 :  nan 	strike_2 20.0 	index_1 nan 	index_2 1.0
#
# RK Singh
# Runs :  77 	Matches :  8 	Balls :  79
# strike1 :  102.04081632653062 	strike_2 90.0 	index_1 10.0 	index_2 9.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# DJM Short
# Runs :  115 	Matches :  7 	Balls :  102
# strike1 :  94.36619718309859 	strike_2 154.83870967741936 	index_1 13.4 	index_2 24.0
#
# B Laughlin
# Runs :  1 	Matches :  2 	Balls :  4
# strike1 :  33.33333333333333 	strike_2 0.0 	index_1 1.0 	index_2 0.0
#
# TK Curran
# Runs :  106 	Matches :  8 	Balls :  91
# strike1 :  75.0 	strike_2 128.16901408450704 	index_1 3.75 	index_2 22.75
#
# B Stanlake
# Runs :  5 	Matches :  1 	Balls :  2
# strike1 :  nan 	strike_2 250.0 	index_1 nan 	index_2 5.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# A Dananjaya
# Runs :  4 	Matches :  1 	Balls :  5
# strike1 :  80.0 	strike_2 nan 	index_1 4.0 	index_2 nan
#
# Shivam Mavi
# Runs :  23 	Matches :  6 	Balls :  29
# strike1 :  77.77777777777779 	strike_2 80.0 	index_1 3.5 	index_2 4.0
#
# H Klaasen
# Runs :  66 	Matches :  6 	Balls :  58
# strike1 :  131.0344827586207 	strike_2 96.55172413793103 	index_1 19.0 	index_2 7.0
#
# LE Plunkett
# Runs :  1 	Matches :  2 	Balls :  3
# strike1 :  50.0 	strike_2 0.0 	index_1 1.0 	index_2 0.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# Mustafizur Rahman
# Runs :  1 	Matches :  1 	Balls :  3
# strike1 :  nan 	strike_2 33.33333333333333 	index_1 nan 	index_2 1.0
#
# AD Hales
# Runs :  148 	Matches :  6 	Balls :  119
# strike1 :  98.11320754716981 	strike_2 145.45454545454547 	index_1 17.333333333333332 	index_2 32.0
#
# MK Lomror
# Runs :  87 	Matches :  6 	Balls :  78
# strike1 :  125.49019607843137 	strike_2 85.18518518518519 	index_1 21.333333333333332 	index_2 7.666666666666667
#
# DR Shorey
# Runs :  13 	Matches :  2 	Balls :  20
# strike1 :  nan 	strike_2 65.0 	index_1 nan 	index_2 6.5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# P Chopra
# Runs :  8 	Matches :  1 	Balls :  6
# strike1 :  nan 	strike_2 133.33333333333331 	index_1 nan 	index_2 8.0
#
# JPR Scantlebury-Searles
# Runs :  8 	Matches :  2 	Balls :  6
# strike1 :  133.33333333333331 	strike_2 nan 	index_1 4.0 	index_2 nan
#
# IS Sodhi
# Runs :  7 	Matches :  2 	Balls :  18
# strike1 :  38.88888888888889 	strike_2 nan 	index_1 3.5 	index_2 nan
#
# SP Goswami
# Runs :  52 	Matches :  5 	Balls :  47
# strike1 :  123.80952380952381 	strike_2 0.0 	index_1 17.333333333333332 	index_2 0.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# Harpreet Brar
# Runs :  20 	Matches :  1 	Balls :  14
# strike1 :  142.85714285714286 	strike_2 nan 	index_1 20.0 	index_2 nan
#
# SE Rutherford
# Runs :  73 	Matches :  7 	Balls :  55
# strike1 :  152.0 	strike_2 116.66666666666667 	index_1 19.0 	index_2 7.0
#
# Y Prithvi Raj
# Runs :  0 	Matches :  1 	Balls :  1
# strike1 :  0.0 	strike_2 nan 	index_1 0.0 	index_2 nan
#
# P Simran Singh
# Runs :  31 	Matches :  3 	Balls :  33
# strike1 :  nan 	strike_2 93.93939393939394 	index_1 nan 	index_2 10.333333333333334
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# J Suchith
# Runs :  6 	Matches :  1 	Balls :  15
# strike1 :  nan 	strike_2 40.0 	index_1 nan 	index_2 6.0
#
# JL Pattinson
# Runs :  15 	Matches :  2 	Balls :  13
# strike1 :  115.38461538461537 	strike_2 nan 	index_1 7.5 	index_2 nan
#
# A Nortje
# Runs :  7 	Matches :  3 	Balls :  6
# strike1 :  300.0 	strike_2 80.0 	index_1 3.0 	index_2 2.0
#
# D Padikkal
# Runs :  473 	Matches :  15 	Balls :  398
# strike1 :  121.05263157894737 	strike_2 113.27433628318585 	index_1 34.5 	index_2 25.6
#
# JR Philippe
# Runs :  78 	Matches :  5 	Balls :  80
# strike1 :  101.29870129870129 	strike_2 0.0 	index_1 19.5 	index_2 0.0
#
# PK Garg
# Runs :  133 	Matches :  10 	Balls :  116
# strike1 :  183.33333333333331 	strike_2 83.75 	index_1 22.0 	index_2 9.571428571428571
#
# T Natarajan
# Runs :  3 	Matches :  2 	Balls :  5
# strike1 :  nan 	strike_2 60.0 	index_1 nan 	index_2 1.5
#
# YBK Jaiswal
# Runs :  40 	Matches :  3 	Balls :  44
# strike1 :  100.0 	strike_2 89.47368421052632 	index_1 6.0 	index_2 17.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# RD Gaikwad
# Runs :  204 	Matches :  6 	Balls :  173
# strike1 :  0.0 	strike_2 121.42857142857142 	index_1 0.0 	index_2 40.8
#
# KL Nagarkoti
# Runs :  22 	Matches :  6 	Balls :  32
# strike1 :  68.18181818181817 	strike_2 70.0 	index_1 3.75 	index_2 3.5
#
# Abdul Samad
# Runs :  111 	Matches :  7 	Balls :  66
# strike1 :  140.0 	strike_2 180.43478260869566 	index_1 9.333333333333334 	index_2 20.75
#
# JDS Neesham
# Runs :  19 	Matches :  3 	Balls :  18
# strike1 :  66.66666666666666 	strike_2 113.33333333333333 	index_1 2.0 	index_2 8.5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# Ravi Bishnoi
# Runs :  7 	Matches :  2 	Balls :  12
# strike1 :  nan 	strike_2 58.333333333333336 	index_1 nan 	index_2 3.5
#
# I Udana
# Runs :  15 	Matches :  4 	Balls :  11
# strike1 :  175.0 	strike_2 33.33333333333333 	index_1 4.666666666666667 	index_2 1.0
#
# CV Varun
# Runs :  10 	Matches :  3 	Balls :  16
# strike1 :  60.0 	strike_2 63.63636363636363 	index_1 1.5 	index_2 7.0
#
# SS Cottrell
# Runs :  0 	Matches :  1 	Balls :  2
# strike1 :  nan 	strike_2 0.0 	index_1 nan 	index_2 0.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# Arshdeep Singh
# Runs :  0 	Matches :  1 	Balls :  3
# strike1 :  nan 	strike_2 0.0 	index_1 nan 	index_2 0.0
#
# Kartik Tyagi
# Runs :  4 	Matches :  2 	Balls :  6
# strike1 :  nan 	strike_2 66.66666666666666 	index_1 nan 	index_2 2.0
#
# N Jagadeesan
# Runs :  33 	Matches :  2 	Balls :  31
# strike1 :  0.0 	strike_2 110.00000000000001 	index_1 0.0 	index_2 33.0
#
# AT Carey
# Runs :  32 	Matches :  3 	Balls :  29
# strike1 :  127.27272727272727 	strike_2 57.14285714285714 	index_1 14.0 	index_2 4.0
#
# T Banton
# Runs :  18 	Matches :  2 	Balls :  22
# strike1 :  125.0 	strike_2 57.14285714285714 	index_1 10.0 	index_2 8.0
#
# TU Deshpande
# Runs :  21 	Matches :  2 	Balls :  12
# strike1 :  nan 	strike_2 175.0 	index_1 nan 	index_2 10.5
#
# Shahbaz Ahmed
# Runs :  1 	Matches :  1 	Balls :  1
# strike1 :  100.0 	strike_2 nan 	index_1 1.0 	index_2 nan
#
# P Dubey
# Runs :  7 	Matches :  1 	Balls :  13
# strike1 :  53.84615384615385 	strike_2 nan 	index_1 7.0 	index_2 nan
#
# DR Sams
# Runs :  0 	Matches :  1 	Balls :  2
# strike1 :  nan 	strike_2 0.0 	index_1 nan 	index_2 0.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in long_scalars

# %%
batsmandata.fillna(0)
# Out:
#            batsman  runs  matches  ...    strike_2    index_1    index_2
# 0      LMP Simmons   145        8  ...  124.074074  15.600000  22.333333
# 1        RG Sharma  1845       71  ...  126.731302  23.250000  29.516129
# 2        HH Pandya  1237       66  ...  141.860465  20.243243  16.827586
# 3       JC Buttler  1714       57  ...  154.244032  25.045455  33.228571
# 4        AT Rayudu  1668       61  ...  116.647264  26.640000  27.833333
# ..             ...   ...      ...  ...         ...        ...        ...
# 262       T Banton    18        2  ...   57.142857  10.000000   8.000000
# 263   TU Deshpande    21        2  ...  175.000000   0.000000  10.500000
# 264  Shahbaz Ahmed     1        1  ...    0.000000   1.000000   0.000000
# 265        P Dubey     7        1  ...    0.000000   7.000000   0.000000
# 266        DR Sams     0        1  ...    0.000000   0.000000   0.000000
#
# [267 rows x 8 columns]

# %%
batsmandata = batsmandata.fillna(0)

# %%
batsmandata
# Out:
#            batsman  runs  matches  ...    strike_2    index_1    index_2
# 0      LMP Simmons   145        8  ...  124.074074  15.600000  22.333333
# 1        RG Sharma  1845       71  ...  126.731302  23.250000  29.516129
# 2        HH Pandya  1237       66  ...  141.860465  20.243243  16.827586
# 3       JC Buttler  1714       57  ...  154.244032  25.045455  33.228571
# 4        AT Rayudu  1668       61  ...  116.647264  26.640000  27.833333
# ..             ...   ...      ...  ...         ...        ...        ...
# 262       T Banton    18        2  ...   57.142857  10.000000   8.000000
# 263   TU Deshpande    21        2  ...  175.000000   0.000000  10.500000
# 264  Shahbaz Ahmed     1        1  ...    0.000000   1.000000   0.000000
# 265        P Dubey     7        1  ...    0.000000   7.000000   0.000000
# 266        DR Sams     0        1  ...    0.000000   0.000000   0.000000
#
# [267 rows x 8 columns]

# %%
import math
for bowler in bowler_list:
  wickets = len(indexdata[(indexdata['bowler']==bowler) & (indexdata['player_dismissed']!='notout')])
  matches = len(indexdata[indexdata['bowler']==bowler]['match_id'].unique())
  bowler_matches = list(indexdata[indexdata['bowler']==bowler]['match_id'].unique())
  match_stats = list()
  match_index = list()
  match_index2 = list()
  for bowlmatch in bowler_matches:
    match_wickets = len(indexdata[(indexdata['bowler']==bowler) & (indexdata['match_id']==bowlmatch) & (indexdata['player_dismissed']!='notout')])
    match_runs = indexdata[(indexdata['bowler']==bowler) & (indexdata['match_id']==bowlmatch)]['runs_off_bat'].sum() + indexdata[(indexdata['bowler']==bowler) & (indexdata['match_id']==bowlmatch)]['extras'].sum()
    balls = len(indexdata[(indexdata['bowler']==bowler) & (indexdata['match_id']==bowlmatch)])
    data = str(match_wickets)+'/'+str(match_runs)+'-'+str(math.ceil(balls/6))
    match_stats.append(data)
    match_index.append(match_runs/((math.ceil(balls/6))*(match_wickets+1)))
    match_index2.append(match_runs/math.ceil(balls/6))
  balls = len(indexdata[indexdata['bowler']==bowler])
  print(bowler,"\nWickets : ",wickets,'\tMatches : ',matches,'\tBalls : ',balls,'\nMatchStats : ',match_stats ,'\nMatchIndex : ',match_index,'\nAvgIndex',sum(match_index)/len(match_index),'\nAvgIndex2', (sum(match_index2)/len(match_index2) / (wickets+1/len(match_index2))))
  print("Economy rate : ",sum(match_index2)/len(match_index2),'\t Avgwicket/match : ',(wickets+1))
  bowlerdata = bowlerdata.append({'bowler':bowler,'wickets':wickets,'matches':matches,'balls':balls,'A1index':sum(match_index)/len(match_index),'A2index':(sum(match_index)/len(match_index) )/(len(match_index2) / (wickets+1/matches))}, ignore_index=True)
  print()
# Out:
# RP Singh
# Wickets :  3 	Matches :  4 	Balls :  76
# MatchStats :  ['1/30-4', '0/22-3', '1/39-5', '1/23-4']
# MatchIndex :  [3.75, 7.333333333333333, 3.9, 2.875]
# AvgIndex 4.464583333333334
# AvgIndex2 2.183333333333333
# Economy rate :  7.095833333333333 	 Avgwicket/match :  4
#
# I Sharma
# Wickets :  17 	Matches :  24 	Balls :  516
# MatchStats :  ['2/37-5', '1/41-4', '0/26-3', '0/47-5', '0/21-3', '0/25-5', '0/60-4', '0/42-4', '0/30-4', '0/12-1', '3/35-4', '1/32-3', '1/5-2', '0/32-5', '1/22-5', '0/19-4', '0/18-3', '0/29-5', '1/30-4', '1/41-4', '3/38-5', '2/35-4', '1/28-4', '0/26-4']
# MatchIndex :  [2.466666666666667, 5.125, 8.666666666666666, 9.4, 7.0, 5.0, 15.0, 10.5, 7.5, 12.0, 2.1875, 5.333333333333333, 1.25, 6.4, 2.2, 4.75, 6.0, 5.8, 3.75, 5.125, 1.9, 2.9166666666666665, 3.5, 6.5]
# AvgIndex 5.844618055555556
# AvgIndex2 0.4635289323553382
# Economy rate :  7.899305555555556 	 Avgwicket/match :  18
#
# MR Marsh
# Wickets :  4 	Matches :  4 	Balls :  59
# MatchStats :  ['2/21-5', '0/10-1', '2/14-4', '0/6-1']
# MatchIndex :  [1.4, 10.0, 1.1666666666666667, 6.0]
# AvgIndex 4.641666666666667
# AvgIndex2 1.3941176470588235
# Economy rate :  5.925 	 Avgwicket/match :  5
#
# R Bhatia
# Wickets :  8 	Matches :  13 	Balls :  251
# MatchStats :  ['1/10-4', '0/31-4', '0/22-3', '2/19-4', '0/24-4', '1/26-3', '0/21-3', '2/22-5', '0/47-4', '0/27-3', '2/14-3', '0/20-3', '0/21-2']
# MatchIndex :  [1.25, 7.75, 7.333333333333333, 1.5833333333333333, 6.0, 4.333333333333333, 7.0, 1.4666666666666666, 11.75, 9.0, 1.5555555555555556, 6.666666666666667, 10.5]
# AvgIndex 5.860683760683761
# AvgIndex2 0.8665079365079367
# Economy rate :  6.99871794871795 	 Avgwicket/match :  9
#
# M Ashwin
# Wickets :  25 	Matches :  31 	Balls :  623
# MatchStats :  ['1/16-4', '2/34-5', '3/36-4', '0/29-2', '1/32-5', '0/6-1', '0/22-3', '0/25-3', '0/32-3', '0/13-2', '2/26-4', '0/19-2', '0/23-5', '0/24-4', '1/24-5', '2/37-5', '1/17-4', '0/21-4', '1/31-4', '1/32-5', '0/24-2', '0/33-3', '3/22-4', '1/16-2', '2/23-4', '0/32-3', '1/33-5', '1/27-4', '1/27-4', '1/43-4', '0/17-4']
# MatchIndex :  [2.0, 2.2666666666666666, 2.25, 14.5, 3.2, 6.0, 7.333333333333333, 8.333333333333334, 10.666666666666666, 6.5, 2.1666666666666665, 9.5, 4.6, 6.0, 2.4, 2.466666666666667, 2.125, 5.25, 3.875, 3.2, 12.0, 11.0, 1.375, 4.0, 1.9166666666666667, 10.666666666666666, 3.3, 3.375, 3.375, 5.375, 4.25]
# AvgIndex 5.331182795698925
# AvgIndex2 0.29639175257731953
# Economy rate :  7.419354838709676 	 Avgwicket/match :  26
#
# R Ashwin
# Wickets :  54 	Matches :  57 	Balls :  1246
# MatchStats :  ['1/7-1', '0/26-5', '0/27-4', '0/22-4', '0/21-3', '1/15-4', '0/37-5', '1/21-3', '1/34-5', '0/7-1', '1/16-5', '2/31-3', '0/23-5', '4/34-4', '2/20-4', '0/47-5', '0/26-5', '2/31-5', '3/23-5', '2/30-4', '1/37-4', '1/30-5', '2/24-5', '1/23-5', '2/30-4', '1/33-5', '0/53-5', '1/33-5', '1/19-4', '0/34-4', '0/23-4', '1/30-4', '0/34-4', '0/36-3', '0/9-1', '2/18-3', '2/36-5', '0/26-4', '1/15-4', '2/30-5', '1/38-5', '0/23-4', '2/2-1', '0/26-3', '1/26-5', '2/22-5', '1/35-4', '1/17-4', '0/30-3', '2/28-5', '0/45-3', '1/35-3', '1/18-4', '0/18-4', '3/29-4', '0/34-4', '1/28-4']
# MatchIndex :  [3.5, 5.2, 6.75, 5.5, 7.0, 1.875, 7.4, 3.5, 3.4, 7.0, 1.6, 3.4444444444444446, 4.6, 1.7, 1.6666666666666667, 9.4, 5.2, 2.066666666666667, 1.15, 2.5, 4.625, 3.0, 1.6, 2.3, 2.5, 3.3, 10.6, 3.3, 2.375, 8.5, 5.75, 3.75, 8.5, 12.0, 9.0, 2.0, 2.4, 6.5, 1.875, 2.0, 3.8, 5.75, 0.6666666666666666, 8.666666666666666, 2.6, 1.4666666666666666, 4.375, 2.125, 10.0, 1.8666666666666667, 15.0, 5.833333333333333, 2.25, 4.5, 1.8125, 8.5, 3.5]
# AvgIndex 4.61474171539961
# AvgIndex2 0.12665367543574754
# Economy rate :  6.841520467836258 	 Avgwicket/match :  55
#
# MJ McClenaghan
# Wickets :  57 	Matches :  44 	Balls :  1041
# MatchStats :  ['0/27-3', '2/25-5', '4/26-4', '0/33-4', '1/48-4', '2/32-5', '2/32-5', '1/33-4', '1/27-5', '1/39-5', '1/37-5', '2/24-4', '1/27-4', '0/39-4', '1/36-4', '1/52-5', '1/42-4', '2/20-5', '2/24-5', '2/47-5', '3/25-5', '0/37-5', '0/50-5', '4/34-4', '1/18-2', '1/26-5', '1/54-5', '1/47-5', '3/40-4', '0/24-2', '0/35-5', '1/44-5', '2/24-3', '1/32-4', '3/26-4', '2/26-4', '2/35-5', '1/31-5', '1/30-4', '1/24-3', '0/29-5', '2/39-5', '0/20-5', '0/24-5']
# MatchIndex :  [9.0, 1.6666666666666667, 1.3, 8.25, 6.0, 2.1333333333333333, 2.1333333333333333, 4.125, 2.7, 3.9, 3.7, 2.0, 3.375, 9.75, 4.5, 5.2, 5.25, 1.3333333333333333, 1.6, 3.1333333333333333, 1.25, 7.4, 10.0, 1.7, 4.5, 2.6, 5.4, 4.7, 2.5, 12.0, 7.0, 4.4, 2.6666666666666665, 4.0, 1.625, 2.1666666666666665, 2.3333333333333335, 3.1, 3.75, 4.0, 5.8, 2.6, 4.0, 4.8]
# AvgIndex 4.212310606060607
# AvgIndex2 0.13399760860900758
# Economy rate :  7.6409090909090915 	 Avgwicket/match :  58
#
# JJ Bumrah
# Wickets :  107 	Matches :  75 	Balls :  1770
# MatchStats :  ['0/30-4', '1/32-4', '2/32-5', '0/19-4', '4/31-4', '0/42-5', '3/27-4', '0/35-4', '3/30-4', '0/35-4', '1/30-4', '0/14-3', '3/14-4', '1/42-5', '0/29-4', '1/39-5', '3/24-4', '1/40-5', '0/46-5', '1/31-5', '2/21-5', '2/30-4', '3/32-5', '1/34-4', '1/6-1', '1/24-4', '1/25-4', '1/34-4', '3/7-3', '2/27-4', '1/41-4', '4/21-5', '0/23-4', '0/28-5', '1/16-3', '1/39-5', '2/24-4', '0/24-4', '1/37-5', '2/32-4', '0/27-4', '2/29-5', '2/28-5', '1/25-4', '0/26-5', '1/22-4', '1/20-4', '1/42-4', '1/17-3', '1/34-4', '3/15-5', '1/29-5', '3/19-4', '1/22-4', '2/11-4', '0/45-5', '2/31-4', '2/31-5', '0/31-5', '2/19-4', '1/43-5', '2/34-5', '0/48-5', '2/19-4', '2/44-5', '4/20-4', '0/26-4', '1/22-5', '3/24-5', '2/26-4', '0/40-5', '3/14-5', '4/17-5', '4/14-5', '0/29-4']
# MatchIndex :  [7.5, 4.0, 2.1333333333333333, 4.75, 1.55, 8.4, 1.6875, 8.75, 1.875, 8.75, 3.75, 4.666666666666667, 0.875, 4.2, 7.25, 3.9, 1.5, 4.0, 9.2, 3.1, 1.4, 2.5, 1.6, 4.25, 3.0, 3.0, 3.125, 4.25, 0.5833333333333334, 2.25, 5.125, 0.84, 5.75, 5.6, 2.6666666666666665, 3.9, 2.0, 6.0, 3.7, 2.6666666666666665, 6.75, 1.9333333333333333, 1.8666666666666667, 3.125, 5.2, 2.75, 2.5, 5.25, 2.8333333333333335, 4.25, 0.75, 2.9, 1.1875, 2.75, 0.9166666666666666, 9.0, 2.5833333333333335, 2.066666666666667, 6.2, 1.5833333333333333, 4.3, 2.2666666666666666, 9.6, 1.5833333333333333, 2.933333333333333, 1.0, 6.5, 2.2, 1.2, 2.1666666666666665, 8.0, 0.7, 0.68, 0.56, 7.25]
# AvgIndex 3.6450666666666667
# AvgIndex2 0.06009220034886619
# Economy rate :  6.430666666666667 	 Avgwicket/match :  108
#
# R Vinay Kumar
# Wickets :  8 	Matches :  6 	Balls :  102
# MatchStats :  ['0/14-3', '2/33-4', '2/18-3', '2/31-4', '2/30-2', '0/35-3']
# MatchIndex :  [4.666666666666667, 2.75, 2.0, 2.5833333333333335, 5.0, 11.666666666666666]
# AvgIndex 4.777777777777778
# AvgIndex2 1.08843537414966
# Economy rate :  8.88888888888889 	 Avgwicket/match :  9
#
# S Gopal
# Wickets :  42 	Matches :  39 	Balls :  800
# MatchStats :  ['0/19-3', '0/5-1', '3/27-4', '0/23-3', '3/12-4', '2/36-4', '0/31-4', '0/21-4', '0/32-4', '0/18-3', '2/24-4', '1/24-3', '3/20-5', '0/30-3', '1/26-2', '0/26-3', '0/21-2', '4/16-4', '1/34-4', '2/21-4', '2/47-5', '1/32-3', '2/30-4', '3/12-1', '2/21-4', '1/38-4', '0/44-5', '0/43-4', '1/27-4', '2/29-4', '0/23-2', '0/31-4', '1/31-5', '1/33-5', '1/14-4', '0/32-4', '2/30-4', '0/10-1', '1/44-4']
# MatchIndex :  [6.333333333333333, 5.0, 1.6875, 7.666666666666667, 0.75, 3.0, 7.75, 5.25, 8.0, 6.0, 2.0, 4.0, 1.0, 10.0, 6.5, 8.666666666666666, 10.5, 0.8, 4.25, 1.75, 3.1333333333333333, 5.333333333333333, 2.5, 3.0, 1.75, 4.75, 8.8, 10.75, 3.375, 2.4166666666666665, 11.5, 7.75, 3.1, 3.3, 1.75, 8.0, 2.5, 10.0, 5.5]
# AvgIndex 5.131089743589744
# AvgIndex2 0.1846146023998373
# Economy rate :  7.758547008547009 	 Avgwicket/match :  43
#
# Harbhajan Singh
# Wickets :  42 	Matches :  48 	Balls :  1009
# MatchStats :  ['1/24-3', '1/33-4', '0/20-2', '0/39-5', '0/20-3', '1/25-3', '0/31-4', '1/32-4', '1/25-5', '2/29-5', '0/19-3', '0/35-4', '1/34-4', '1/36-4', '0/27-4', '2/24-4', '0/25-4', '1/22-4', '0/12-2', '0/26-4', '1/20-4', '1/23-5', '3/22-4', '0/23-4', '0/45-3', '4/22-4', '0/30-5', '2/17-4', '3/15-4', '0/14-2', '1/11-2', '1/41-4', '0/24-2', '1/20-4', '0/26-5', '1/20-3', '2/22-4', '1/29-2', '0/26-3', '0/24-2', '0/13-1', '2/39-4', '0/23-4', '1/28-4', '3/58-5', '1/25-5', '2/31-4', '0/27-5']
# MatchIndex :  [4.0, 4.125, 10.0, 7.8, 6.666666666666667, 4.166666666666667, 7.75, 4.0, 2.5, 1.9333333333333333, 6.333333333333333, 8.75, 4.25, 4.5, 6.75, 2.0, 6.25, 2.75, 6.0, 6.5, 2.5, 2.3, 1.375, 5.75, 15.0, 1.1, 6.0, 1.4166666666666667, 0.9375, 7.0, 2.75, 5.125, 12.0, 2.5, 5.2, 3.3333333333333335, 1.8333333333333333, 7.25, 8.666666666666666, 12.0, 13.0, 3.25, 5.75, 3.5, 2.9, 2.5, 2.5833333333333335, 5.4]
# AvgIndex 5.207204861111111
# AvgIndex2 0.17752437613617583
# Economy rate :  7.459722222222222 	 Avgwicket/match :  43
#
# HH Pandya
# Wickets :  44 	Matches :  52 	Balls :  807
# MatchStats :  ['0/12-1', '1/22-3', '0/17-3', '0/29-3', '0/19-2', '1/7-1', '1/15-2', '0/14-3', '0/10-1', '0/10-2', '1/37-4', '1/24-4', '1/9-2', '0/15-1', '0/19-2', '1/25-4', '0/5-1', '0/2-1', '0/13-1', '0/29-3', '2/22-4', '0/15-1', '0/4-1', '1/42-5', '0/38-3', '0/39-4', '3/24-5', '0/7-1', '2/57-5', '0/11-2', '1/22-3', '3/24-5', '0/32-2', '0/4-1', '2/25-3', '2/20-4', '1/40-4', '3/28-4', '1/48-5', '2/19-5', '3/16-3', '2/52-4', '0/43-5', '0/40-5', '1/17-2', '1/31-4', '1/22-3', '1/31-4', '2/20-2', '2/20-3', '0/13-2', '1/3-2']
# MatchIndex :  [12.0, 3.6666666666666665, 5.666666666666667, 9.666666666666666, 9.5, 3.5, 3.75, 4.666666666666667, 10.0, 5.0, 4.625, 3.0, 2.25, 15.0, 9.5, 3.125, 5.0, 2.0, 13.0, 9.666666666666666, 1.8333333333333333, 15.0, 4.0, 4.2, 12.666666666666666, 9.75, 1.2, 7.0, 3.8, 5.5, 3.6666666666666665, 1.2, 16.0, 4.0, 2.7777777777777777, 1.6666666666666667, 5.0, 1.75, 4.8, 1.2666666666666666, 1.3333333333333333, 4.333333333333333, 8.6, 8.0, 4.25, 3.875, 3.6666666666666665, 3.875, 3.3333333333333335, 2.2222222222222223, 6.5, 0.75]
# AvgIndex 5.623076923076923
# AvgIndex2 0.1788189893694481
# Economy rate :  7.871474358974359 	 Avgwicket/match :  45
#
# AD Russell
# Wickets :  50 	Matches :  46 	Balls :  759
# MatchStats :  ['3/24-4', '1/52-4', '2/21-4', '0/18-1', '0/16-2', '0/28-3', '4/27-4', '1/24-5', '6/25-5', '1/21-4', '1/12-2', '0/33-3', '2/32-3', '2/21-3', '1/28-3', '0/16-1', '1/29-3', '0/16-1', '0/10-2', '0/35-4', '0/39-3', '1/25-3', '0/31-2', '1/28-4', '3/31-4', '0/12-2', '2/12-3', '0/16-3', '3/42-4', '2/13-3', '1/35-4', '0/22-3', '0/9-1', '1/17-3', '0/8-1', '1/32-3', '2/25-4', '1/30-4', '0/34-3', '1/17-2', '2/18-3', '2/29-4', '1/18-2', '1/51-5', '0/15-2', '0/30-3']
# MatchIndex :  [1.5, 6.5, 1.75, 18.0, 8.0, 9.333333333333334, 1.35, 2.4, 0.7142857142857143, 2.625, 3.0, 11.0, 3.5555555555555554, 2.3333333333333335, 4.666666666666667, 16.0, 4.833333333333333, 16.0, 5.0, 8.75, 13.0, 4.166666666666667, 15.5, 3.5, 1.9375, 6.0, 1.3333333333333333, 5.333333333333333, 2.625, 1.4444444444444444, 4.375, 7.333333333333333, 9.0, 2.8333333333333335, 8.0, 5.333333333333333, 2.0833333333333335, 3.75, 11.333333333333334, 4.25, 2.0, 2.4166666666666665, 4.5, 5.1, 7.5, 10.0]
# AvgIndex 5.912176501035198
# AvgIndex2 0.17188179052585834
# Economy rate :  8.597826086956522 	 Avgwicket/match :  51
#
# UT Yadav
# Wickets :  60 	Matches :  50 	Balls :  1082
# MatchStats :  ['0/21-3', '3/28-5', '2/17-3', '1/21-2', '1/19-3', '3/38-3', '2/56-5', '0/28-4', '0/18-2', '4/33-5', '0/29-4', '1/53-4', '1/18-2', '1/17-3', '1/29-4', '1/39-5', '0/31-4', '1/28-4', '3/36-5', '1/27-4', '1/44-4', '2/21-5', '1/27-3', '0/13-4', '2/26-5', '0/47-4', '0/40-4', '0/42-5', '0/25-3', '2/28-5', '3/23-4', '0/59-5', '2/37-5', '1/27-4', '1/23-4', '0/36-4', '2/31-5', '2/16-3', '1/36-5', '0/29-4', '3/23-4', '0/31-4', '3/25-4', '3/51-5', '3/36-5', '1/39-4', '0/10-1', '0/46-5', '1/49-5', '0/37-4']
# MatchIndex :  [7.0, 1.4, 1.8888888888888888, 5.25, 3.1666666666666665, 3.1666666666666665, 3.7333333333333334, 7.0, 9.0, 1.32, 7.25, 6.625, 4.5, 2.8333333333333335, 3.625, 3.9, 7.75, 3.5, 1.8, 3.375, 5.5, 1.4, 4.5, 3.25, 1.7333333333333334, 11.75, 10.0, 8.4, 8.333333333333334, 1.8666666666666667, 1.4375, 11.8, 2.466666666666667, 3.375, 2.875, 9.0, 2.066666666666667, 1.7777777777777777, 3.6, 7.25, 1.4375, 7.75, 1.5625, 2.55, 1.8, 4.875, 10.0, 9.2, 4.9, 9.25]
# AvgIndex 4.875816666666668
# AvgIndex2 0.13155614795068307
# Economy rate :  7.895999999999998 	 Avgwicket/match :  61
#
# JW Hastings
# Wickets :  2 	Matches :  2 	Balls :  42
# MatchStats :  ['2/6-3', '0/31-5']
# MatchIndex :  [0.6666666666666666, 6.2]
# AvgIndex 3.4333333333333336
# AvgIndex2 1.64
# Economy rate :  4.1 	 Avgwicket/match :  3
#
# C Munro
# Wickets :  0 	Matches :  2 	Balls :  12
# MatchStats :  ['0/7-1', '0/8-1']
# MatchIndex :  [7.0, 8.0]
# AvgIndex 7.5
# AvgIndex2 15.0
# Economy rate :  7.5 	 Avgwicket/match :  1
#
# GB Hogg
# Wickets :  5 	Matches :  5 	Balls :  98
# MatchStats :  ['3/19-5', '1/39-5', '0/39-4', '0/28-2', '1/19-2']
# MatchIndex :  [0.95, 3.9, 9.75, 14.0, 4.75]
# AvgIndex 6.67
# AvgIndex2 1.725
# Economy rate :  8.97 	 Avgwicket/match :  6
#
# PP Chawla
# Wickets :  49 	Matches :  52 	Balls :  1029
# MatchStats :  ['2/21-5', '1/29-4', '0/13-1', '1/18-4', '0/26-3', '0/24-3', '2/32-4', '2/27-5', '2/30-4', '2/21-4', '0/32-4', '1/33-5', '1/36-3', '1/36-4', '0/13-2', '1/27-3', '2/34-5', '1/23-3', '1/27-3', '1/36-4', '0/32-4', '0/19-4', '1/28-4', '0/35-3', '2/32-4', '1/31-4', '1/49-5', '1/20-4', '1/17-3', '1/18-4', '0/24-2', '1/33-4', '0/22-3', '2/39-4', '0/35-3', '3/49-4', '0/16-2', '0/19-2', '2/24-4', '1/23-3', '0/10-1', '0/38-3', '3/20-4', '1/62-4', '0/43-4', '1/21-5', '1/55-5', '2/33-4', '2/20-3', '1/22-2', '0/8-1', '0/32-3']
# MatchIndex :  [1.4, 3.625, 13.0, 2.25, 8.666666666666666, 8.0, 2.6666666666666665, 1.8, 2.5, 1.75, 8.0, 3.3, 6.0, 4.5, 6.5, 4.5, 2.2666666666666666, 3.8333333333333335, 4.5, 4.5, 8.0, 4.75, 3.5, 11.666666666666666, 2.6666666666666665, 3.875, 4.9, 2.5, 2.8333333333333335, 2.25, 12.0, 4.125, 7.333333333333333, 3.25, 11.666666666666666, 3.0625, 8.0, 9.5, 2.0, 3.8333333333333335, 10.0, 12.666666666666666, 1.25, 7.75, 10.75, 2.1, 5.5, 2.75, 2.2222222222222223, 5.5, 8.0, 10.666666666666666]
# AvgIndex 5.469738247863249
# AvgIndex2 0.17009938537988756
# Economy rate :  8.338141025641026 	 Avgwicket/match :  50
#
# NM Coulter-Nile
# Wickets :  26 	Matches :  19 	Balls :  436
# MatchStats :  ['0/32-4', '2/29-5', '0/21-4', '2/38-4', '3/22-5', '2/41-4', '3/22-4', '3/34-4', '1/35-5', '0/41-4', '3/22-4', '1/15-3', '1/51-5', '0/33-4', '1/25-5', '1/14-2', '0/27-5', '0/27-5', '3/29-5']
# MatchIndex :  [8.0, 1.9333333333333333, 5.25, 3.1666666666666665, 1.1, 3.4166666666666665, 1.375, 2.125, 3.5, 10.25, 1.375, 2.5, 5.1, 8.25, 2.5, 3.5, 5.4, 5.4, 1.45]
# AvgIndex 3.9785087719298255
# AvgIndex2 0.2666666666666667
# Economy rate :  6.947368421052633 	 Avgwicket/match :  27
#
# Z Khan
# Wickets :  24 	Matches :  23 	Balls :  517
# MatchStats :  ['0/24-3', '1/14-4', '1/50-4', '2/30-5', '0/48-4', '4/21-4', '1/27-5', '1/25-3', '1/27-5', '0/19-4', '0/26-4', '1/30-5', '3/31-5', '3/20-4', '0/38-4', '2/29-4', '0/37-4', '0/37-5', '0/9-2', '0/30-4', '0/35-4', '2/25-5', '2/32-5']
# MatchIndex :  [8.0, 1.75, 6.25, 2.0, 12.0, 1.05, 2.7, 4.166666666666667, 2.7, 4.75, 6.5, 3.0, 1.55, 1.25, 9.5, 2.4166666666666665, 9.25, 7.4, 4.5, 7.5, 8.75, 1.6666666666666667, 2.1333333333333333]
# AvgIndex 4.816666666666667
# AvgIndex2 0.29002411091018687
# Economy rate :  6.973188405797102 	 Avgwicket/match :  25
#
# CH Morris
# Wickets :  58 	Matches :  43 	Balls :  960
# MatchStats :  ['0/21-5', '1/20-5', '0/30-4', '2/27-5', '2/35-5', '2/20-3', '1/33-5', '2/35-5', '2/19-5', '2/36-4', '1/13-3', '1/31-4', '3/22-4', '1/19-3', '3/23-5', '1/30-4', '4/26-4', '2/33-5', '0/39-3', '0/13-2', '0/36-4', '1/39-4', '3/30-5', '0/30-3', '2/28-5', '2/38-5', '3/22-3', '1/25-3', '0/35-3', '2/45-5', '0/43-5', '0/39-4', '1/41-5', '1/47-5', '3/19-4', '2/17-4', '0/22-5', '4/26-5', '1/17-5', '1/36-4', '1/36-5', '0/19-3', '0/20-2']
# MatchIndex :  [4.2, 2.0, 7.5, 1.8, 2.3333333333333335, 2.2222222222222223, 3.3, 2.3333333333333335, 1.2666666666666666, 3.0, 2.1666666666666665, 3.875, 1.375, 3.1666666666666665, 1.15, 3.75, 1.3, 2.2, 13.0, 6.5, 9.0, 4.875, 1.5, 10.0, 1.8666666666666667, 2.533333333333333, 1.8333333333333333, 4.166666666666667, 11.666666666666666, 3.0, 8.6, 9.75, 4.1, 4.7, 1.1875, 1.4166666666666667, 4.4, 1.04, 1.7, 4.5, 3.6, 6.333333333333333, 10.0]
# AvgIndex 4.190885012919896
# AvgIndex2 0.12206412825651297
# Economy rate :  7.082558139534881 	 Avgwicket/match :  59
#
# CR Brathwaite
# Wickets :  16 	Matches :  16 	Balls :  266
# MatchStats :  ['0/11-3', '1/33-4', '1/19-2', '3/47-5', '0/17-2', '0/20-2', '3/27-5', '1/18-4', '0/29-3', '1/38-5', '0/13-1', '2/22-3', '1/32-4', '2/15-2', '1/27-3', '0/16-3']
# MatchIndex :  [3.6666666666666665, 4.125, 4.75, 2.35, 8.5, 10.0, 1.35, 2.25, 9.666666666666666, 3.8, 13.0, 2.4444444444444446, 4.0, 2.5, 4.5, 5.333333333333333]
# AvgIndex 5.139756944444444
# AvgIndex2 0.4928015564202334
# Economy rate :  7.915624999999999 	 Avgwicket/match :  17
#
# A Mishra
# Wickets :  51 	Matches :  52 	Balls :  1051
# MatchStats :  ['1/11-3', '4/11-4', '0/30-3', '2/25-4', '0/27-3', '1/37-5', '1/19-3', '1/28-5', '0/37-5', '2/19-3', '1/42-4', '0/10-2', '1/21-3', '0/33-4', '0/32-2', '3/11-3', '1/16-3', '1/26-3', '0/33-3', '2/19-5', '0/36-3', '0/9-1', '1/23-5', '0/23-2', '1/38-4', '1/27-2', '0/26-4', '0/26-2', '2/36-5', '1/36-5', '0/13-3', '0/46-4', '0/33-5', '3/24-4', '1/30-4', '1/12-2', '2/19-5', '0/29-3', '1/33-5', '2/20-4', '3/19-4', '1/18-3', '0/41-4', '0/28-3', '2/29-5', '0/16-3', '3/17-4', '1/16-4', '1/21-4', '0/23-4', '2/35-4', '1/14-3']
# MatchIndex :  [1.8333333333333333, 0.55, 10.0, 2.0833333333333335, 9.0, 3.7, 3.1666666666666665, 2.8, 7.4, 2.111111111111111, 5.25, 5.0, 3.5, 8.25, 16.0, 0.9166666666666666, 2.6666666666666665, 4.333333333333333, 11.0, 1.2666666666666666, 12.0, 9.0, 2.3, 11.5, 4.75, 6.75, 6.5, 13.0, 2.4, 3.6, 4.333333333333333, 11.5, 6.6, 1.5, 3.75, 3.0, 1.2666666666666666, 9.666666666666666, 3.3, 1.6666666666666667, 1.1875, 3.0, 10.25, 9.333333333333334, 1.9333333333333333, 5.333333333333333, 1.0625, 2.0, 2.625, 5.75, 2.9166666666666665, 2.3333333333333335]
# AvgIndex 5.133386752136753
# AvgIndex2 0.14288855383842192
# Economy rate :  7.290064102564103 	 Avgwicket/match :  52
#
# P Kumar
# Wickets :  16 	Matches :  22 	Balls :  427
# MatchStats :  ['0/25-4', '0/12-2', '0/20-4', '0/31-3', '0/28-3', '0/14-4', '1/37-4', '2/25-3', '0/20-3', '1/28-5', '2/19-4', '2/46-4', '0/12-3', '2/24-4', '0/34-4', '0/33-4', '0/13-2', '1/16-2', '1/51-5', '1/25-4', '1/24-2', '2/25-5']
# MatchIndex :  [6.25, 6.0, 5.0, 10.333333333333334, 9.333333333333334, 3.5, 4.625, 2.7777777777777777, 6.666666666666667, 2.8, 1.5833333333333333, 3.8333333333333335, 4.0, 2.0, 8.5, 8.25, 6.5, 4.0, 5.1, 3.125, 6.0, 1.6666666666666667]
# AvgIndex 5.083838383838384
# AvgIndex2 0.4567044381491973
# Economy rate :  7.328030303030303 	 Avgwicket/match :  17
#
# PJ Sangwan
# Wickets :  6 	Matches :  8 	Balls :  147
# MatchStats :  ['0/21-2', '0/28-3', '2/38-5', '1/45-5', '1/28-3', '2/35-3', '0/37-4', '0/20-2']
# MatchIndex :  [10.5, 9.333333333333334, 2.533333333333333, 4.5, 4.666666666666667, 3.888888888888889, 9.25, 10.0]
# AvgIndex 6.834027777777778
# AvgIndex2 1.564965986394558
# Economy rate :  9.585416666666667 	 Avgwicket/match :  7
#
# JP Faulkner
# Wickets :  11 	Matches :  15 	Balls :  267
# MatchStats :  ['0/40-5', '0/15-2', '1/40-5', '1/23-2', '0/22-2', '0/19-2', '0/9-1', '1/39-4', '2/20-3', '2/34-4', '1/31-3', '0/38-3', '0/43-4', '3/39-4', '0/24-2']
# MatchIndex :  [8.0, 7.5, 4.0, 5.75, 11.0, 9.5, 9.0, 4.875, 2.2222222222222223, 2.8333333333333335, 5.166666666666667, 12.666666666666666, 10.75, 2.4375, 12.0]
# AvgIndex 7.180092592592593
# AvgIndex2 0.8729919678714861
# Economy rate :  9.661111111111113 	 Avgwicket/match :  12
#
# S Ladda
# Wickets :  0 	Matches :  1 	Balls :  12
# MatchStats :  ['0/21-2']
# MatchIndex :  [10.5]
# AvgIndex 10.5
# AvgIndex2 10.5
# Economy rate :  10.5 	 Avgwicket/match :  1
#
# RA Jadeja
# Wickets :  47 	Matches :  69 	Balls :  1273
# MatchStats :  ['2/32-5', '2/19-4', '0/20-3', '0/18-3', '0/14-1', '0/39-5', '2/29-4', '1/21-3', '0/14-2', '0/26-3', '0/35-4', '0/17-2', '0/15-1', '2/21-4', '1/40-4', '0/34-4', '0/57-4', '0/32-4', '1/33-4', '2/29-4', '0/11-1', '0/19-2', '1/28-2', '0/19-3', '0/31-4', '0/19-3', '2/16-4', '1/24-4', '0/23-2', '1/10-2', '0/24-4', '1/17-5', '2/20-4', '0/49-5', '0/22-4', '0/9-1', '1/19-2', '0/6-1', '0/28-5', '0/26-2', '2/32-5', '1/39-5', '3/18-4', '1/28-4', '0/24-2', '1/19-4', '1/24-3', '1/13-4', '1/25-2', '2/29-4', '0/33-4', '3/9-3', '1/16-2', '0/19-4', '2/24-3', '0/12-2', '2/42-4', '0/40-5', '0/44-4', '0/16-2', '1/30-4', '0/7-2', '1/21-3', '0/35-2', '0/11-2', '0/15-1', '0/20-3', '1/20-3', '1/17-3']
# MatchIndex :  [2.1333333333333333, 1.5833333333333333, 6.666666666666667, 6.0, 14.0, 7.8, 2.4166666666666665, 3.5, 7.0, 8.666666666666666, 8.75, 8.5, 15.0, 1.75, 5.0, 8.5, 14.25, 8.0, 4.125, 2.4166666666666665, 11.0, 9.5, 7.0, 6.333333333333333, 7.75, 6.333333333333333, 1.3333333333333333, 3.0, 11.5, 2.5, 6.0, 1.7, 1.6666666666666667, 9.8, 5.5, 9.0, 4.75, 6.0, 5.6, 13.0, 2.1333333333333333, 3.9, 1.125, 3.5, 12.0, 2.375, 4.0, 1.625, 6.25, 2.4166666666666665, 8.25, 0.75, 4.0, 4.75, 2.6666666666666665, 6.0, 3.5, 8.0, 11.0, 8.0, 3.75, 3.5, 3.5, 17.5, 5.5, 15.0, 6.666666666666667, 3.3333333333333335, 2.8333333333333335]
# AvgIndex 6.1326086956521735
# AvgIndex2 0.1687577065351418
# Economy rate :  7.934057971014492 	 Avgwicket/match :  48
#
# DJ Bravo
# Wickets :  57 	Matches :  49 	Balls :  1084
# MatchStats :  ['4/22-5', '1/43-4', '2/39-5', '0/27-3', '0/43-5', '1/40-5', '2/40-5', '2/33-4', '2/14-3', '0/39-5', '0/46-4', '1/29-5', '2/25-5', '0/30-4', '2/32-4', '1/0-1', '3/33-5', '2/33-5', '1/49-5', '0/26-4', '0/50-3', '1/37-4', '2/16-3', '1/37-3', '4/33-5', '1/22-4', '0/43-4', '0/23-2', '1/17-2', '2/31-4', '1/39-5', '0/53-5', '2/40-4', '2/25-5', '1/46-5', '2/34-4', '0/35-5', '0/35-5', '1/18-3', '0/31-5', '0/25-3', '2/19-5', '1/24-4', '0/28-5', '0/38-5', '4/37-5', '0/29-4', '2/25-3', '1/23-4']
# MatchIndex :  [0.88, 5.375, 2.6, 9.0, 8.6, 4.0, 2.6666666666666665, 2.75, 1.5555555555555556, 7.8, 11.5, 2.9, 1.6666666666666667, 7.5, 2.6666666666666665, 0.0, 1.65, 2.2, 4.9, 6.5, 16.666666666666668, 4.625, 1.7777777777777777, 6.166666666666667, 1.32, 2.75, 10.75, 11.5, 4.25, 2.5833333333333335, 3.9, 10.6, 3.3333333333333335, 1.6666666666666667, 4.6, 2.8333333333333335, 7.0, 7.0, 3.0, 6.2, 8.333333333333334, 1.2666666666666666, 3.0, 5.6, 7.6, 1.48, 7.25, 2.7777777777777777, 2.875]
# AvgIndex 4.886043083900227
# AvgIndex2 0.1346158434741112
# Economy rate :  7.675850340136055 	 Avgwicket/match :  58
#
# Sandeep Sharma
# Wickets :  77 	Matches :  63 	Balls :  1464
# MatchStats :  ['1/21-3', '1/6-2', '2/24-5', '0/25-2', '2/30-4', '1/20-5', '1/31-5', '2/25-5', '1/38-4', '3/49-5', '2/11-4', '1/36-4', '1/29-3', '1/29-5', '2/33-4', '1/26-5', '0/28-4', '1/41-4', '1/38-4', '0/39-4', '2/40-4', '4/20-5', '3/22-4', '2/30-5', '0/31-4', '1/42-5', '0/12-3', '1/42-5', '0/38-4', '4/19-4', '1/25-4', '1/20-4', '2/21-4', '0/32-5', '0/33-5', '2/25-4', '1/9-4', '2/17-4', '1/15-4', '1/35-5', '1/20-5', '1/24-4', '1/36-5', '1/40-5', '0/30-3', '2/30-3', '1/53-5', '1/37-4', '1/55-4', '2/33-5', '0/36-4', '2/41-4', '0/27-5', '0/32-4', '2/19-4', '0/27-4', '0/31-4', '2/29-5', '2/27-5', '2/20-5', '3/34-4', '0/21-4', '1/30-4']
# MatchIndex :  [3.5, 1.5, 1.6, 12.5, 2.5, 2.0, 3.1, 1.6666666666666667, 4.75, 2.45, 0.9166666666666666, 4.5, 4.833333333333333, 2.9, 2.75, 2.6, 7.0, 5.125, 4.75, 9.75, 3.3333333333333335, 0.8, 1.375, 2.0, 7.75, 4.2, 4.0, 4.2, 9.5, 0.95, 3.125, 2.5, 1.75, 6.4, 6.6, 2.0833333333333335, 1.125, 1.4166666666666667, 1.875, 3.5, 2.0, 3.0, 3.6, 4.0, 10.0, 3.3333333333333335, 5.3, 4.625, 6.875, 2.2, 9.0, 3.4166666666666665, 5.4, 8.0, 1.5833333333333333, 6.75, 7.75, 1.9333333333333333, 1.8, 1.3333333333333333, 2.125, 5.25, 3.75]
# AvgIndex 4.003174603174604
# AvgIndex2 0.09099683979115142
# Economy rate :  7.008201058201058 	 Avgwicket/match :  78
#
# MG Johnson
# Wickets :  14 	Matches :  14 	Balls :  327
# MatchStats :  ['2/37-5', '0/28-3', '1/43-5', '1/23-5', '1/34-5', '1/31-5', '2/28-5', '4/31-4', '1/30-4', '1/30-4', '0/42-4', '0/39-4', '0/51-4', '0/26-4']
# MatchIndex :  [2.466666666666667, 9.333333333333334, 4.3, 2.3, 3.4, 3.1, 1.8666666666666667, 1.55, 3.75, 3.75, 10.5, 9.75, 12.75, 6.5]
# AvgIndex 5.379761904761905
# AvgIndex2 0.5623519458544839
# Economy rate :  7.913095238095238 	 Avgwicket/match :  15
#
# MM Sharma
# Wickets :  38 	Matches :  39 	Balls :  810
# MatchStats :  ['0/24-3', '0/11-3', '4/24-4', '0/29-4', '2/20-4', '3/38-5', '3/32-4', '1/39-4', '0/21-4', '0/33-4', '2/26-5', '0/41-4', '0/33-3', '1/39-5', '0/34-4', '0/47-4', '0/30-3', '1/37-5', '2/25-4', '1/29-3', '1/27-5', '1/34-3', '1/3-2', '2/24-4', '0/35-4', '2/24-3', '2/57-4', '0/6-1', '1/27-3', '2/34-4', '0/45-4', '1/47-5', '2/52-5', '0/29-4', '1/40-5', '0/15-1', '0/38-4', '1/28-4', '1/45-5']
# MatchIndex :  [8.0, 3.6666666666666665, 1.2, 7.25, 1.6666666666666667, 1.9, 2.0, 4.875, 5.25, 8.25, 1.7333333333333334, 10.25, 11.0, 3.9, 8.5, 11.75, 10.0, 3.7, 2.0833333333333335, 4.833333333333333, 2.7, 5.666666666666667, 0.75, 2.0, 8.75, 2.6666666666666665, 4.75, 6.0, 4.5, 2.8333333333333335, 11.25, 4.7, 3.466666666666667, 7.25, 4.0, 15.0, 9.5, 3.5, 4.5]
# AvgIndex 5.527991452991453
# AvgIndex2 0.21720611373342322
# Economy rate :  8.25940170940171 	 Avgwicket/match :  39
#
# MP Stoinis
# Wickets :  29 	Matches :  37 	Balls :  562
# MatchStats :  ['1/27-2', '1/24-4', '0/26-3', '3/42-5', '0/35-3', '4/21-4', '0/28-4', '1/28-4', '0/28-4', '0/15-2', '1/28-3', '0/12-2', '0/28-3', '0/28-2', '0/7-1', '1/37-3', '0/6-1', '1/15-2', '0/13-1', '1/43-3', '1/32-5', '0/22-4', '1/13-2', '0/24-3', '2/30-3', '0/23-3', '1/47-5', '2/17-3', '1/31-3', '0/10-1', '0/14-2', '2/42-5', '0/15-2', '0/4-1', '1/5-1', '3/26-4', '1/23-2']
# MatchIndex :  [6.75, 3.0, 8.666666666666666, 2.1, 11.666666666666666, 1.05, 7.0, 3.5, 7.0, 7.5, 4.666666666666667, 6.0, 9.333333333333334, 14.0, 7.0, 6.166666666666667, 6.0, 3.75, 13.0, 7.166666666666667, 3.2, 5.5, 3.25, 8.0, 3.3333333333333335, 7.666666666666667, 4.7, 1.8888888888888888, 5.166666666666667, 10.0, 7.0, 2.8, 7.5, 4.0, 2.5, 1.625, 5.75]
# AvgIndex 5.924249249249248
# AvgIndex2 0.2888112973308503
# Economy rate :  8.383333333333331 	 Avgwicket/match :  30
#
# AR Patel
# Wickets :  54 	Matches :  65 	Balls :  1361
# MatchStats :  ['0/17-3', '1/26-3', '0/27-3', '2/19-3', '0/11-2', '1/42-4', '4/21-5', '0/26-4', '0/33-4', '1/27-4', '1/30-4', '1/27-4', '1/46-4', '1/43-5', '1/28-5', '1/12-4', '1/36-4', '1/34-4', '2/33-5', '0/21-3', '2/37-4', '0/34-3', '2/22-5', '3/11-3', '0/29-3', '0/28-4', '1/28-3', '1/13-2', '1/42-3', '0/16-4', '1/22-5', '1/22-4', '0/30-4', '0/23-2', '1/35-3', '1/26-4', '0/9-1', '1/22-4', '0/24-3', '0/52-5', '0/24-4', '0/29-4', '2/17-4', '2/22-3', '1/39-4', '1/26-4', '1/31-3', '1/16-4', '0/30-4', '1/32-4', '1/14-4', '2/18-4', '0/14-3', '2/19-4', '1/8-2', '1/24-3', '2/32-4', '0/23-4', '1/27-4', '0/7-1', '0/37-5', '0/30-4', '0/27-3', '1/33-4', '0/16-4']
# MatchIndex :  [5.666666666666667, 4.333333333333333, 9.0, 2.111111111111111, 5.5, 5.25, 0.84, 6.5, 8.25, 3.375, 3.75, 3.375, 5.75, 4.3, 2.8, 1.5, 4.5, 4.25, 2.2, 7.0, 3.0833333333333335, 11.333333333333334, 1.4666666666666666, 0.9166666666666666, 9.666666666666666, 7.0, 4.666666666666667, 3.25, 7.0, 4.0, 2.2, 2.75, 7.5, 11.5, 5.833333333333333, 3.25, 9.0, 2.75, 8.0, 10.4, 6.0, 7.25, 1.4166666666666667, 2.4444444444444446, 4.875, 3.25, 5.166666666666667, 2.0, 7.5, 4.0, 1.75, 1.5, 4.666666666666667, 1.5833333333333333, 2.0, 4.0, 2.6666666666666665, 5.75, 3.375, 7.0, 7.4, 7.5, 9.0, 4.125, 4.0]
# AvgIndex 4.862111111111111
# AvgIndex2 0.13344251400360768
# Economy rate :  7.2079487179487165 	 Avgwicket/match :  55
#
# P Sahu
# Wickets :  3 	Matches :  5 	Balls :  107
# MatchStats :  ['1/36-4', '0/31-3', '0/32-5', '2/18-4', '0/35-3']
# MatchIndex :  [4.5, 10.333333333333334, 6.4, 1.5, 11.666666666666666]
# AvgIndex 6.88
# AvgIndex2 2.6187499999999995
# Economy rate :  8.379999999999999 	 Avgwicket/match :  4
#
# A Nehra
# Wickets :  21 	Matches :  14 	Balls :  293
# MatchStats :  ['0/21-3', '1/22-4', '1/32-4', '0/23-4', '3/15-3', '5/29-4', '1/23-3', '0/35-3', '2/42-5', '2/28-4', '1/46-4', '1/35-5', '3/42-4', '1/5-2']
# MatchIndex :  [7.0, 2.75, 4.0, 5.75, 1.25, 1.2083333333333333, 3.8333333333333335, 11.666666666666666, 2.8, 2.3333333333333335, 5.75, 3.5, 2.625, 1.25]
# AvgIndex 3.9797619047619044
# AvgIndex2 0.3550282485875706
# Economy rate :  7.480952380952381 	 Avgwicket/match :  22
#
# B Kumar
# Wickets :  81 	Matches :  62 	Balls :  1479
# MatchStats :  ['2/55-5', '0/29-5', '1/17-4', '4/30-5', '1/38-4', '1/17-4', '1/36-5', '2/28-4', '1/23-4', '1/21-5', '0/32-5', '2/33-4', '0/37-5', '2/31-4', '3/20-4', '2/27-5', '1/29-5', '2/28-5', '2/23-4', '3/23-4', '3/21-4', '5/20-5', '0/31-5', '1/39-5', '2/29-4', '2/30-4', '1/33-4', '1/39-5', '2/31-5', '2/26-4', '2/11-1', '0/37-4', '0/55-5', '0/25-3', '2/27-5', '1/34-5', '0/25-4', '2/34-5', '0/22-4', '2/30-5', '3/26-5', '1/25-5', '1/22-3', '0/33-4', '1/28-4', '1/52-5', '0/38-4', '0/33-5', '1/14-4', '0/39-4', '0/17-4', '2/35-5', '2/19-4', '0/23-5', '0/34-5', '1/29-5', '2/25-5', '2/42-5', '2/25-5', '0/29-4', '2/26-5', '1/20-4']
# MatchIndex :  [3.6666666666666665, 5.8, 2.125, 1.2, 4.75, 2.125, 3.6, 2.3333333333333335, 2.875, 2.1, 6.4, 2.75, 7.4, 2.5833333333333335, 1.25, 1.8, 2.9, 1.8666666666666667, 1.9166666666666667, 1.4375, 1.3125, 0.6666666666666666, 6.2, 3.9, 2.4166666666666665, 2.5, 4.125, 3.9, 2.066666666666667, 2.1666666666666665, 3.6666666666666665, 9.25, 11.0, 8.333333333333334, 1.8, 3.4, 6.25, 2.2666666666666666, 5.5, 2.0, 1.3, 2.5, 3.6666666666666665, 8.25, 3.5, 5.2, 9.5, 6.6, 1.75, 9.75, 4.25, 2.3333333333333335, 1.5833333333333333, 4.6, 6.8, 2.9, 1.6666666666666667, 2.8, 1.6666666666666667, 7.25, 1.7333333333333334, 2.5]
# AvgIndex 3.8016129032258066
# AvgIndex2 0.08216537261928462
# Economy rate :  6.656720430107527 	 Avgwicket/match :  82
#
# Mustafizur Rahman
# Wickets :  28 	Matches :  24 	Balls :  560
# MatchStats :  ['2/26-4', '1/29-5', '1/33-5', '1/19-4', '3/9-4', '0/22-3', '1/35-4', '2/17-4', '3/16-4', '0/26-4', '0/39-5', '1/32-4', '1/24-5', '1/32-5', '0/30-4', '2/38-4', '0/34-3', '1/40-4', '3/24-4', '1/26-4', '0/55-5', '1/35-5', '2/18-4', '1/34-4']
# MatchIndex :  [2.1666666666666665, 2.9, 3.3, 2.375, 0.5625, 7.333333333333333, 4.375, 1.4166666666666667, 1.0, 6.5, 7.8, 4.0, 2.4, 3.2, 7.5, 3.1666666666666665, 11.333333333333334, 5.0, 1.5, 3.25, 11.0, 3.5, 1.5, 4.25]
# AvgIndex 4.222048611111111
# AvgIndex2 0.246012877662209
# Economy rate :  6.898611111111111 	 Avgwicket/match :  29
#
# MC Henriques
# Wickets :  16 	Matches :  29 	Balls :  466
# MatchStats :  ['0/41-4', '0/19-3', '0/23-5', '0/18-4', '2/33-5', '1/16-2', '2/40-4', '1/24-4', '1/20-4', '1/20-3', '2/19-3', '1/29-3', '0/18-2', '0/14-2', '3/17-3', '0/27-3', '0/40-3', '1/20-3', '0/12-1', '0/26-3', '1/6-2', '0/32-4', '0/4-1', '0/39-3', '0/31-3', '0/36-3', '0/15-3', '0/15-1', '0/12-1']
# MatchIndex :  [10.25, 6.333333333333333, 4.6, 4.5, 2.2, 4.0, 3.3333333333333335, 3.0, 2.5, 3.3333333333333335, 2.111111111111111, 4.833333333333333, 9.0, 7.0, 1.4166666666666667, 9.0, 13.333333333333334, 3.3333333333333335, 12.0, 8.666666666666666, 1.5, 8.0, 4.0, 13.0, 10.333333333333334, 12.0, 5.0, 15.0, 12.0]
# AvgIndex 6.744061302681993
# AvgIndex2 0.5110035842293907
# Economy rate :  8.193678160919541 	 Avgwicket/match :  17
#
# KV Sharma
# Wickets :  24 	Matches :  25 	Balls :  482
# MatchStats :  ['0/58-5', '0/24-3', '0/28-4', '1/25-3', '0/39-4', '2/39-4', '1/23-4', '3/12-4', '0/20-2', '1/32-3', '1/26-3', '1/30-4', '4/17-5', '0/18-5', '1/33-3', '2/13-2', '1/30-3', '0/11-1', '0/11-1', '1/25-4', '2/25-4', '0/34-5', '2/37-5', '0/34-3', '1/35-4']
# MatchIndex :  [11.6, 8.0, 7.0, 4.166666666666667, 9.75, 3.25, 2.875, 0.75, 10.0, 5.333333333333333, 4.333333333333333, 3.75, 0.68, 3.6, 5.5, 2.1666666666666665, 5.0, 11.0, 11.0, 3.125, 2.0833333333333335, 6.8, 2.466666666666667, 11.333333333333334, 4.375]
# AvgIndex 5.597533333333334
# AvgIndex2 0.33826955074875215
# Economy rate :  8.132000000000001 	 Avgwicket/match :  25
#
# A Ashish Reddy
# Wickets :  1 	Matches :  2 	Balls :  23
# MatchStats :  ['0/26-2', '1/14-2']
# MatchIndex :  [13.0, 3.5]
# AvgIndex 8.25
# AvgIndex2 6.666666666666667
# Economy rate :  10.0 	 Avgwicket/match :  2
#
# AF Milne
# Wickets :  5 	Matches :  5 	Balls :  115
# MatchStats :  ['1/44-5', '3/32-4', '1/45-5', '0/35-5', '0/29-3']
# MatchIndex :  [4.4, 2.0, 4.5, 7.0, 9.666666666666666]
# AvgIndex 5.513333333333333
# AvgIndex2 1.633333333333333
# Economy rate :  8.493333333333332 	 Avgwicket/match :  6
#
# SR Watson
# Wickets :  35 	Matches :  35 	Balls :  701
# MatchStats :  ['2/30-5', '2/28-5', '0/40-5', '2/31-5', '1/31-4', '2/33-5', '1/38-3', '3/25-5', '2/22-4', '0/38-4', '0/4-2', '0/46-5', '2/7-3', '1/27-4', '4/29-5', '1/61-5', '0/41-3', '1/21-4', '0/29-2', '1/44-5', '0/24-2', '1/28-4', '1/43-5', '1/16-4', '2/29-5', '3/39-5', '1/15-2', '1/13-4', '0/23-2', '0/21-3', '0/41-5', '0/27-2', '0/19-3', '0/9-1', '0/16-3']
# MatchIndex :  [2.0, 1.8666666666666667, 8.0, 2.066666666666667, 3.875, 2.2, 6.333333333333333, 1.25, 1.8333333333333333, 9.5, 2.0, 9.2, 0.7777777777777778, 3.375, 1.16, 6.1, 13.666666666666666, 2.625, 14.5, 4.4, 12.0, 3.5, 4.3, 2.0, 1.9333333333333333, 1.95, 3.75, 1.625, 11.5, 7.0, 8.2, 13.5, 6.333333333333333, 9.0, 5.333333333333333]
# AvgIndex 5.390126984126985
# AvgIndex2 0.22033713974986402
# Economy rate :  7.718095238095238 	 Avgwicket/match :  36
#
# Parvez Rasool
# Wickets :  1 	Matches :  4 	Balls :  84
# MatchStats :  ['1/31-4', '0/28-3', '0/34-4', '0/37-3']
# MatchIndex :  [3.875, 9.333333333333334, 8.5, 12.333333333333334]
# AvgIndex 8.510416666666668
# AvgIndex2 7.583333333333334
# Economy rate :  9.479166666666668 	 Avgwicket/match :  2
#
# HV Patel
# Wickets :  18 	Matches :  18 	Balls :  374
# MatchStats :  ['0/33-5', '0/32-3', '0/20-2', '2/46-5', '0/16-2', '3/43-5', '2/40-5', '1/37-5', '1/34-3', '1/32-4', '1/51-5', '1/24-4', '3/28-3', '2/34-5', '0/44-5', '1/29-5', '0/20-2', '0/8-2']
# MatchIndex :  [6.6, 10.666666666666666, 10.0, 3.066666666666667, 8.0, 2.15, 2.6666666666666665, 3.7, 5.666666666666667, 4.0, 5.1, 3.0, 2.3333333333333335, 2.2666666666666666, 8.8, 2.9, 10.0, 4.0]
# AvgIndex 5.273148148148148
# AvgIndex2 0.45764102564102566
# Economy rate :  8.262962962962964 	 Avgwicket/match :  19
#
# YS Chahal
# Wickets :  88 	Matches :  69 	Balls :  1548
# MatchStats :  ['2/44-5', '0/23-3', '1/33-5', '2/31-5', '1/38-5', '2/32-4', '1/16-4', '3/19-4', '1/38-5', '4/25-3', '3/32-5', '1/42-4', '1/36-4', '1/22-4', '1/20-4', '1/29-4', '1/34-3', '0/11-2', '3/31-5', '3/16-5', '0/30-4', '0/25-2', '1/36-5', '2/29-5', '1/40-5', '0/28-4', '1/6-4', '4/42-5', '1/44-5', '2/17-5', '1/25-4', '0/36-5', '2/35-5', '2/27-4', '0/29-4', '1/39-4', '2/27-5', '0/32-3', '2/23-4', '2/27-5', '0/29-4', '0/25-5', '0/29-4', '1/25-5', '2/28-4', '1/7-2', '1/28-5', '0/26-4', '0/45-4', '1/24-4', '0/27-2', '2/41-4', '1/1-1', '1/24-5', '3/22-4', '1/25-4', '1/48-4', '3/25-4', '0/29-3', '1/35-5', '1/14-4', '2/35-4', '2/35-5', '2/15-4', '1/22-4', '2/37-4', '2/19-4', '0/29-4', '1/24-4']
# MatchIndex :  [2.933333333333333, 7.666666666666667, 3.3, 2.066666666666667, 3.8, 2.6666666666666665, 2.0, 1.1875, 3.8, 1.6666666666666667, 1.6, 5.25, 4.5, 2.75, 2.5, 3.625, 5.666666666666667, 5.5, 1.55, 0.8, 7.5, 12.5, 3.6, 1.9333333333333333, 4.0, 7.0, 0.75, 1.68, 4.4, 1.1333333333333333, 3.125, 7.2, 2.3333333333333335, 2.25, 7.25, 4.875, 1.8, 10.666666666666666, 1.9166666666666667, 1.8, 7.25, 5.0, 7.25, 2.5, 2.3333333333333335, 1.75, 2.8, 6.5, 11.25, 3.0, 13.5, 3.4166666666666665, 0.5, 2.4, 1.375, 3.125, 6.0, 1.5625, 9.666666666666666, 3.5, 1.75, 2.9166666666666665, 2.3333333333333335, 1.25, 2.75, 3.0833333333333335, 1.5833333333333333, 7.25, 3.0]
# AvgIndex 3.958526570048309
# AvgIndex2 0.07858828695318075
# Economy rate :  6.916908212560387 	 Avgwicket/match :  89
#
# TG Southee
# Wickets :  21 	Matches :  25 	Balls :  575
# MatchStats :  ['0/44-5', '0/31-4', '3/25-5', '0/25-4', '0/22-4', '2/28-4', '2/38-4', '0/35-5', '0/36-4', '1/27-5', '1/22-5', '1/34-5', '0/23-3', '2/40-5', '0/62-5', '1/28-3', '0/34-5', '2/25-5', '0/30-3', '5/31-5', '0/41-5', '0/20-2', '0/45-5', '1/37-5', '0/33-4']
# MatchIndex :  [8.8, 7.75, 1.25, 6.25, 5.5, 2.3333333333333335, 3.1666666666666665, 7.0, 9.0, 2.7, 2.2, 3.4, 7.666666666666667, 2.6666666666666665, 12.4, 4.666666666666667, 6.8, 1.6666666666666667, 10.0, 1.0333333333333334, 8.2, 10.0, 9.0, 3.7, 8.25]
# AvgIndex 5.816
# AvgIndex2 0.3624524714828898
# Economy rate :  7.626 	 Avgwicket/match :  22
#
# J Suchith
# Wickets :  2 	Matches :  2 	Balls :  38
# MatchStats :  ['0/31-3', '2/28-4']
# MatchIndex :  [10.333333333333334, 2.3333333333333335]
# AvgIndex 6.333333333333334
# AvgIndex2 3.4666666666666672
# Economy rate :  8.666666666666668 	 Avgwicket/match :  3
#
# Kuldeep Yadav
# Wickets :  43 	Matches :  43 	Balls :  913
# MatchStats :  ['1/37-5', '3/29-5', '3/36-4', '2/25-4', '1/35-5', '1/23-4', '0/29-3', '2/33-4', '2/31-4', '0/27-4', '0/43-5', '1/35-4', '2/35-4', '1/29-3', '0/18-2', '0/32-5', '3/41-4', '1/31-4', '0/33-4', '0/16-4', '0/28-5', '0/28-3', '0/33-4', '1/29-4', '1/23-4', '3/32-4', '1/24-4', '0/13-1', '0/22-2', '1/22-4', '1/34-5', '0/17-2', '0/43-3', '1/29-3', '4/20-4', '1/35-4', '1/18-4', '3/29-4', '1/59-5', '0/40-5', '0/15-2', '1/21-3', '0/19-4']
# MatchIndex :  [3.7, 1.45, 2.25, 2.0833333333333335, 3.5, 2.875, 9.666666666666666, 2.75, 2.5833333333333335, 6.75, 8.6, 4.375, 2.9166666666666665, 4.833333333333333, 9.0, 6.4, 2.5625, 3.875, 8.25, 4.0, 5.6, 9.333333333333334, 8.25, 3.625, 2.875, 2.0, 3.0, 13.0, 11.0, 2.75, 3.4, 8.5, 14.333333333333334, 4.833333333333333, 1.0, 4.375, 2.25, 1.8125, 5.9, 8.0, 7.5, 3.5, 4.75]
# AvgIndex 5.209496124031009
# AvgIndex2 0.18300900900900902
# Economy rate :  7.873643410852714 	 Avgwicket/match :  44
#
# SB Jakati
# Wickets :  2 	Matches :  8 	Balls :  155
# MatchStats :  ['0/41-4', '1/13-4', '0/28-3', '1/24-4', '0/30-3', '0/45-4', '0/30-4', '0/22-2']
# MatchIndex :  [10.25, 1.625, 9.333333333333334, 3.0, 10.0, 11.25, 7.5, 11.0]
# AvgIndex 7.994791666666667
# AvgIndex2 4.034313725490197
# Economy rate :  8.572916666666668 	 Avgwicket/match :  3
#
# PV Tambe
# Wickets :  5 	Matches :  7 	Balls :  97
# MatchStats :  ['2/33-4', '2/12-2', '0/17-3', '1/24-3', '0/17-1', '0/15-2', '0/25-2']
# MatchIndex :  [2.75, 2.0, 5.666666666666667, 4.0, 17.0, 7.5, 12.5]
# AvgIndex 7.345238095238096
# AvgIndex2 1.8032407407407407
# Economy rate :  9.273809523809524 	 Avgwicket/match :  6
#
# P Negi
# Wickets :  23 	Matches :  23 	Balls :  348
# MatchStats :  ['1/10-1', '0/26-3', '0/19-1', '0/10-1', '1/19-3', '2/3-1', '0/8-1', '0/29-3', '1/13-4', '1/21-5', '2/15-4', '1/24-3', '1/18-5', '3/18-4', '1/22-3', '2/21-4', '3/10-2', '2/21-4', '1/28-4', '0/47-5', '0/13-1', '1/36-3', '0/7-1']
# MatchIndex :  [5.0, 8.666666666666666, 19.0, 10.0, 3.1666666666666665, 1.0, 8.0, 9.666666666666666, 1.625, 2.1, 1.25, 4.0, 1.8, 1.125, 3.6666666666666665, 1.75, 1.25, 1.75, 3.5, 9.4, 13.0, 6.0, 7.0]
# AvgIndex 5.378985507246377
# AvgIndex2 0.3267924528301887
# Economy rate :  7.530434782608697 	 Avgwicket/match :  24
#
# J Yadav
# Wickets :  4 	Matches :  11 	Balls :  226
# MatchStats :  ['1/23-5', '0/25-4', '1/32-5', '0/37-4', '0/8-1', '0/16-3', '0/27-4', '0/25-4', '1/25-4', '0/18-3', '1/25-4']
# MatchIndex :  [2.3, 6.25, 3.2, 9.25, 8.0, 5.333333333333333, 6.75, 6.25, 3.125, 6.0, 3.125]
# AvgIndex 5.416666666666667
# AvgIndex2 1.5851851851851853
# Economy rate :  6.484848484848485 	 Avgwicket/match :  5
#
# GJ Maxwell
# Wickets :  15 	Matches :  32 	Balls :  394
# MatchStats :  ['0/11-2', '0/3-1', '0/18-2', '0/16-2', '0/11-1', '0/11-1', '0/11-1', '0/18-1', '0/7-1', '2/29-4', '1/12-4', '2/15-4', '1/21-2', '1/9-2', '0/15-2', '0/21-4', '1/13-3', '0/4-1', '2/22-2', '1/5-1', '1/21-1', '0/4-1', '0/9-1', '0/14-2', '0/19-2', '1/10-2', '0/31-3', '0/26-2', '0/28-4', '0/24-4', '1/31-4', '1/21-2']
# MatchIndex :  [5.5, 3.0, 9.0, 8.0, 11.0, 11.0, 11.0, 18.0, 7.0, 2.4166666666666665, 1.5, 1.25, 5.25, 2.25, 7.5, 5.25, 2.1666666666666665, 4.0, 3.6666666666666665, 2.5, 10.5, 4.0, 9.0, 7.0, 9.5, 2.5, 10.333333333333334, 13.0, 7.0, 6.0, 3.875, 5.25]
# AvgIndex 6.537760416666667
# AvgIndex2 0.5398475398475399
# Economy rate :  8.114583333333334 	 Avgwicket/match :  16
#
# M Morkel
# Wickets :  10 	Matches :  10 	Balls :  220
# MatchStats :  ['2/35-5', '2/27-4', '0/30-3', '2/28-4', '1/28-5', '0/38-4', '0/22-4', '0/20-2', '1/39-4', '2/32-4']
# MatchIndex :  [2.3333333333333335, 2.25, 10.0, 2.3333333333333335, 2.8, 9.5, 5.5, 10.0, 4.875, 2.6666666666666665]
# AvgIndex 5.225833333333333
# AvgIndex2 0.7831683168316831
# Economy rate :  7.909999999999999 	 Avgwicket/match :  11
#
# Shakib Al Hasan
# Wickets :  23 	Matches :  30 	Balls :  619
# MatchStats :  ['0/19-3', '0/29-5', '1/14-3', '1/30-4', '0/21-3', '1/38-3', '1/21-3', '0/39-5', '1/36-5', '0/34-3', '1/42-4', '2/24-4', '1/34-5', '2/22-5', '0/28-2', '0/32-5', '1/16-3', '2/18-3', '0/30-4', '0/34-4', '2/36-4', '2/27-4', '1/41-4', '0/35-4', '1/30-3', '0/20-2', '2/16-3', '0/15-1', '0/27-4', '1/26-4']
# MatchIndex :  [6.333333333333333, 5.8, 2.3333333333333335, 3.75, 7.0, 6.333333333333333, 3.5, 7.8, 3.6, 11.333333333333334, 5.25, 2.0, 3.4, 1.4666666666666666, 14.0, 6.4, 2.6666666666666665, 2.0, 7.5, 8.5, 3.0, 2.25, 5.125, 8.75, 5.0, 10.0, 1.7777777777777777, 15.0, 6.75, 3.25]
# AvgIndex 5.728981481481482
# AvgIndex2 0.34886637723106606
# Economy rate :  8.035555555555556 	 Avgwicket/match :  24
#
# SP Narine
# Wickets :  59 	Matches :  64 	Balls :  1498
# MatchStats :  ['0/26-4', '2/23-5', '1/33-4', '2/22-4', '1/22-4', '0/45-4', '1/12-4', '1/34-4', '2/30-5', '3/28-4', '0/35-5', '0/33-4', '1/22-4', '1/19-5', '1/18-4', '2/20-5', '0/42-4', '1/34-5', '2/25-5', '0/37-4', '1/28-4', '2/29-4', '1/27-4', '0/37-5', '0/20-4', '0/21-4', '0/29-3', '0/26-2', '1/30-5', '0/26-5', '2/24-4', '2/19-5', '1/31-4', '1/18-4', '2/17-5', '3/18-3', '0/48-4', '1/23-3', '0/36-3', '0/39-4', '2/20-4', '2/35-4', '1/28-4', '1/44-4', '1/29-5', '1/24-5', '0/39-5', '1/24-4', '1/32-5', '0/36-4', '2/25-4', '2/44-4', '1/29-4', '0/33-5', '2/22-4', '0/32-4', '1/42-5', '0/26-2', '1/32-4', '2/30-4', '0/37-5', '0/27-4', '0/23-4', '0/37-4']
# MatchIndex :  [6.5, 1.5333333333333334, 4.125, 1.8333333333333333, 2.75, 11.25, 1.5, 4.25, 2.0, 1.75, 7.0, 8.25, 2.75, 1.9, 2.25, 1.3333333333333333, 10.5, 3.4, 1.6666666666666667, 9.25, 3.5, 2.4166666666666665, 3.375, 7.4, 5.0, 5.25, 9.666666666666666, 13.0, 3.0, 5.2, 2.0, 1.2666666666666666, 3.875, 2.25, 1.1333333333333333, 1.5, 12.0, 3.8333333333333335, 12.0, 9.75, 1.6666666666666667, 2.9166666666666665, 3.5, 5.5, 2.9, 2.4, 7.8, 3.0, 3.2, 9.0, 2.0833333333333335, 3.6666666666666665, 3.625, 6.6, 1.8333333333333333, 8.0, 4.2, 13.0, 4.0, 2.5, 7.4, 6.75, 5.75, 9.25]
# AvgIndex 4.90234375
# AvgIndex2 0.12133527490954019
# Economy rate :  7.160677083333333 	 Avgwicket/match :  60
#
# BB Sran
# Wickets :  20 	Matches :  23 	Balls :  496
# MatchStats :  ['0/31-5', '3/29-5', '1/36-4', '0/33-4', '1/36-5', '1/21-4', '2/18-4', '1/27-4', '0/21-2', '2/34-5', '1/32-5', '1/33-3', '0/28-4', '1/41-4', '0/29-3', '1/38-5', '1/22-5', '2/50-5', '1/45-5', '0/28-4', '1/48-3', '0/27-2', '0/24-3']
# MatchIndex :  [6.2, 1.45, 4.5, 8.25, 3.6, 2.625, 1.5, 3.375, 10.5, 2.2666666666666666, 3.2, 5.5, 7.0, 5.125, 9.666666666666666, 3.8, 2.2, 3.3333333333333335, 4.5, 7.0, 8.0, 13.5, 8.0]
# AvgIndex 5.438768115942029
# AvgIndex2 0.41229211858279097
# Economy rate :  8.263768115942028 	 Avgwicket/match :  21
#
# DS Kulkarni
# Wickets :  33 	Matches :  39 	Balls :  780
# MatchStats :  ['2/19-4', '0/9-1', '1/39-4', '3/19-4', '0/25-4', '1/28-4', '0/24-2', '2/17-4', '1/30-5', '1/33-3', '2/34-5', '2/41-4', '4/15-4', '1/32-4', '0/42-4', '0/17-2', '1/37-5', '0/23-2', '1/24-5', '1/30-4', '1/30-5', '0/40-4', '1/37-5', '0/26-4', '0/31-4', '1/14-3', '1/38-4', '1/38-4', '0/18-3', '0/5-2', '0/14-1', '0/20-2', '2/32-5', '0/20-2', '1/37-4', '1/43-4', '0/31-4', '1/51-4', '0/22-4']
# MatchIndex :  [1.5833333333333333, 9.0, 4.875, 1.1875, 6.25, 3.5, 12.0, 1.4166666666666667, 3.0, 5.5, 2.2666666666666666, 3.4166666666666665, 0.75, 4.0, 10.5, 8.5, 3.7, 11.5, 2.4, 3.75, 3.0, 10.0, 3.7, 6.5, 7.75, 2.3333333333333335, 4.75, 4.75, 6.0, 2.5, 14.0, 10.0, 2.1333333333333333, 10.0, 4.625, 5.375, 7.75, 6.375, 5.5]
# AvgIndex 5.54198717948718
# AvgIndex2 0.24065734989648033
# Economy rate :  7.947863247863249 	 Avgwicket/match :  34
#
# KH Pandya
# Wickets :  49 	Matches :  69 	Balls :  1283
# MatchStats :  ['1/21-4', '2/27-5', '0/25-5', '0/21-2', '0/21-2', '0/28-3', '0/5-1', '1/15-4', '0/32-4', '3/15-3', '0/28-2', '0/21-2', '3/24-4', '0/12-2', '1/25-4', '0/18-3', '1/31-5', '0/8-1', '3/15-5', '2/34-5', '0/14-2', '0/22-4', '0/25-3', '0/31-4', '0/21-2', '0/28-4', '2/44-5', '0/13-3', '0/9-2', '0/17-2', '3/34-5', '0/10-1', '0/10-2', '2/21-3', '3/28-5', '1/33-5', '0/14-3', '2/32-5', '0/25-4', '1/10-1', '1/29-3', '3/12-4', '0/24-4', '0/37-4', '1/13-2', '1/7-2', '0/24-2', '2/7-3', '0/27-3', '2/22-5', '0/14-5', '1/21-4', '1/39-3', '1/37-5', '0/10-1', '0/23-4', '1/27-5', '1/37-5', '0/22-2', '2/26-4', '0/24-4', '0/12-2', '0/16-4', '0/21-2', '0/27-4', '0/16-4', '0/37-4', '1/22-5', '0/30-4']
# MatchIndex :  [2.625, 1.8, 5.0, 10.5, 10.5, 9.333333333333334, 5.0, 1.875, 8.0, 1.25, 14.0, 10.5, 1.5, 6.0, 3.125, 6.0, 3.1, 8.0, 0.75, 2.2666666666666666, 7.0, 5.5, 8.333333333333334, 7.75, 10.5, 7.0, 2.933333333333333, 4.333333333333333, 4.5, 8.5, 1.7, 10.0, 5.0, 2.3333333333333335, 1.4, 3.3, 4.666666666666667, 2.1333333333333333, 6.25, 5.0, 4.833333333333333, 0.75, 6.0, 9.25, 3.25, 1.75, 12.0, 0.7777777777777778, 9.0, 1.4666666666666666, 2.8, 2.625, 6.5, 3.7, 10.0, 5.75, 2.7, 3.7, 11.0, 2.1666666666666665, 6.0, 6.0, 4.0, 10.5, 6.75, 4.0, 9.25, 2.2, 7.5]
# AvgIndex 5.4417069243156195
# AvgIndex2 0.14179972402917404
# Economy rate :  6.950241545893719 	 Avgwicket/match :  50
#
# KJ Abbott
# Wickets :  2 	Matches :  5 	Balls :  102
# MatchStats :  ['1/42-5', '0/32-4', '0/34-3', '1/48-4', '0/26-3']
# MatchIndex :  [4.2, 8.0, 11.333333333333334, 6.0, 8.666666666666666]
# AvgIndex 7.639999999999999
# AvgIndex2 4.3999999999999995
# Economy rate :  9.68 	 Avgwicket/match :  3
#
# Ankit Sharma
# Wickets :  1 	Matches :  5 	Balls :  82
# MatchStats :  ['1/27-5', '0/31-5', '0/26-4', '0/16-1', '0/11-1']
# MatchIndex :  [2.7, 6.2, 6.5, 16.0, 11.0]
# AvgIndex 8.48
# AvgIndex2 7.516666666666667
# Economy rate :  9.02 	 Avgwicket/match :  2
#
# IK Pathan
# Wickets :  2 	Matches :  4 	Balls :  60
# MatchStats :  ['0/7-1', '0/17-3', '0/37-4', '2/26-2']
# MatchIndex :  [7.0, 5.666666666666667, 9.25, 4.333333333333333]
# AvgIndex 6.5625
# AvgIndex2 3.87962962962963
# Economy rate :  8.729166666666668 	 Avgwicket/match :  3
#
# NLTC Perera
# Wickets :  10 	Matches :  11 	Balls :  202
# MatchStats :  ['0/30-3', '3/34-5', '2/28-4', '1/32-4', '3/41-5', '0/35-4', '0/9-1', '0/40-3', '0/26-2', '0/27-3', '1/24-2']
# MatchIndex :  [10.0, 1.7, 2.3333333333333335, 4.0, 2.05, 8.75, 9.0, 13.333333333333334, 13.0, 9.0, 6.0]
# AvgIndex 7.196969696969696
# AvgIndex2 0.9466966966966966
# Economy rate :  9.553030303030303 	 Avgwicket/match :  11
#
# Mohammed Shami
# Wickets :  63 	Matches :  48 	Balls :  1070
# MatchStats :  ['3/36-5', '1/24-3', '0/34-5', '2/33-4', '0/50-4', '1/34-4', '1/28-3', '0/13-1', '0/28-4', '0/19-3', '2/40-5', '1/40-3', '0/16-2', '2/37-5', '2/37-5', '1/31-5', '1/33-4', '1/44-5', '2/43-5', '3/27-4', '0/41-5', '1/30-4', '3/21-5', '1/43-4', '2/46-4', '0/26-2', '1/29-4', '1/36-4', '1/53-5', '2/22-4', '1/57-5', '2/36-5', '1/16-3', '2/18-3', '4/16-5', '1/15-3', '3/53-5', '1/36-5', '0/35-4', '1/40-4', '2/32-4', '2/49-4', '2/30-4', '2/28-5', '1/34-5', '3/36-4', '0/37-3', '0/33-5']
# MatchIndex :  [1.8, 4.0, 6.8, 2.75, 12.5, 4.25, 4.666666666666667, 13.0, 7.0, 6.333333333333333, 2.6666666666666665, 6.666666666666667, 8.0, 2.466666666666667, 2.466666666666667, 3.1, 4.125, 4.4, 2.8666666666666667, 1.6875, 8.2, 3.75, 1.05, 5.375, 3.8333333333333335, 13.0, 3.625, 4.5, 5.3, 1.8333333333333333, 5.7, 2.4, 2.6666666666666665, 2.0, 0.64, 2.5, 2.65, 3.6, 8.75, 5.0, 2.6666666666666665, 4.083333333333333, 2.5, 1.8666666666666667, 3.4, 2.25, 12.333333333333334, 6.6]
# AvgIndex 4.658732638888889
# AvgIndex2 0.1322038567493113
# Economy rate :  8.331597222222221 	 Avgwicket/match :  64
#
# S Aravind
# Wickets :  16 	Matches :  19 	Balls :  372
# MatchStats :  ['1/32-4', '1/16-3', '1/23-4', '1/16-3', '2/45-4', '2/18-3', '1/28-4', '0/14-3', '2/30-4', '0/36-3', '0/21-5', '2/29-5', '1/53-5', '1/27-4', '0/20-4', '0/31-4', '0/22-2', '1/13-2', '0/26-2']
# ...
#
# V Shankar
# Wickets :  7 	Matches :  14 	Balls :  170
# MatchStats :  ['0/13-1', '1/13-3', '0/17-2', '1/11-2', '0/12-1', '0/10-1', '1/22-3', '0/14-2', '0/16-2', '1/14-2', '0/22-4', '1/20-4', '1/15-3', '1/11-2']
# MatchIndex :  [13.0, 2.1666666666666665, 8.5, 2.75, 12.0, 10.0, 3.6666666666666665, 7.0, 8.0, 3.5, 5.5, 2.5, 2.5, 2.75]
# AvgIndex 5.988095238095238
# AvgIndex2 1.0471380471380471
# Economy rate :  7.404761904761904 	 Avgwicket/match :  8
#
# S Lamichhane
# Wickets :  14 	Matches :  9 	Balls :  211
# MatchStats :  ['2/29-4', '2/28-4', '1/32-4', '1/46-4', '1/29-4', '1/21-4', '3/36-5', '3/40-4', '0/36-3']
# MatchIndex :  [2.4166666666666665, 2.3333333333333335, 4.0, 5.75, 3.625, 2.625, 1.8, 2.5, 12.0]
# AvgIndex 4.116666666666666
# AvgIndex2 0.5940944881889764
# Economy rate :  8.383333333333333 	 Avgwicket/match :  15
#
# P Ray Barman
# Wickets :  0 	Matches :  1 	Balls :  24
# MatchStats :  ['0/56-4']
# MatchIndex :  [14.0]
# AvgIndex 14.0
# AvgIndex2 14.0
# Economy rate :  14.0 	 Avgwicket/match :  1
#
# MJ Santner
# Wickets :  6 	Matches :  6 	Balls :  130
# MatchStats :  ['0/26-3', '1/25-5', '1/30-5', '2/13-4', '1/23-4', '1/30-3']
# MatchIndex :  [8.666666666666666, 2.5, 3.0, 1.0833333333333333, 2.875, 5.0]
# AvgIndex 3.8541666666666665
# AvgIndex2 1.0450450450450448
# Economy rate :  6.444444444444444 	 Avgwicket/match :  7
#
# GH Vihari
# Wickets :  0 	Matches :  1 	Balls :  6
# MatchStats :  ['0/9-1']
# MatchIndex :  [9.0]
# AvgIndex 9.0
# AvgIndex2 9.0
# Economy rate :  9.0 	 Avgwicket/match :  1
#
# JP Behrendorff
# Wickets :  5 	Matches :  5 	Balls :  117
# MatchStats :  ['2/23-5', '1/28-4', '1/35-4', '0/31-4', '1/51-5']
# MatchIndex :  [1.5333333333333334, 3.5, 4.375, 7.75, 5.1]
# AvgIndex 4.451666666666666
# AvgIndex2 1.473076923076923
# Economy rate :  7.659999999999999 	 Avgwicket/match :  6
#
# SC Kuggeleijn
# Wickets :  2 	Matches :  2 	Balls :  50
# MatchStats :  ['2/37-5', '0/34-5']
# MatchIndex :  [2.466666666666667, 6.8]
# AvgIndex 4.633333333333333
# AvgIndex2 2.84
# Economy rate :  7.1 	 Avgwicket/match :  3
#
# AS Joseph
# Wickets :  6 	Matches :  3 	Balls :  55
# MatchStats :  ['6/14-4', '0/22-3', '0/53-3']
# MatchIndex :  [0.5, 7.333333333333333, 17.666666666666668]
# AvgIndex 8.5
# AvgIndex2 1.5
# Economy rate :  9.5 	 Avgwicket/match :  7
#
# HF Gurney
# Wickets :  7 	Matches :  8 	Balls :  169
# MatchStats :  ['2/25-5', '0/20-3', '1/37-4', '1/42-5', '0/16-3', '2/37-4', '1/42-4', '0/20-4']
# MatchIndex :  [1.6666666666666667, 6.666666666666667, 4.625, 4.2, 5.333333333333333, 3.0833333333333335, 5.25, 5.0]
# AvgIndex 4.478125
# AvgIndex2 1.0421052631578949
# Economy rate :  7.425000000000001 	 Avgwicket/match :  8
#
# S Midhun
# Wickets :  0 	Matches :  1 	Balls :  13
# MatchStats :  ['0/29-3']
# MatchIndex :  [9.666666666666666]
# AvgIndex 9.666666666666666
# AvgIndex2 9.666666666666666
# Economy rate :  9.666666666666666 	 Avgwicket/match :  1
#
# R Parag
# Wickets :  2 	Matches :  9 	Balls :  97
# MatchStats :  ['0/24-3', '0/17-2', '1/25-3', '0/7-1', '0/24-3', '1/10-1', '0/14-1', '0/14-1', '0/13-2']
# MatchIndex :  [8.0, 8.5, 4.166666666666667, 7.0, 8.0, 5.0, 14.0, 14.0, 6.5]
# AvgIndex 8.351851851851853
# AvgIndex2 4.438596491228071
# Economy rate :  9.370370370370372 	 Avgwicket/match :  3
#
# LS Livingstone
# Wickets :  0 	Matches :  1 	Balls :  6
# MatchStats :  ['0/13-1']
# MatchIndex :  [13.0]
# AvgIndex 13.0
# AvgIndex2 13.0
# Economy rate :  13.0 	 Avgwicket/match :  1
#
# SN Khan
# Wickets :  0 	Matches :  1 	Balls :  2
# MatchStats :  ['0/6-1']
# MatchIndex :  [6.0]
# AvgIndex 6.0
# AvgIndex2 6.0
# Economy rate :  6.0 	 Avgwicket/match :  1
#
# KK Ahmed
# Wickets :  30 	Matches :  17 	Balls :  399
# MatchStats :  ['3/31-5', '1/25-5', '0/39-4', '3/33-5', '0/27-4', '1/33-4', '3/40-5', '3/42-4', '3/37-5', '3/24-3', '1/29-3', '1/43-5', '0/34-5', '3/24-3', '2/37-4', '2/47-5', '1/31-4']
# MatchIndex :  [1.55, 2.5, 9.75, 1.65, 6.75, 4.125, 2.0, 2.625, 1.85, 2.0, 4.833333333333333, 4.3, 6.8, 2.0, 3.0833333333333335, 3.1333333333333333, 3.875]
# AvgIndex 3.695588235294118
# AvgIndex2 0.2659817351598173
# Economy rate :  7.995098039215685 	 Avgwicket/match :  31
#
# Abhishek Sharma
# Wickets :  3 	Matches :  8 	Balls :  74
# MatchStats :  ['1/10-1', '0/11-2', '1/16-2', '0/11-1', '0/34-5', '0/4-1', '1/16-1', '0/11-1']
# MatchIndex :  [5.0, 5.5, 4.0, 11.0, 6.8, 4.0, 8.0, 11.0]
# AvgIndex 6.9125
# AvgIndex2 2.892
# Economy rate :  9.0375 	 Avgwicket/match :  4
#
# IS Sodhi
# Wickets :  9 	Matches :  8 	Balls :  182
# MatchStats :  ['1/41-5', '1/25-3', '1/15-4', '1/30-4', '1/21-4', '1/31-4', '0/15-4', '3/26-4']
# MatchIndex :  [4.1, 4.166666666666667, 1.875, 3.75, 2.625, 3.875, 3.75, 1.625]
# AvgIndex 3.220833333333333
# AvgIndex2 0.6990867579908675
# Economy rate :  6.379166666666666 	 Avgwicket/match :  10
#
# Arshdeep Singh
# Wickets :  14 	Matches :  11 	Balls :  223
# MatchStats :  ['2/44-5', '1/48-5', '0/25-2', '2/33-5', '2/25-5', '1/20-3', '2/36-4', '0/30-3', '4/23-4', '0/18-3', '0/34-3']
# MatchIndex :  [2.933333333333333, 4.8, 12.5, 2.2, 1.6666666666666667, 3.3333333333333335, 3.0, 10.0, 1.15, 6.0, 11.333333333333334]
# AvgIndex 5.356060606060606
# AvgIndex2 0.5887096774193548
# Economy rate :  8.295454545454545 	 Avgwicket/match :  15
#
# MA Wood
# Wickets :  0 	Matches :  1 	Balls :  25
# MatchStats :  ['0/50-5']
# MatchIndex :  [10.0]
# AvgIndex 10.0
# AvgIndex2 10.0
# Economy rate :  10.0 	 Avgwicket/match :  1
#
# K Khejroliya
# Wickets :  3 	Matches :  5 	Balls :  101
# MatchStats :  ['0/36-5', '2/34-4', '0/40-4', '0/18-1', '1/29-5']
# MatchIndex :  [7.2, 2.8333333333333335, 10.0, 18.0, 2.9]
# AvgIndex 8.186666666666666
# AvgIndex2 3.09375
# Economy rate :  9.9 	 Avgwicket/match :  4
#
# B Laughlin
# Wickets :  9 	Matches :  7 	Balls :  134
# MatchStats :  ['0/20-3', '2/21-2', '1/46-5', '0/37-4', '2/38-5', '2/15-2', '2/35-4']
# MatchIndex :  [6.666666666666667, 3.5, 4.6, 9.25, 2.533333333333333, 2.5, 2.9166666666666665]
# AvgIndex 4.566666666666666
# AvgIndex2 0.9291666666666667
# Economy rate :  8.495238095238095 	 Avgwicket/match :  10
#
# DJM Short
# Wickets :  1 	Matches :  2 	Balls :  18
# MatchStats :  ['0/13-2', '1/10-1']
# MatchIndex :  [6.5, 5.0]
# AvgIndex 5.75
# AvgIndex2 5.5
# Economy rate :  8.25 	 Avgwicket/match :  2
#
# TK Curran
# Wickets :  9 	Matches :  10 	Balls :  180
# MatchStats :  ['2/39-3', '1/21-2', '2/19-3', '0/6-1', '1/33-4', '1/55-5', '1/44-5', '1/37-5', '0/40-4', '0/34-4']
# MatchIndex :  [4.333333333333333, 5.25, 2.111111111111111, 6.0, 4.125, 5.5, 4.4, 3.7, 10.0, 8.5]
# AvgIndex 5.391944444444444
# AvgIndex2 0.9866300366300367
# Economy rate :  8.978333333333333 	 Avgwicket/match :  10
#
# A Dananjaya
# Wickets :  0 	Matches :  1 	Balls :  25
# MatchStats :  ['0/47-5']
# MatchIndex :  [9.4]
# AvgIndex 9.4
# AvgIndex2 9.4
# Economy rate :  9.4 	 Avgwicket/match :  1
#
# Shivam Mavi
# Wickets :  16 	Matches :  17 	Balls :  341
# MatchStats :  ['0/10-1', '1/16-3', '2/40-5', '0/29-4', '2/58-5', '0/22-4', '0/21-4', '1/44-4', '1/33-5', '2/33-5', '0/15-3', '2/21-4', '0/40-3', '1/32-3', '1/24-3', '1/34-4', '2/15-5']
# MatchIndex :  [10.0, 2.6666666666666665, 2.6666666666666665, 7.25, 3.8666666666666667, 5.5, 5.25, 5.5, 3.3, 2.2, 5.0, 1.75, 13.333333333333334, 5.333333333333333, 4.0, 4.25, 1.0]
# AvgIndex 4.874509803921568
# AvgIndex2 0.4794261294261294
# Economy rate :  7.6990196078431365 	 Avgwicket/match :  17
#
# LE Plunkett
# Wickets :  4 	Matches :  7 	Balls :  154
# MatchStats :  ['3/19-5', '0/24-4', '0/52-3', '0/37-3', '1/27-5', '0/42-4', '0/27-4']
# MatchIndex :  [0.95, 6.0, 17.333333333333332, 12.333333333333334, 2.7, 10.5, 6.75]
# AvgIndex 8.08095238095238
# AvgIndex2 2.1419540229885055
# Economy rate :  8.873809523809523 	 Avgwicket/match :  5
#
# MK Tiwary
# Wickets :  0 	Matches :  1 	Balls :  7
# MatchStats :  ['0/10-2']
# MatchIndex :  [5.0]
# AvgIndex 5.0
# AvgIndex2 5.0
# Economy rate :  5.0 	 Avgwicket/match :  1
#
# MK Lomror
# Wickets :  0 	Matches :  2 	Balls :  18
# MatchStats :  ['0/8-1', '0/19-2']
# MatchIndex :  [8.0, 9.5]
# AvgIndex 8.75
# AvgIndex2 17.5
# Economy rate :  8.75 	 Avgwicket/match :  1
#
# L Ngidi
# Wickets :  23 	Matches :  11 	Balls :  267
# MatchStats :  ['1/27-5', '1/36-4', '2/26-5', '2/16-4', '4/11-5', '1/20-4', '2/26-4', '3/38-5', '2/56-5', '2/35-5', '3/40-5']
# MatchIndex :  [2.7, 4.5, 1.7333333333333334, 1.3333333333333333, 0.44, 2.5, 2.1666666666666665, 1.9, 3.7333333333333334, 2.3333333333333335, 2.0]
# AvgIndex 2.3036363636363637
# AvgIndex2 0.27992125984251964
# Economy rate :  6.463636363636363 	 Avgwicket/match :  24
#
# KM Asif
# Wickets :  3 	Matches :  2 	Balls :  38
# MatchStats :  ['2/43-4', '1/32-4']
# MatchIndex :  [3.5833333333333335, 4.0]
# AvgIndex 3.791666666666667
# AvgIndex2 2.6785714285714284
# Economy rate :  9.375 	 Avgwicket/match :  4
#
# DJ Willey
# Wickets :  2 	Matches :  3 	Balls :  61
# MatchStats :  ['1/25-4', '1/47-5', '0/24-2']
# MatchIndex :  [3.125, 4.7, 12.0]
# AvgIndex 6.608333333333333
# AvgIndex2 3.9499999999999997
# Economy rate :  9.216666666666667 	 Avgwicket/match :  3
#
# JPR Scantlebury-Searles
# Wickets :  2 	Matches :  3 	Balls :  45
# MatchStats :  ['1/52-5', '1/24-2', '0/13-1']
# MatchIndex :  [5.2, 6.0, 13.0]
# AvgIndex 8.066666666666666
# AvgIndex2 5.057142857142856
# Economy rate :  11.799999999999999 	 Avgwicket/match :  3
#
# CJ Dala
# Wickets :  0 	Matches :  1 	Balls :  19
# MatchStats :  ['0/34-4']
# MatchIndex :  [8.5]
# AvgIndex 8.5
# AvgIndex2 8.5
# Economy rate :  8.5 	 Avgwicket/match :  1
#
# SE Rutherford
# Wickets :  1 	Matches :  6 	Balls :  46
# MatchStats :  ['0/5-1', '0/16-2', '1/6-1', '0/20-3', '0/2-1', '0/11-2']
# MatchIndex :  [5.0, 8.0, 3.0, 6.666666666666667, 2.0, 5.5]
# AvgIndex 5.027777777777778
# AvgIndex2 4.738095238095238
# Economy rate :  5.527777777777779 	 Avgwicket/match :  2
#
# Harpreet Brar
# Wickets :  0 	Matches :  3 	Balls :  55
# MatchStats :  ['0/24-2', '0/24-3', '0/41-5']
# MatchIndex :  [12.0, 8.0, 8.2]
# AvgIndex 9.4
# AvgIndex2 28.200000000000003
# Economy rate :  9.4 	 Avgwicket/match :  1
#
# Y Prithvi Raj
# Wickets :  1 	Matches :  2 	Balls :  33
# MatchStats :  ['1/29-4', '0/28-3']
# MatchIndex :  [3.625, 9.333333333333334]
# AvgIndex 6.479166666666667
# AvgIndex2 5.527777777777779
# Economy rate :  8.291666666666668 	 Avgwicket/match :  2
#
# O Thomas
# Wickets :  5 	Matches :  4 	Balls :  63
# MatchStats :  ['1/34-5', '2/30-5', '2/8-2', '0/13-1']
# MatchIndex :  [3.4, 2.0, 1.3333333333333333, 13.0]
# AvgIndex 4.933333333333334
# AvgIndex2 1.4190476190476191
# Economy rate :  7.45 	 Avgwicket/match :  6
#
# AS Roy
# Wickets :  1 	Matches :  1 	Balls :  15
# MatchStats :  ['1/11-3']
# MatchIndex :  [1.8333333333333333]
# AvgIndex 1.8333333333333333
# AvgIndex2 1.8333333333333333
# Economy rate :  3.6666666666666665 	 Avgwicket/match :  2
#
# S Sandeep Warrier
# Wickets :  2 	Matches :  4 	Balls :  94
# MatchStats :  ['0/30-4', '2/31-4', '0/25-5', '0/34-4']
# MatchIndex :  [7.5, 2.5833333333333335, 5.0, 8.5]
# AvgIndex 5.895833333333334
# AvgIndex2 3.1944444444444446
# Economy rate :  7.1875 	 Avgwicket/match :  3
#
# JL Pattinson
# Wickets :  11 	Matches :  10 	Balls :  222
# MatchStats :  ['1/27-5', '2/25-5', '0/51-4', '2/28-5', '2/29-5', '2/20-4', '0/37-4', '2/40-4', '0/35-3', '0/29-3']
# MatchIndex :  [2.7, 1.6666666666666667, 12.75, 1.8666666666666667, 1.9333333333333333, 1.6666666666666667, 9.25, 3.3333333333333335, 11.666666666666666, 9.666666666666666]
# AvgIndex 5.65
# AvgIndex2 0.721921921921922
# Economy rate :  8.013333333333334 	 Avgwicket/match :  12
#
# SS Cottrell
# Wickets :  6 	Matches :  6 	Balls :  131
# MatchStats :  ['2/24-5', '2/17-4', '1/52-4', '1/20-5', '0/30-4', '0/34-4']
# MatchIndex :  [1.6, 1.4166666666666667, 6.5, 2.0, 7.5, 8.5]
# AvgIndex 4.586111111111111
# AvgIndex2 1.1364864864864863
# Economy rate :  7.008333333333333 	 Avgwicket/match :  7
#
# Ravi Bishnoi
# Wickets :  14 	Matches :  14 	Balls :  318
# MatchStats :  ['1/22-5', '3/32-5', '0/34-5', '1/37-5', '0/33-5', '3/29-3', '1/25-4', '0/30-4', '1/12-2', '0/25-3', '1/13-4', '2/20-4', '1/27-5', '0/42-5']
# MatchIndex :  [2.2, 1.6, 6.8, 3.7, 6.6, 2.4166666666666665, 3.125, 7.5, 3.0, 8.333333333333334, 1.625, 1.6666666666666667, 2.7, 8.4]
# AvgIndex 4.261904761904762
# AvgIndex2 0.46395939086294424
# Economy rate :  6.528571428571429 	 Avgwicket/match :  15
#
# A Nortje
# Wickets :  23 	Matches :  16 	Balls :  376
# MatchStats :  ['0/37-4', '2/21-5', '0/41-4', '3/38-4', '2/24-5', '1/26-5', '0/28-5', '2/34-4', '2/44-4', '2/27-4', '1/38-5', '4/34-4', '1/25-3', '1/51-4', '0/36-4', '2/25-3']
# MatchIndex :  [9.25, 1.4, 10.25, 2.375, 1.6, 2.6, 5.6, 2.8333333333333335, 3.6666666666666665, 2.25, 3.8, 1.7, 4.166666666666667, 6.375, 9.0, 2.7777777777777777]
# AvgIndex 4.352777777777778
# AvgIndex2 0.3511291779584462
# Economy rate :  8.097916666666666 	 Avgwicket/match :  24
#
# JR Hazlewood
# Wickets :  1 	Matches :  3 	Balls :  61
# MatchStats :  ['0/32-5', '1/23-4', '0/17-2']
# MatchIndex :  [6.4, 2.875, 8.5]
# AvgIndex 5.925
# AvgIndex2 5.1625
# Economy rate :  6.883333333333333 	 Avgwicket/match :  2
#
# JDS Neesham
# Wickets :  2 	Matches :  5 	Balls :  93
# MatchStats :  ['0/13-3', '1/40-4', '0/53-5', '1/17-2', '0/26-4']
# MatchIndex :  [4.333333333333333, 5.0, 10.6, 4.25, 6.5]
# AvgIndex 6.136666666666666
# AvgIndex2 3.63030303030303
# Economy rate :  7.986666666666666 	 Avgwicket/match :  3
#
# KL Nagarkoti
# Wickets :  5 	Matches :  9 	Balls :  160
# MatchStats :  ['0/18-3', '2/13-2', '1/35-4', '1/21-3', '0/40-3', '0/36-4', '0/11-2', '0/34-3', '1/25-5']
# MatchIndex :  [6.0, 2.1666666666666665, 4.375, 3.5, 13.333333333333334, 9.0, 5.5, 11.333333333333334, 2.5]
# AvgIndex 6.412037037037037
# AvgIndex2 1.574275362318841
# Economy rate :  8.046296296296298 	 Avgwicket/match :  6
#
# I Udana
# Wickets :  8 	Matches :  10 	Balls :  182
# MatchStats :  ['2/45-5', '2/41-5', '1/43-5', '1/30-4', '1/19-2', '0/15-3', '0/43-4', '0/6-1', '1/20-3', '0/24-2']
# MatchIndex :  [3.0, 2.7333333333333334, 4.3, 3.75, 4.75, 5.0, 10.75, 6.0, 3.3333333333333335, 12.0]
# AvgIndex 5.5616666666666665
# AvgIndex2 1.027366255144033
# Economy rate :  8.321666666666667 	 Avgwicket/match :  9
#
# Abdul Samad
# Wickets :  1 	Matches :  3 	Balls :  43
# MatchStats :  ['1/41-5', '0/27-2', '0/28-1']
# MatchIndex :  [4.1, 13.5, 28.0]
# AvgIndex 15.200000000000001
# AvgIndex2 12.425
# Economy rate :  16.566666666666666 	 Avgwicket/match :  2
#
# Kartik Tyagi
# Wickets :  10 	Matches :  10 	Balls :  241
# MatchStats :  ['1/37-5', '1/37-5', '1/29-3', '1/30-5', '1/32-5', '2/36-5', '0/42-4', '1/45-4', '0/47-5', '2/37-4']
# MatchIndex :  [3.7, 3.7, 4.833333333333333, 3.0, 3.2, 2.4, 10.5, 5.625, 9.4, 3.0833333333333335]
# AvgIndex 4.944166666666666
# AvgIndex2 0.8363036303630363
# Economy rate :  8.446666666666667 	 Avgwicket/match :  11
#
# TU Deshpande
# Wickets :  3 	Matches :  5 	Balls :  110
# MatchStats :  ['2/37-5', '1/39-5', '0/41-3', '0/40-5', '0/36-3']
# MatchIndex :  [2.466666666666667, 3.9, 13.666666666666666, 8.0, 12.0]
# AvgIndex 8.006666666666666
# AvgIndex2 3.0541666666666667
# Economy rate :  9.773333333333333 	 Avgwicket/match :  4
#
# CJ Green
# Wickets :  0 	Matches :  1 	Balls :  17
# MatchStats :  ['0/24-3']
# MatchIndex :  [8.0]
# AvgIndex 8.0
# AvgIndex2 8.0
# Economy rate :  8.0 	 Avgwicket/match :  1
#
# Shahbaz Ahmed
# Wickets :  2 	Matches :  2 	Balls :  37
# MatchStats :  ['0/18-2', '2/27-5']
# MatchIndex :  [9.0, 1.8]
# AvgIndex 5.4
# AvgIndex2 2.88
# Economy rate :  7.2 	 Avgwicket/match :  3
#
# DR Sams
# Wickets :  0 	Matches :  3 	Balls :  77
# MatchStats :  ['0/30-5', '0/40-5', '0/44-4']
# MatchIndex :  [6.0, 8.0, 11.0]
# AvgIndex 8.333333333333334
# AvgIndex2 25.000000000000004
# Economy rate :  8.333333333333334 	 Avgwicket/match :  1
#
# Monu Kumar
# Wickets :  0 	Matches :  1 	Balls :  16
# MatchStats :  ['0/20-3']
# MatchIndex :  [6.666666666666667]
# AvgIndex 6.666666666666667
# AvgIndex2 6.666666666666667
# Economy rate :  6.666666666666667 	 Avgwicket/match :  1
#
# DA Warner
# Wickets :  0 	Matches :  1 	Balls :  2
# MatchStats :  ['0/2-1']
# MatchIndex :  [2.0]
# AvgIndex 2.0
# AvgIndex2 2.0
# Economy rate :  2.0 	 Avgwicket/match :  1
#
# P Dubey
# Wickets :  0 	Matches :  3 	Balls :  48
# MatchStats :  ['0/29-3', '0/14-2', '0/29-3']
# MatchIndex :  [9.666666666666666, 7.0, 9.666666666666666]
# AvgIndex 8.777777777777777
# AvgIndex2 26.333333333333332
# Economy rate :  8.777777777777777 	 Avgwicket/match :  1

# %%
bowlerdata
# Out:
#             bowler wickets matches balls   A1index   A2index
# 0         RP Singh       3       4    76  4.464583  3.627474
# 1         I Sharma      17      24   516  5.844618  4.150085
# 2         MR Marsh       4       4    59  4.641667  4.931771
# 3         R Bhatia       8      13   251  5.860684  3.641253
# 4         M Ashwin      25      31   623  5.331183  4.304889
# ..             ...     ...     ...   ...       ...       ...
# 207  Shahbaz Ahmed       2       2    37  5.400000  6.750000
# 208        DR Sams       0       3    77  8.333333  0.925926
# 209     Monu Kumar       0       1    16  6.666667  6.666667
# 210      DA Warner       0       1     2  2.000000  2.000000
# 211        P Dubey       0       3    48  8.777778  0.975309
#
# [212 rows x 6 columns]

# %% [markdown]
# ### Seasons fron 2019

# %%
batsman_list = list(indexdata19to20['striker'].unique())
bowler_list = list(indexdata19to20['bowler'].unique())

# %%
for batsman in batsman_list:
  runs = indexdata19to20[indexdata19to20['striker']==batsman]['runs_off_bat'].sum()
  matches = len(indexdata19to20[indexdata19to20['striker']==batsman]['match_id'].unique())
  balls = len(indexdata19to20[indexdata19to20['striker']==batsman])
  print(batsman,"\nRuns : ",runs,'\tMatches : ',matches,'\tBalls : ',balls)
# Out:
# LMP Simmons
# Runs :  145 	Matches :  8 	Balls :  124
# RG Sharma
# Runs :  1845 	Matches :  71 	Balls :  1464
# HH Pandya
# Runs :  1237 	Matches :  66 	Balls :  829
# JC Buttler
# Runs :  1714 	Matches :  57 	Balls :  1184
# AT Rayudu
# Runs :  1668 	Matches :  61 	Balls :  1370
# KA Pollard
# Runs :  1272 	Matches :  60 	Balls :  883
# S Gopal
# Runs :  152 	Matches :  17 	Balls :  150
# Harbhajan Singh
# Runs :  138 	Matches :  18 	Balls :  149
# R Vinay Kumar
# Runs :  19 	Matches :  3 	Balls :  16
# MJ McClenaghan
# Runs :  72 	Matches :  17 	Balls :  67
# AM Rahane
# Runs :  1738 	Matches :  65 	Balls :  1438
# F du Plessis
# Runs :  1221 	Matches :  38 	Balls :  961
# KP Pietersen
# Runs :  73 	Matches :  4 	Balls :  61
# MA Agarwal
# Runs :  929 	Matches :  41 	Balls :  673
# Q de Kock
# Runs :  1678 	Matches :  53 	Balls :  1273
# SS Iyer
# Runs :  1761 	Matches :  64 	Balls :  1442
# KK Nair
# Runs :  960 	Matches :  41 	Balls :  778
# SV Samson
# Runs :  1835 	Matches :  68 	Balls :  1345
# P Negi
# Runs :  213 	Matches :  22 	Balls :  194
# CR Brathwaite
# Runs :  181 	Matches :  14 	Balls :  120
# CH Morris
# Runs :  461 	Matches :  29 	Balls :  296
# NM Coulter-Nile
# Runs :  48 	Matches :  7 	Balls :  42
# A Mishra
# Runs :  75 	Matches :  13 	Balls :  98
# Z Khan
# Runs :  10 	Matches :  5 	Balls :  26
# RV Uthappa
# Runs :  1611 	Matches :  67 	Balls :  1237
# G Gambhir
# Runs :  1084 	Matches :  36 	Balls :  920
# MK Pandey
# Runs :  1697 	Matches :  62 	Balls :  1379
# M Vijay
# Runs :  561 	Matches :  20 	Balls :  489
# M Vohra
# Runs :  445 	Matches :  20 	Balls :  356
# DA Miller
# Runs :  531 	Matches :  30 	Balls :  461
# GJ Maxwell
# Runs :  766 	Matches :  46 	Balls :  549
# WP Saha
# Runs :  926 	Matches :  42 	Balls :  730
# MP Stoinis
# Runs :  825 	Matches :  42 	Balls :  623
# AR Patel
# Runs :  645 	Matches :  52 	Balls :  503
# AJ Finch
# Runs :  1094 	Matches :  46 	Balls :  853
# BB McCullum
# Runs :  800 	Matches :  33 	Balls :  587
# SK Raina
# Runs :  1669 	Matches :  61 	Balls :  1306
# KD Karthik
# Runs :  1616 	Matches :  70 	Balls :  1204
# RA Jadeja
# Runs :  776 	Matches :  53 	Balls :  623
# Ishan Kishan
# Runs :  1211 	Matches :  46 	Balls :  907
# DJ Bravo
# Runs :  327 	Matches :  32 	Balls :  255
# CH Gayle
# Runs :  1573 	Matches :  50 	Balls :  1153
# V Kohli
# Runs :  2741 	Matches :  69 	Balls :  2029
# AB de Villiers
# Runs :  2279 	Matches :  63 	Balls :  1452
# SR Watson
# Runs :  1502 	Matches :  65 	Balls :  1158
# KM Jadhav
# Runs :  557 	Matches :  34 	Balls :  490
# SN Khan
# Runs :  330 	Matches :  18 	Balls :  249
# DA Warner
# Runs :  2729 	Matches :  59 	Balls :  1959
# S Dhawan
# Runs :  2616 	Matches :  80 	Balls :  2024
# MC Henriques
# Runs :  459 	Matches :  26 	Balls :  367
# NV Ojha
# Runs :  216 	Matches :  19 	Balls :  216
# DJ Hooda
# Runs :  474 	Matches :  41 	Balls :  405
# EJG Morgan
# Runs :  606 	Matches :  24 	Balls :  479
# A Ashish Reddy
# Runs :  47 	Matches :  3 	Balls :  30
# KV Sharma
# Runs :  85 	Matches :  9 	Balls :  76
# AD Russell
# Runs :  1131 	Matches :  44 	Balls :  657
# YK Pathan
# Runs :  804 	Matches :  44 	Balls :  637
# C Munro
# Runs :  177 	Matches :  11 	Balls :  144
# SA Yadav
# Runs :  1703 	Matches :  62 	Balls :  1295
# PA Patel
# Runs :  1098 	Matches :  46 	Balls :  851
# SPD Smith
# Runs :  1372 	Matches :  46 	Balls :  1114
# MS Dhoni
# Runs :  1645 	Matches :  66 	Balls :  1294
# MR Marsh
# Runs :  7 	Matches :  2 	Balls :  12
# R Bhatia
# Runs :  50 	Matches :  6 	Balls :  37
# SE Marsh
# Runs :  423 	Matches :  14 	Balls :  332
# MG Johnson
# Runs :  41 	Matches :  6 	Balls :  42
# MM Sharma
# Runs :  93 	Matches :  17 	Balls :  94
# P Sahu
# Runs :  19 	Matches :  2 	Balls :  13
# Sandeep Sharma
# Runs :  33 	Matches :  16 	Balls :  39
# B Kumar
# Runs :  72 	Matches :  19 	Balls :  71
# KH Pandya
# Runs :  1000 	Matches :  57 	Balls :  727
# TG Southee
# Runs :  98 	Matches :  10 	Balls :  78
# AD Nath
# Runs :  90 	Matches :  10 	Balls :  99
# JP Faulkner
# Runs :  131 	Matches :  11 	Balls :  120
# P Kumar
# Runs :  32 	Matches :  8 	Balls :  36
# DS Kulkarni
# Runs :  42 	Matches :  10 	Balls :  30
# NLTC Perera
# Runs :  150 	Matches :  10 	Balls :  97
# IK Pathan
# Runs :  13 	Matches :  4 	Balls :  17
# R Ashwin
# Runs :  222 	Matches :  25 	Balls :  176
# D Wiese
# Runs :  5 	Matches :  1 	Balls :  4
# JP Duminy
# Runs :  227 	Matches :  10 	Balls :  203
# MJ Guptill
# Runs :  270 	Matches :  13 	Balls :  196
# KJ Abbott
# Runs :  13 	Matches :  3 	Balls :  8
# Shakib Al Hasan
# Runs :  363 	Matches :  22 	Balls :  323
# KL Rahul
# Runs :  2319 	Matches :  54 	Balls :  1675
# TM Head
# Runs :  205 	Matches :  10 	Balls :  151
# STR Binny
# Runs :  255 	Matches :  22 	Balls :  199
# KW Richardson
# Runs :  1 	Matches :  1 	Balls :  1
# DW Steyn
# Runs :  2 	Matches :  2 	Balls :  4
# Ankit Sharma
# Runs :  28 	Matches :  2 	Balls :  19
# M Ashwin
# Runs :  8 	Matches :  6 	Balls :  12
# NS Naik
# Runs :  31 	Matches :  4 	Balls :  53
# R Dhawan
# Runs :  14 	Matches :  2 	Balls :  6
# AP Tare
# Runs :  26 	Matches :  5 	Balls :  40
# DR Smith
# Runs :  563 	Matches :  23 	Balls :  384
# JA Morkel
# Runs :  16 	Matches :  1 	Balls :  9
# R Sathish
# Runs :  24 	Matches :  3 	Balls :  24
# PP Chawla
# Runs :  98 	Matches :  14 	Balls :  106
# UT Yadav
# Runs :  47 	Matches :  17 	Balls :  59
# Bipul Sharma
# Runs :  82 	Matches :  7 	Balls :  50
# RR Pant
# Runs :  2079 	Matches :  68 	Balls :  1416
# CA Lynn
# Runs :  1216 	Matches :  38 	Balls :  876
# SS Tiwary
# Runs :  325 	Matches :  13 	Balls :  276
# SW Billings
# Runs :  334 	Matches :  19 	Balls :  256
# Mohammed Shami
# Runs :  48 	Matches :  13 	Balls :  39
# JO Holder
# Runs :  88 	Matches :  8 	Balls :  74
# SP Narine
# Runs :  852 	Matches :  50 	Balls :  529
# KS Williamson
# Runs :  1588 	Matches :  50 	Balls :  1193
# Sachin Baby
# Runs :  134 	Matches :  9 	Balls :  99
# Parvez Rasool
# Runs :  10 	Matches :  1 	Balls :  9
# Gurkeerat Singh
# Runs :  282 	Matches :  14 	Balls :  243
# KC Cariappa
# Runs :  24 	Matches :  5 	Balls :  21
# PSP Handscomb
# Runs :  6 	Matches :  1 	Balls :  12
# Swapnil Singh
# Runs :  12 	Matches :  3 	Balls :  20
# J Yadav
# Runs :  6 	Matches :  2 	Balls :  12
# UT Khawaja
# Runs :  127 	Matches :  6 	Balls :  105
# Yuvraj Singh
# Runs :  651 	Matches :  31 	Balls :  528
# GJ Bailey
# Runs :  84 	Matches :  5 	Balls :  99
# HM Amla
# Runs :  577 	Matches :  16 	Balls :  418
# JJ Bumrah
# Runs :  39 	Matches :  9 	Balls :  38
# F Behardien
# Runs :  14 	Matches :  3 	Balls :  13
# BB Sran
# Runs :  10 	Matches :  7 	Balls :  14
# A Zampa
# Runs :  5 	Matches :  2 	Balls :  8
# N Rana
# Runs :  1437 	Matches :  55 	Balls :  1093
# A Nehra
# Runs :  1 	Matches :  1 	Balls :  1
# UBT Chand
# Runs :  0 	Matches :  1 	Balls :  5
# PV Tambe
# Runs :  7 	Matches :  1 	Balls :  19
# S Kaushik
# Runs :  0 	Matches :  1 	Balls :  1
# BCJ Cutting
# Runs :  230 	Matches :  16 	Balls :  140
# S Nadeem
# Runs :  16 	Matches :  7 	Balls :  30
# Imran Tahir
# Runs :  20 	Matches :  4 	Balls :  21
# M Morkel
# Runs :  1 	Matches :  1 	Balls :  1
# ER Dwivedi
# Runs :  24 	Matches :  2 	Balls :  15
# SB Jakati
# Runs :  1 	Matches :  1 	Balls :  2
# Iqbal Abdulla
# Runs :  42 	Matches :  3 	Balls :  34
# CJ Jordan
# Runs :  32 	Matches :  6 	Balls :  38
# Mandeep Singh
# Runs :  735 	Matches :  42 	Balls :  604
# S Aravind
# Runs :  32 	Matches :  6 	Balls :  40
# YS Chahal
# Runs :  20 	Matches :  12 	Balls :  51
# TS Mills
# Runs :  8 	Matches :  3 	Balls :  11
# A Choudhary
# Runs :  25 	Matches :  3 	Balls :  20
# BA Stokes
# Runs :  920 	Matches :  40 	Balls :  700
# JJ Roy
# Runs :  179 	Matches :  8 	Balls :  139
# Vishnu Vinod
# Runs :  19 	Matches :  3 	Balls :  26
# PJ Cummins
# Runs :  223 	Matches :  18 	Balls :  174
# MK Tiwary
# Runs :  371 	Matches :  17 	Balls :  287
# DT Christian
# Runs :  105 	Matches :  12 	Balls :  85
# Basil Thampi
# Runs :  32 	Matches :  7 	Balls :  37
# CR Woakes
# Runs :  63 	Matches :  11 	Balls :  66
# CJ Anderson
# Runs :  159 	Matches :  14 	Balls :  152
# RA Tripathi
# Runs :  988 	Matches :  44 	Balls :  756
# DL Chahar
# Runs :  78 	Matches :  10 	Balls :  58
# AB Dinda
# Runs :  7 	Matches :  1 	Balls :  8
# V Shankar
# Runs :  654 	Matches :  32 	Balls :  528
# Rashid Khan
# Runs :  139 	Matches :  23 	Balls :  99
# VR Aaron
# Runs :  8 	Matches :  5 	Balls :  28
# SN Thakur
# Runs :  41 	Matches :  8 	Balls :  36
# RD Chahar
# Runs :  17 	Matches :  6 	Balls :  17
# LH Ferguson
# Runs :  44 	Matches :  3 	Balls :  30
# C de Grandhomme
# Runs :  303 	Matches :  21 	Balls :  229
# JD Unadkat
# Runs :  61 	Matches :  9 	Balls :  59
# AF Milne
# Runs :  7 	Matches :  3 	Balls :  12
# S Badree
# Runs :  13 	Matches :  5 	Balls :  25
# AD Mathews
# Runs :  32 	Matches :  2 	Balls :  28
# Mohammad Nabi
# Runs :  146 	Matches :  11 	Balls :  102
# I Sharma
# Runs :  18 	Matches :  4 	Balls :  16
# AJ Tye
# Runs :  91 	Matches :  13 	Balls :  79
# K Rabada
# Runs :  125 	Matches :  13 	Balls :  135
# Kuldeep Yadav
# Runs :  57 	Matches :  10 	Balls :  76
# Washington Sundar
# Runs :  186 	Matches :  21 	Balls :  154
# DM Bravo
# Runs :  6 	Matches :  1 	Balls :  5
# AR Bawne
# Runs :  12 	Matches :  1 	Balls :  12
# SP Jackson
# Runs :  38 	Matches :  3 	Balls :  31
# Anureet Singh
# Runs :  18 	Matches :  2 	Balls :  16
# Ankit Soni
# Runs :  7 	Matches :  3 	Balls :  9
# SL Malinga
# Runs :  7 	Matches :  2 	Balls :  3
# PJ Sangwan
# Runs :  2 	Matches :  4 	Balls :  9
# S Kaul
# Runs :  3 	Matches :  5 	Balls :  17
# MN Samuels
# Runs :  29 	Matches :  4 	Balls :  32
# R Tewatia
# Runs :  350 	Matches :  22 	Balls :  267
# MM Patel
# Runs :  0 	Matches :  1 	Balls :  1
# TA Boult
# Runs :  12 	Matches :  5 	Balls :  15
# IR Jaggi
# Runs :  33 	Matches :  2 	Balls :  40
# AS Rajpoot
# Runs :  24 	Matches :  6 	Balls :  35
# MM Ali
# Runs :  309 	Matches :  17 	Balls :  199
# SO Hetmyer
# Runs :  275 	Matches :  16 	Balls :  203
# S Dube
# Runs :  169 	Matches :  13 	Balls :  142
# NA Saini
# Runs :  29 	Matches :  5 	Balls :  31
# Mohammed Siraj
# Runs :  46 	Matches :  9 	Balls :  52
# JM Bairstow
# Runs :  790 	Matches :  21 	Balls :  576
# Shubman Gill
# Runs :  939 	Matches :  37 	Balls :  766
# PP Shaw
# Runs :  826 	Matches :  38 	Balls :  605
# CA Ingram
# Runs :  184 	Matches :  12 	Balls :  157
# KMA Paul
# Runs :  18 	Matches :  5 	Balls :  26
# Rasikh Salam
# Runs :  5 	Matches :  1 	Balls :  4
# N Pooran
# Runs :  521 	Matches :  20 	Balls :  323
# K Gowtham
# Runs :  186 	Matches :  19 	Balls :  113
# JC Archer
# Runs :  195 	Matches :  21 	Balls :  128
# M Markande
# Runs :  27 	Matches :  7 	Balls :  30
# GH Vihari
# Runs :  4 	Matches :  2 	Balls :  8
# P Ray Barman
# Runs :  19 	Matches :  1 	Balls :  25
# SM Curran
# Runs :  281 	Matches :  19 	Balls :  200
# GC Viljoen
# Runs :  3 	Matches :  3 	Balls :  7
# HV Patel
# Runs :  81 	Matches :  5 	Balls :  61
# Avesh Khan
# Runs :  4 	Matches :  1 	Balls :  3
# S Lamichhane
# Runs :  0 	Matches :  1 	Balls :  1
# M Prasidh Krishna
# Runs :  3 	Matches :  4 	Balls :  11
# HF Gurney
# Runs :  1 	Matches :  1 	Balls :  5
# SD Lad
# Runs :  15 	Matches :  1 	Balls :  13
# AS Joseph
# Runs :  15 	Matches :  1 	Balls :  13
# R Parag
# Runs :  246 	Matches :  13 	Balls :  214
# MJ Santner
# Runs :  32 	Matches :  2 	Balls :  25
# JL Denly
# Runs :  0 	Matches :  1 	Balls :  1
# LS Livingstone
# Runs :  70 	Matches :  4 	Balls :  48
# RK Bhui
# Runs :  7 	Matches :  2 	Balls :  18
# Abhishek Sharma
# Runs :  143 	Matches :  13 	Balls :  104
# KK Ahmed
# Runs :  0 	Matches :  2 	Balls :  3
# Mujeeb Ur Rahman
# Runs :  11 	Matches :  5 	Balls :  14
# AJ Turner
# Runs :  3 	Matches :  4 	Balls :  11
# E Lewis
# Runs :  430 	Matches :  16 	Balls :  343
# MA Wood
# Runs :  1 	Matches :  1 	Balls :  5
# RK Singh
# Runs :  77 	Matches :  8 	Balls :  79
# DJM Short
# Runs :  115 	Matches :  7 	Balls :  102
# B Laughlin
# Runs :  1 	Matches :  2 	Balls :  4
# TK Curran
# Runs :  106 	Matches :  8 	Balls :  91
# B Stanlake
# Runs :  5 	Matches :  1 	Balls :  2
# A Dananjaya
# Runs :  4 	Matches :  1 	Balls :  5
# Shivam Mavi
# Runs :  23 	Matches :  6 	Balls :  29
# H Klaasen
# Runs :  66 	Matches :  6 	Balls :  58
# LE Plunkett
# Runs :  1 	Matches :  2 	Balls :  3
# Mustafizur Rahman
# Runs :  1 	Matches :  1 	Balls :  3
# AD Hales
# Runs :  148 	Matches :  6 	Balls :  119
# MK Lomror
# Runs :  87 	Matches :  6 	Balls :  78
# DR Shorey
# Runs :  13 	Matches :  2 	Balls :  20
# P Chopra
# Runs :  8 	Matches :  1 	Balls :  6
# JPR Scantlebury-Searles
# Runs :  8 	Matches :  2 	Balls :  6
# IS Sodhi
# Runs :  7 	Matches :  2 	Balls :  18
# SP Goswami
# Runs :  52 	Matches :  5 	Balls :  47
# Harpreet Brar
# Runs :  20 	Matches :  1 	Balls :  14
# SE Rutherford
# Runs :  73 	Matches :  7 	Balls :  55
# Y Prithvi Raj
# Runs :  0 	Matches :  1 	Balls :  1
# P Simran Singh
# Runs :  31 	Matches :  3 	Balls :  33
# J Suchith
# Runs :  6 	Matches :  1 	Balls :  15
# JL Pattinson
# Runs :  15 	Matches :  2 	Balls :  13
# A Nortje
# Runs :  7 	Matches :  3 	Balls :  6
# D Padikkal
# Runs :  473 	Matches :  15 	Balls :  398
# JR Philippe
# Runs :  78 	Matches :  5 	Balls :  80
# PK Garg
# Runs :  133 	Matches :  10 	Balls :  116
# T Natarajan
# Runs :  3 	Matches :  2 	Balls :  5
# YBK Jaiswal
# Runs :  40 	Matches :  3 	Balls :  44
# RD Gaikwad
# Runs :  204 	Matches :  6 	Balls :  173
# KL Nagarkoti
# Runs :  22 	Matches :  6 	Balls :  32
# Abdul Samad
# Runs :  111 	Matches :  7 	Balls :  66
# JDS Neesham
# Runs :  19 	Matches :  3 	Balls :  18
# Ravi Bishnoi
# Runs :  7 	Matches :  2 	Balls :  12
# I Udana
# Runs :  15 	Matches :  4 	Balls :  11
# CV Varun
# Runs :  10 	Matches :  3 	Balls :  16
# SS Cottrell
# Runs :  0 	Matches :  1 	Balls :  2
# Arshdeep Singh
# Runs :  0 	Matches :  1 	Balls :  3
# Kartik Tyagi
# Runs :  4 	Matches :  2 	Balls :  6
# N Jagadeesan
# Runs :  33 	Matches :  2 	Balls :  31
# AT Carey
# Runs :  32 	Matches :  3 	Balls :  29
# T Banton
# Runs :  18 	Matches :  2 	Balls :  22
# TU Deshpande
# Runs :  21 	Matches :  2 	Balls :  12
# Shahbaz Ahmed
# Runs :  1 	Matches :  1 	Balls :  1
# P Dubey
# Runs :  7 	Matches :  1 	Balls :  13
# DR Sams
# Runs :  0 	Matches :  1 	Balls :  2

# %%
import math
for bowler in bowler_list:
  wickets = len(indexdata19to20[(indexdata19to20['bowler']==bowler) & (indexdata19to20['player_dismissed']!='notout')])
  matches = len(indexdata19to20[indexdata19to20['bowler']==bowler]['match_id'].unique())
  bowler_matches = list(indexdata19to20[indexdata19to20['bowler']==bowler]['match_id'].unique())
  match_stats = list()
  match_index = list()
  match_index2 = list()
  for bowlmatch in bowler_matches:
    match_wickets = len(indexdata19to20[(indexdata19to20['bowler']==bowler) & (indexdata19to20['match_id']==bowlmatch) & (indexdata19to20['player_dismissed']!='notout')])
    match_runs = indexdata19to20[(indexdata19to20['bowler']==bowler) & (indexdata19to20['match_id']==bowlmatch)]['runs_off_bat'].sum() + indexdata19to20[(indexdata19to20['bowler']==bowler) & (indexdata19to20['match_id']==bowlmatch)]['extras'].sum()
    balls = len(indexdata19to20[(indexdata19to20['bowler']==bowler) & (indexdata19to20['match_id']==bowlmatch)])
    data = str(match_wickets)+'/'+str(match_runs)+'-'+str(math.ceil(balls/6))
    match_stats.append(data)
    match_index.append(match_runs/((math.ceil(balls/6))*(match_wickets+1)))
    match_index2.append(match_runs/math.ceil(balls/6))
  balls = len(indexdata19to20[indexdata19to20['bowler']==bowler])
  print(bowler,"\nWickets : ",wickets,'\tMatches : ',matches,'\tBalls : ',balls,'\nMatchStats : ',match_stats ,'\nMatchIndex : ',match_index,'\nAvgIndex',sum(match_index)/len(match_index),'\nAvgIndex2', (sum(match_index)/len(match_index) )/(len(match_index2) / (wickets+1/matches)))
  print()
# Out:
# RP Singh
# Wickets :  3 	Matches :  4 	Balls :  76
# MatchStats :  ['1/30-4', '0/22-3', '1/39-5', '1/23-4']
# MatchIndex :  [3.75, 7.333333333333333, 3.9, 2.875]
# AvgIndex 4.464583333333334
# AvgIndex2 3.6274739583333333
#
# I Sharma
# Wickets :  17 	Matches :  24 	Balls :  516
# MatchStats :  ['2/37-5', '1/41-4', '0/26-3', '0/47-5', '0/21-3', '0/25-5', '0/60-4', '0/42-4', '0/30-4', '0/12-1', '3/35-4', '1/32-3', '1/5-2', '0/32-5', '1/22-5', '0/19-4', '0/18-3', '0/29-5', '1/30-4', '1/41-4', '3/38-5', '2/35-4', '1/28-4', '0/26-4']
# MatchIndex :  [2.466666666666667, 5.125, 8.666666666666666, 9.4, 7.0, 5.0, 15.0, 10.5, 7.5, 12.0, 2.1875, 5.333333333333333, 1.25, 6.4, 2.2, 4.75, 6.0, 5.8, 3.75, 5.125, 1.9, 2.9166666666666665, 3.5, 6.5]
# AvgIndex 5.844618055555556
# AvgIndex2 4.150084695698303
#
# MR Marsh
# Wickets :  4 	Matches :  4 	Balls :  59
# MatchStats :  ['2/21-5', '0/10-1', '2/14-4', '0/6-1']
# MatchIndex :  [1.4, 10.0, 1.1666666666666667, 6.0]
# AvgIndex 4.641666666666667
# AvgIndex2 4.931770833333333
#
# R Bhatia
# Wickets :  8 	Matches :  13 	Balls :  251
# MatchStats :  ['1/10-4', '0/31-4', '0/22-3', '2/19-4', '0/24-4', '1/26-3', '0/21-3', '2/22-5', '0/47-4', '0/27-3', '2/14-3', '0/20-3', '0/21-2']
# MatchIndex :  [1.25, 7.75, 7.333333333333333, 1.5833333333333333, 6.0, 4.333333333333333, 7.0, 1.4666666666666666, 11.75, 9.0, 1.5555555555555556, 6.666666666666667, 10.5]
# AvgIndex 5.860683760683761
# AvgIndex2 3.641253224093461
#
# M Ashwin
# Wickets :  25 	Matches :  31 	Balls :  623
# MatchStats :  ['1/16-4', '2/34-5', '3/36-4', '0/29-2', '1/32-5', '0/6-1', '0/22-3', '0/25-3', '0/32-3', '0/13-2', '2/26-4', '0/19-2', '0/23-5', '0/24-4', '1/24-5', '2/37-5', '1/17-4', '0/21-4', '1/31-4', '1/32-5', '0/24-2', '0/33-3', '3/22-4', '1/16-2', '2/23-4', '0/32-3', '1/33-5', '1/27-4', '1/27-4', '1/43-4', '0/17-4']
# MatchIndex :  [2.0, 2.2666666666666666, 2.25, 14.5, 3.2, 6.0, 7.333333333333333, 8.333333333333334, 10.666666666666666, 6.5, 2.1666666666666665, 9.5, 4.6, 6.0, 2.4, 2.466666666666667, 2.125, 5.25, 3.875, 3.2, 12.0, 11.0, 1.375, 4.0, 1.9166666666666667, 10.666666666666666, 3.3, 3.375, 3.375, 5.375, 4.25]
# AvgIndex 5.331182795698925
# AvgIndex2 4.304888501001421
#
# R Ashwin
# Wickets :  54 	Matches :  57 	Balls :  1246
# MatchStats :  ['1/7-1', '0/26-5', '0/27-4', '0/22-4', '0/21-3', '1/15-4', '0/37-5', '1/21-3', '1/34-5', '0/7-1', '1/16-5', '2/31-3', '0/23-5', '4/34-4', '2/20-4', '0/47-5', '0/26-5', '2/31-5', '3/23-5', '2/30-4', '1/37-4', '1/30-5', '2/24-5', '1/23-5', '2/30-4', '1/33-5', '0/53-5', '1/33-5', '1/19-4', '0/34-4', '0/23-4', '1/30-4', '0/34-4', '0/36-3', '0/9-1', '2/18-3', '2/36-5', '0/26-4', '1/15-4', '2/30-5', '1/38-5', '0/23-4', '2/2-1', '0/26-3', '1/26-5', '2/22-5', '1/35-4', '1/17-4', '0/30-3', '2/28-5', '0/45-3', '1/35-3', '1/18-4', '0/18-4', '3/29-4', '0/34-4', '1/28-4']
# MatchIndex :  [3.5, 5.2, 6.75, 5.5, 7.0, 1.875, 7.4, 3.5, 3.4, 7.0, 1.6, 3.4444444444444446, 4.6, 1.7, 1.6666666666666667, 9.4, 5.2, 2.066666666666667, 1.15, 2.5, 4.625, 3.0, 1.6, 2.3, 2.5, 3.3, 10.6, 3.3, 2.375, 8.5, 5.75, 3.75, 8.5, 12.0, 9.0, 2.0, 2.4, 6.5, 1.875, 2.0, 3.8, 5.75, 0.6666666666666666, 8.666666666666666, 2.6, 1.4666666666666666, 4.375, 2.125, 10.0, 1.8666666666666667, 15.0, 5.833333333333333, 2.25, 4.5, 1.8125, 8.5, 3.5]
# AvgIndex 4.61474171539961
# AvgIndex2 4.373280930044753
#
# MJ McClenaghan
# Wickets :  57 	Matches :  44 	Balls :  1041
# MatchStats :  ['0/27-3', '2/25-5', '4/26-4', '0/33-4', '1/48-4', '2/32-5', '2/32-5', '1/33-4', '1/27-5', '1/39-5', '1/37-5', '2/24-4', '1/27-4', '0/39-4', '1/36-4', '1/52-5', '1/42-4', '2/20-5', '2/24-5', '2/47-5', '3/25-5', '0/37-5', '0/50-5', '4/34-4', '1/18-2', '1/26-5', '1/54-5', '1/47-5', '3/40-4', '0/24-2', '0/35-5', '1/44-5', '2/24-3', '1/32-4', '3/26-4', '2/26-4', '2/35-5', '1/31-5', '1/30-4', '1/24-3', '0/29-5', '2/39-5', '0/20-5', '0/24-5']
# MatchIndex :  [9.0, 1.6666666666666667, 1.3, 8.25, 6.0, 2.1333333333333333, 2.1333333333333333, 4.125, 2.7, 3.9, 3.7, 2.0, 3.375, 9.75, 4.5, 5.2, 5.25, 1.3333333333333333, 1.6, 3.1333333333333333, 1.25, 7.4, 10.0, 1.7, 4.5, 2.6, 5.4, 4.7, 2.5, 12.0, 7.0, 4.4, 2.6666666666666665, 4.0, 1.625, 2.1666666666666665, 2.3333333333333335, 3.1, 3.75, 4.0, 5.8, 2.6, 4.0, 4.8]
# AvgIndex 4.212310606060607
# AvgIndex2 5.459032701759329
#
# JJ Bumrah
# Wickets :  107 	Matches :  75 	Balls :  1770
# MatchStats :  ['0/30-4', '1/32-4', '2/32-5', '0/19-4', '4/31-4', '0/42-5', '3/27-4', '0/35-4', '3/30-4', '0/35-4', '1/30-4', '0/14-3', '3/14-4', '1/42-5', '0/29-4', '1/39-5', '3/24-4', '1/40-5', '0/46-5', '1/31-5', '2/21-5', '2/30-4', '3/32-5', '1/34-4', '1/6-1', '1/24-4', '1/25-4', '1/34-4', '3/7-3', '2/27-4', '1/41-4', '4/21-5', '0/23-4', '0/28-5', '1/16-3', '1/39-5', '2/24-4', '0/24-4', '1/37-5', '2/32-4', '0/27-4', '2/29-5', '2/28-5', '1/25-4', '0/26-5', '1/22-4', '1/20-4', '1/42-4', '1/17-3', '1/34-4', '3/15-5', '1/29-5', '3/19-4', '1/22-4', '2/11-4', '0/45-5', '2/31-4', '2/31-5', '0/31-5', '2/19-4', '1/43-5', '2/34-5', '0/48-5', '2/19-4', '2/44-5', '4/20-4', '0/26-4', '1/22-5', '3/24-5', '2/26-4', '0/40-5', '3/14-5', '4/17-5', '4/14-5', '0/29-4']
# MatchIndex :  [7.5, 4.0, 2.1333333333333333, 4.75, 1.55, 8.4, 1.6875, 8.75, 1.875, 8.75, 3.75, 4.666666666666667, 0.875, 4.2, 7.25, 3.9, 1.5, 4.0, 9.2, 3.1, 1.4, 2.5, 1.6, 4.25, 3.0, 3.0, 3.125, 4.25, 0.5833333333333334, 2.25, 5.125, 0.84, 5.75, 5.6, 2.6666666666666665, 3.9, 2.0, 6.0, 3.7, 2.6666666666666665, 6.75, 1.9333333333333333, 1.8666666666666667, 3.125, 5.2, 2.75, 2.5, 5.25, 2.8333333333333335, 4.25, 0.75, 2.9, 1.1875, 2.75, 0.9166666666666666, 9.0, 2.5833333333333335, 2.066666666666667, 6.2, 1.5833333333333333, 4.3, 2.2666666666666666, 9.6, 1.5833333333333333, 2.933333333333333, 1.0, 6.5, 2.2, 1.2, 2.1666666666666665, 8.0, 0.7, 0.68, 0.56, 7.25]
# AvgIndex 3.6450666666666667
# AvgIndex2 5.200943122962963
#
# R Vinay Kumar
# Wickets :  8 	Matches :  6 	Balls :  102
# MatchStats :  ['0/14-3', '2/33-4', '2/18-3', '2/31-4', '2/30-2', '0/35-3']
# MatchIndex :  [4.666666666666667, 2.75, 2.0, 2.5833333333333335, 5.0, 11.666666666666666]
# AvgIndex 4.777777777777778
# AvgIndex2 6.503086419753086
#
# S Gopal
# Wickets :  42 	Matches :  39 	Balls :  800
# MatchStats :  ['0/19-3', '0/5-1', '3/27-4', '0/23-3', '3/12-4', '2/36-4', '0/31-4', '0/21-4', '0/32-4', '0/18-3', '2/24-4', '1/24-3', '3/20-5', '0/30-3', '1/26-2', '0/26-3', '0/21-2', '4/16-4', '1/34-4', '2/21-4', '2/47-5', '1/32-3', '2/30-4', '3/12-1', '2/21-4', '1/38-4', '0/44-5', '0/43-4', '1/27-4', '2/29-4', '0/23-2', '0/31-4', '1/31-5', '1/33-5', '1/14-4', '0/32-4', '2/30-4', '0/10-1', '1/44-4']
# MatchIndex :  [6.333333333333333, 5.0, 1.6875, 7.666666666666667, 0.75, 3.0, 7.75, 5.25, 8.0, 6.0, 2.0, 4.0, 1.0, 10.0, 6.5, 8.666666666666666, 10.5, 0.8, 4.25, 1.75, 3.1333333333333333, 5.333333333333333, 2.5, 3.0, 1.75, 4.75, 8.8, 10.75, 3.375, 2.4166666666666665, 11.5, 7.75, 3.1, 3.3, 1.75, 8.0, 2.5, 10.0, 5.5]
# AvgIndex 5.131089743589744
# AvgIndex2 5.529162452165411
#
# Harbhajan Singh
# Wickets :  42 	Matches :  48 	Balls :  1009
# MatchStats :  ['1/24-3', '1/33-4', '0/20-2', '0/39-5', '0/20-3', '1/25-3', '0/31-4', '1/32-4', '1/25-5', '2/29-5', '0/19-3', '0/35-4', '1/34-4', '1/36-4', '0/27-4', '2/24-4', '0/25-4', '1/22-4', '0/12-2', '0/26-4', '1/20-4', '1/23-5', '3/22-4', '0/23-4', '0/45-3', '4/22-4', '0/30-5', '2/17-4', '3/15-4', '0/14-2', '1/11-2', '1/41-4', '0/24-2', '1/20-4', '0/26-5', '1/20-3', '2/22-4', '1/29-2', '0/26-3', '0/24-2', '0/13-1', '2/39-4', '0/23-4', '1/28-4', '3/58-5', '1/25-5', '2/31-4', '0/27-5']
# MatchIndex :  [4.0, 4.125, 10.0, 7.8, 6.666666666666667, 4.166666666666667, 7.75, 4.0, 2.5, 1.9333333333333333, 6.333333333333333, 8.75, 4.25, 4.5, 6.75, 2.0, 6.25, 2.75, 6.0, 6.5, 2.5, 2.3, 1.375, 5.75, 15.0, 1.1, 6.0, 1.4166666666666667, 0.9375, 7.0, 2.75, 5.125, 12.0, 2.5, 5.2, 3.3333333333333335, 1.8333333333333333, 7.25, 8.666666666666666, 12.0, 13.0, 3.25, 5.75, 3.5, 2.9, 2.5, 2.5833333333333335, 5.4]
# AvgIndex 5.207204861111111
# AvgIndex2 4.558564325026524
#
# HH Pandya
# Wickets :  44 	Matches :  52 	Balls :  807
# MatchStats :  ['0/12-1', '1/22-3', '0/17-3', '0/29-3', '0/19-2', '1/7-1', '1/15-2', '0/14-3', '0/10-1', '0/10-2', '1/37-4', '1/24-4', '1/9-2', '0/15-1', '0/19-2', '1/25-4', '0/5-1', '0/2-1', '0/13-1', '0/29-3', '2/22-4', '0/15-1', '0/4-1', '1/42-5', '0/38-3', '0/39-4', '3/24-5', '0/7-1', '2/57-5', '0/11-2', '1/22-3', '3/24-5', '0/32-2', '0/4-1', '2/25-3', '2/20-4', '1/40-4', '3/28-4', '1/48-5', '2/19-5', '3/16-3', '2/52-4', '0/43-5', '0/40-5', '1/17-2', '1/31-4', '1/22-3', '1/31-4', '2/20-2', '2/20-3', '0/13-2', '1/3-2']
# MatchIndex :  [12.0, 3.6666666666666665, 5.666666666666667, 9.666666666666666, 9.5, 3.5, 3.75, 4.666666666666667, 10.0, 5.0, 4.625, 3.0, 2.25, 15.0, 9.5, 3.125, 5.0, 2.0, 13.0, 9.666666666666666, 1.8333333333333333, 15.0, 4.0, 4.2, 12.666666666666666, 9.75, 1.2, 7.0, 3.8, 5.5, 3.6666666666666665, 1.2, 16.0, 4.0, 2.7777777777777777, 1.6666666666666667, 5.0, 1.75, 4.8, 1.2666666666666666, 1.3333333333333333, 4.333333333333333, 8.6, 8.0, 4.25, 3.875, 3.6666666666666665, 3.875, 3.3333333333333335, 2.2222222222222223, 6.5, 0.75]
# AvgIndex 5.623076923076923
# AvgIndex2 4.760067705962676
#
# AD Russell
# Wickets :  50 	Matches :  46 	Balls :  759
# MatchStats :  ['3/24-4', '1/52-4', '2/21-4', '0/18-1', '0/16-2', '0/28-3', '4/27-4', '1/24-5', '6/25-5', '1/21-4', '1/12-2', '0/33-3', '2/32-3', '2/21-3', '1/28-3', '0/16-1', '1/29-3', '0/16-1', '0/10-2', '0/35-4', '0/39-3', '1/25-3', '0/31-2', '1/28-4', '3/31-4', '0/12-2', '2/12-3', '0/16-3', '3/42-4', '2/13-3', '1/35-4', '0/22-3', '0/9-1', '1/17-3', '0/8-1', '1/32-3', '2/25-4', '1/30-4', '0/34-3', '1/17-2', '2/18-3', '2/29-4', '1/18-2', '1/51-5', '0/15-2', '0/30-3']
# MatchIndex :  [1.5, 6.5, 1.75, 18.0, 8.0, 9.333333333333334, 1.35, 2.4, 0.7142857142857143, 2.625, 3.0, 11.0, 3.5555555555555554, 2.3333333333333335, 4.666666666666667, 16.0, 4.833333333333333, 16.0, 5.0, 8.75, 13.0, 4.166666666666667, 15.5, 3.5, 1.9375, 6.0, 1.3333333333333333, 5.333333333333333, 2.625, 1.4444444444444444, 4.375, 7.333333333333333, 9.0, 2.8333333333333335, 8.0, 5.333333333333333, 2.0833333333333335, 3.75, 11.333333333333334, 4.25, 2.0, 2.4166666666666665, 4.5, 5.1, 7.5, 10.0]
# AvgIndex 5.912176501035198
# AvgIndex2 6.429072839736291
#
# UT Yadav
# Wickets :  60 	Matches :  50 	Balls :  1082
# MatchStats :  ['0/21-3', '3/28-5', '2/17-3', '1/21-2', '1/19-3', '3/38-3', '2/56-5', '0/28-4', '0/18-2', '4/33-5', '0/29-4', '1/53-4', '1/18-2', '1/17-3', '1/29-4', '1/39-5', '0/31-4', '1/28-4', '3/36-5', '1/27-4', '1/44-4', '2/21-5', '1/27-3', '0/13-4', '2/26-5', '0/47-4', '0/40-4', '0/42-5', '0/25-3', '2/28-5', '3/23-4', '0/59-5', '2/37-5', '1/27-4', '1/23-4', '0/36-4', '2/31-5', '2/16-3', '1/36-5', '0/29-4', '3/23-4', '0/31-4', '3/25-4', '3/51-5', '3/36-5', '1/39-4', '0/10-1', '0/46-5', '1/49-5', '0/37-4']
# MatchIndex :  [7.0, 1.4, 1.8888888888888888, 5.25, 3.1666666666666665, 3.1666666666666665, 3.7333333333333334, 7.0, 9.0, 1.32, 7.25, 6.625, 4.5, 2.8333333333333335, 3.625, 3.9, 7.75, 3.5, 1.8, 3.375, 5.5, 1.4, 4.5, 3.25, 1.7333333333333334, 11.75, 10.0, 8.4, 8.333333333333334, 1.8666666666666667, 1.4375, 11.8, 2.466666666666667, 3.375, 2.875, 9.0, 2.066666666666667, 1.7777777777777777, 3.6, 7.25, 1.4375, 7.75, 1.5625, 2.55, 1.8, 4.875, 10.0, 9.2, 4.9, 9.25]
# AvgIndex 4.875816666666668
# AvgIndex2 5.852930326666669
#
# JW Hastings
# Wickets :  2 	Matches :  2 	Balls :  42
# MatchStats :  ['2/6-3', '0/31-5']
# MatchIndex :  [0.6666666666666666, 6.2]
# AvgIndex 3.4333333333333336
# AvgIndex2 4.291666666666667
#
# C Munro
# Wickets :  0 	Matches :  2 	Balls :  12
# MatchStats :  ['0/7-1', '0/8-1']
# MatchIndex :  [7.0, 8.0]
# AvgIndex 7.5
# AvgIndex2 1.875
#
# GB Hogg
# Wickets :  5 	Matches :  5 	Balls :  98
# MatchStats :  ['3/19-5', '1/39-5', '0/39-4', '0/28-2', '1/19-2']
# MatchIndex :  [0.95, 3.9, 9.75, 14.0, 4.75]
# AvgIndex 6.67
# AvgIndex2 6.936800000000001
#
# PP Chawla
# Wickets :  49 	Matches :  52 	Balls :  1029
# MatchStats :  ['2/21-5', '1/29-4', '0/13-1', '1/18-4', '0/26-3', '0/24-3', '2/32-4', '2/27-5', '2/30-4', '2/21-4', '0/32-4', '1/33-5', '1/36-3', '1/36-4', '0/13-2', '1/27-3', '2/34-5', '1/23-3', '1/27-3', '1/36-4', '0/32-4', '0/19-4', '1/28-4', '0/35-3', '2/32-4', '1/31-4', '1/49-5', '1/20-4', '1/17-3', '1/18-4', '0/24-2', '1/33-4', '0/22-3', '2/39-4', '0/35-3', '3/49-4', '0/16-2', '0/19-2', '2/24-4', '1/23-3', '0/10-1', '0/38-3', '3/20-4', '1/62-4', '0/43-4', '1/21-5', '1/55-5', '2/33-4', '2/20-3', '1/22-2', '0/8-1', '0/32-3']
# MatchIndex :  [1.4, 3.625, 13.0, 2.25, 8.666666666666666, 8.0, 2.6666666666666665, 1.8, 2.5, 1.75, 8.0, 3.3, 6.0, 4.5, 6.5, 4.5, 2.2666666666666666, 3.8333333333333335, 4.5, 4.5, 8.0, 4.75, 3.5, 11.666666666666666, 2.6666666666666665, 3.875, 4.9, 2.5, 2.8333333333333335, 2.25, 12.0, 4.125, 7.333333333333333, 3.25, 11.666666666666666, 3.0625, 8.0, 9.5, 2.0, 3.8333333333333335, 10.0, 12.666666666666666, 1.25, 7.75, 10.75, 2.1, 5.5, 2.75, 2.2222222222222223, 5.5, 8.0, 10.666666666666666]
# AvgIndex 5.469738247863249
# AvgIndex2 5.1561992580633955
#
# NM Coulter-Nile
# Wickets :  26 	Matches :  19 	Balls :  436
# MatchStats :  ['0/32-4', '2/29-5', '0/21-4', '2/38-4', '3/22-5', '2/41-4', '3/22-4', '3/34-4', '1/35-5', '0/41-4', '3/22-4', '1/15-3', '1/51-5', '0/33-4', '1/25-5', '1/14-2', '0/27-5', '0/27-5', '3/29-5']
# MatchIndex :  [8.0, 1.9333333333333333, 5.25, 3.1666666666666665, 1.1, 3.4166666666666665, 1.375, 2.125, 3.5, 10.25, 1.375, 2.5, 5.1, 8.25, 2.5, 3.5, 5.4, 5.4, 1.45]
# AvgIndex 3.9785087719298255
# AvgIndex2 5.455295961510426
#
# Z Khan
# Wickets :  24 	Matches :  23 	Balls :  517
# MatchStats :  ['0/24-3', '1/14-4', '1/50-4', '2/30-5', '0/48-4', '4/21-4', '1/27-5', '1/25-3', '1/27-5', '0/19-4', '0/26-4', '1/30-5', '3/31-5', '3/20-4', '0/38-4', '2/29-4', '0/37-4', '0/37-5', '0/9-2', '0/30-4', '0/35-4', '2/25-5', '2/32-5']
# MatchIndex :  [8.0, 1.75, 6.25, 2.0, 12.0, 1.05, 2.7, 4.166666666666667, 2.7, 4.75, 6.5, 3.0, 1.55, 1.25, 9.5, 2.4166666666666665, 9.25, 7.4, 4.5, 7.5, 8.75, 1.6666666666666667, 2.1333333333333333]
# AvgIndex 4.816666666666667
# AvgIndex2 5.035192186515439
#
# CH Morris
# Wickets :  58 	Matches :  43 	Balls :  960
# MatchStats :  ['0/21-5', '1/20-5', '0/30-4', '2/27-5', '2/35-5', '2/20-3', '1/33-5', '2/35-5', '2/19-5', '2/36-4', '1/13-3', '1/31-4', '3/22-4', '1/19-3', '3/23-5', '1/30-4', '4/26-4', '2/33-5', '0/39-3', '0/13-2', '0/36-4', '1/39-4', '3/30-5', '0/30-3', '2/28-5', '2/38-5', '3/22-3', '1/25-3', '0/35-3', '2/45-5', '0/43-5', '0/39-4', '1/41-5', '1/47-5', '3/19-4', '2/17-4', '0/22-5', '4/26-5', '1/17-5', '1/36-4', '1/36-5', '0/19-3', '0/20-2']
# MatchIndex :  [4.2, 2.0, 7.5, 1.8, 2.3333333333333335, 2.2222222222222223, 3.3, 2.3333333333333335, 1.2666666666666666, 3.0, 2.1666666666666665, 3.875, 1.375, 3.1666666666666665, 1.15, 3.75, 1.3, 2.2, 13.0, 6.5, 9.0, 4.875, 1.5, 10.0, 1.8666666666666667, 2.533333333333333, 1.8333333333333333, 4.166666666666667, 11.666666666666666, 3.0, 8.6, 9.75, 4.1, 4.7, 1.1875, 1.4166666666666667, 4.4, 1.04, 1.7, 4.5, 3.6, 6.333333333333333, 10.0]
# AvgIndex 4.190885012919896
# AvgIndex2 5.65508821375616
#
# CR Brathwaite
# Wickets :  16 	Matches :  16 	Balls :  266
# MatchStats :  ['0/11-3', '1/33-4', '1/19-2', '3/47-5', '0/17-2', '0/20-2', '3/27-5', '1/18-4', '0/29-3', '1/38-5', '0/13-1', '2/22-3', '1/32-4', '2/15-2', '1/27-3', '0/16-3']
# MatchIndex :  [3.6666666666666665, 4.125, 4.75, 2.35, 8.5, 10.0, 1.35, 2.25, 9.666666666666666, 3.8, 13.0, 2.4444444444444446, 4.0, 2.5, 4.5, 5.333333333333333]
# AvgIndex 5.139756944444444
# AvgIndex2 5.1598341200086795
#
# A Mishra
# Wickets :  51 	Matches :  52 	Balls :  1051
# MatchStats :  ['1/11-3', '4/11-4', '0/30-3', '2/25-4', '0/27-3', '1/37-5', '1/19-3', '1/28-5', '0/37-5', '2/19-3', '1/42-4', '0/10-2', '1/21-3', '0/33-4', '0/32-2', '3/11-3', '1/16-3', '1/26-3', '0/33-3', '2/19-5', '0/36-3', '0/9-1', '1/23-5', '0/23-2', '1/38-4', '1/27-2', '0/26-4', '0/26-2', '2/36-5', '1/36-5', '0/13-3', '0/46-4', '0/33-5', '3/24-4', '1/30-4', '1/12-2', '2/19-5', '0/29-3', '1/33-5', '2/20-4', '3/19-4', '1/18-3', '0/41-4', '0/28-3', '2/29-5', '0/16-3', '3/17-4', '1/16-4', '1/21-4', '0/23-4', '2/35-4', '1/14-3']
# MatchIndex :  [1.8333333333333333, 0.55, 10.0, 2.0833333333333335, 9.0, 3.7, 3.1666666666666665, 2.8, 7.4, 2.111111111111111, 5.25, 5.0, 3.5, 8.25, 16.0, 0.9166666666666666, 2.6666666666666665, 4.333333333333333, 11.0, 1.2666666666666666, 12.0, 9.0, 2.3, 11.5, 4.75, 6.75, 6.5, 13.0, 2.4, 3.6, 4.333333333333333, 11.5, 6.6, 1.5, 3.75, 3.0, 1.2666666666666666, 9.666666666666666, 3.3, 1.6666666666666667, 1.1875, 3.0, 10.25, 9.333333333333334, 1.9333333333333333, 5.333333333333333, 1.0625, 2.0, 2.625, 5.75, 2.9166666666666665, 2.3333333333333335]
# AvgIndex 5.133386752136753
# AvgIndex2 5.036566217980327
#
# P Kumar
# Wickets :  16 	Matches :  22 	Balls :  427
# MatchStats :  ['0/25-4', '0/12-2', '0/20-4', '0/31-3', '0/28-3', '0/14-4', '1/37-4', '2/25-3', '0/20-3', '1/28-5', '2/19-4', '2/46-4', '0/12-3', '2/24-4', '0/34-4', '0/33-4', '0/13-2', '1/16-2', '1/51-5', '1/25-4', '1/24-2', '2/25-5']
# MatchIndex :  [6.25, 6.0, 5.0, 10.333333333333334, 9.333333333333334, 3.5, 4.625, 2.7777777777777777, 6.666666666666667, 2.8, 1.5833333333333333, 3.8333333333333335, 4.0, 2.0, 8.5, 8.25, 6.5, 4.0, 5.1, 3.125, 6.0, 1.6666666666666667]
# AvgIndex 5.083838383838384
# AvgIndex2 3.707840804741632
#
# PJ Sangwan
# Wickets :  6 	Matches :  8 	Balls :  147
# MatchStats :  ['0/21-2', '0/28-3', '2/38-5', '1/45-5', '1/28-3', '2/35-3', '0/37-4', '0/20-2']
# MatchIndex :  [10.5, 9.333333333333334, 2.533333333333333, 4.5, 4.666666666666667, 3.888888888888889, 9.25, 10.0]
# AvgIndex 6.834027777777778
# AvgIndex2 5.232302517361112
#
# JP Faulkner
# Wickets :  11 	Matches :  15 	Balls :  267
# MatchStats :  ['0/40-5', '0/15-2', '1/40-5', '1/23-2', '0/22-2', '0/19-2', '0/9-1', '1/39-4', '2/20-3', '2/34-4', '1/31-3', '0/38-3', '0/43-4', '3/39-4', '0/24-2']
# MatchIndex :  [8.0, 7.5, 4.0, 5.75, 11.0, 9.5, 9.0, 4.875, 2.2222222222222223, 2.8333333333333335, 5.166666666666667, 12.666666666666666, 10.75, 2.4375, 12.0]
# AvgIndex 7.180092592592593
# AvgIndex2 5.297312757201646
#
# S Ladda
# Wickets :  0 	Matches :  1 	Balls :  12
# MatchStats :  ['0/21-2']
# MatchIndex :  [10.5]
# AvgIndex 10.5
# AvgIndex2 10.5
#
# RA Jadeja
# Wickets :  47 	Matches :  69 	Balls :  1273
# MatchStats :  ['2/32-5', '2/19-4', '0/20-3', '0/18-3', '0/14-1', '0/39-5', '2/29-4', '1/21-3', '0/14-2', '0/26-3', '0/35-4', '0/17-2', '0/15-1', '2/21-4', '1/40-4', '0/34-4', '0/57-4', '0/32-4', '1/33-4', '2/29-4', '0/11-1', '0/19-2', '1/28-2', '0/19-3', '0/31-4', '0/19-3', '2/16-4', '1/24-4', '0/23-2', '1/10-2', '0/24-4', '1/17-5', '2/20-4', '0/49-5', '0/22-4', '0/9-1', '1/19-2', '0/6-1', '0/28-5', '0/26-2', '2/32-5', '1/39-5', '3/18-4', '1/28-4', '0/24-2', '1/19-4', '1/24-3', '1/13-4', '1/25-2', '2/29-4', '0/33-4', '3/9-3', '1/16-2', '0/19-4', '2/24-3', '0/12-2', '2/42-4', '0/40-5', '0/44-4', '0/16-2', '1/30-4', '0/7-2', '1/21-3', '0/35-2', '0/11-2', '0/15-1', '0/20-3', '1/20-3', '1/17-3']
# MatchIndex :  [2.1333333333333333, 1.5833333333333333, 6.666666666666667, 6.0, 14.0, 7.8, 2.4166666666666665, 3.5, 7.0, 8.666666666666666, 8.75, 8.5, 15.0, 1.75, 5.0, 8.5, 14.25, 8.0, 4.125, 2.4166666666666665, 11.0, 9.5, 7.0, 6.333333333333333, 7.75, 6.333333333333333, 1.3333333333333333, 3.0, 11.5, 2.5, 6.0, 1.7, 1.6666666666666667, 9.8, 5.5, 9.0, 4.75, 6.0, 5.6, 13.0, 2.1333333333333333, 3.9, 1.125, 3.5, 12.0, 2.375, 4.0, 1.625, 6.25, 2.4166666666666665, 8.25, 0.75, 4.0, 4.75, 2.6666666666666665, 6.0, 3.5, 8.0, 11.0, 8.0, 3.75, 3.5, 3.5, 17.5, 5.5, 15.0, 6.666666666666667, 3.3333333333333335, 2.8333333333333335]
# AvgIndex 6.1326086956521735
# AvgIndex2 4.178572276558633
#
# DJ Bravo
# Wickets :  57 	Matches :  49 	Balls :  1084
# MatchStats :  ['4/22-5', '1/43-4', '2/39-5', '0/27-3', '0/43-5', '1/40-5', '2/40-5', '2/33-4', '2/14-3', '0/39-5', '0/46-4', '1/29-5', '2/25-5', '0/30-4', '2/32-4', '1/0-1', '3/33-5', '2/33-5', '1/49-5', '0/26-4', '0/50-3', '1/37-4', '2/16-3', '1/37-3', '4/33-5', '1/22-4', '0/43-4', '0/23-2', '1/17-2', '2/31-4', '1/39-5', '0/53-5', '2/40-4', '2/25-5', '1/46-5', '2/34-4', '0/35-5', '0/35-5', '1/18-3', '0/31-5', '0/25-3', '2/19-5', '1/24-4', '0/28-5', '0/38-5', '4/37-5', '0/29-4', '2/25-3', '1/23-4']
# MatchIndex :  [0.88, 5.375, 2.6, 9.0, 8.6, 4.0, 2.6666666666666665, 2.75, 1.5555555555555556, 7.8, 11.5, 2.9, 1.6666666666666667, 7.5, 2.6666666666666665, 0.0, 1.65, 2.2, 4.9, 6.5, 16.666666666666668, 4.625, 1.7777777777777777, 6.166666666666667, 1.32, 2.75, 10.75, 11.5, 4.25, 2.5833333333333335, 3.9, 10.6, 3.3333333333333335, 1.6666666666666667, 4.6, 2.8333333333333335, 7.0, 7.0, 3.0, 6.2, 8.333333333333334, 1.2666666666666666, 3.0, 5.6, 7.6, 1.48, 7.25, 2.7777777777777777, 2.875]
# AvgIndex 4.886043083900227
# AvgIndex2 5.685799407087561
#
# Sandeep Sharma
# Wickets :  77 	Matches :  63 	Balls :  1464
# MatchStats :  ['1/21-3', '1/6-2', '2/24-5', '0/25-2', '2/30-4', '1/20-5', '1/31-5', '2/25-5', '1/38-4', '3/49-5', '2/11-4', '1/36-4', '1/29-3', '1/29-5', '2/33-4', '1/26-5', '0/28-4', '1/41-4', '1/38-4', '0/39-4', '2/40-4', '4/20-5', '3/22-4', '2/30-5', '0/31-4', '1/42-5', '0/12-3', '1/42-5', '0/38-4', '4/19-4', '1/25-4', '1/20-4', '2/21-4', '0/32-5', '0/33-5', '2/25-4', '1/9-4', '2/17-4', '1/15-4', '1/35-5', '1/20-5', '1/24-4', '1/36-5', '1/40-5', '0/30-3', '2/30-3', '1/53-5', '1/37-4', '1/55-4', '2/33-5', '0/36-4', '2/41-4', '0/27-5', '0/32-4', '2/19-4', '0/27-4', '0/31-4', '2/29-5', '2/27-5', '2/20-5', '3/34-4', '0/21-4', '1/30-4']
# MatchIndex :  [3.5, 1.5, 1.6, 12.5, 2.5, 2.0, 3.1, 1.6666666666666667, 4.75, 2.45, 0.9166666666666666, 4.5, 4.833333333333333, 2.9, 2.75, 2.6, 7.0, 5.125, 4.75, 9.75, 3.3333333333333335, 0.8, 1.375, 2.0, 7.75, 4.2, 4.0, 4.2, 9.5, 0.95, 3.125, 2.5, 1.75, 6.4, 6.6, 2.0833333333333335, 1.125, 1.4166666666666667, 1.875, 3.5, 2.0, 3.0, 3.6, 4.0, 10.0, 3.3333333333333335, 5.3, 4.625, 6.875, 2.2, 9.0, 3.4166666666666665, 5.4, 8.0, 1.5833333333333333, 6.75, 7.75, 1.9333333333333333, 1.8, 1.3333333333333333, 2.125, 5.25, 3.75]
# AvgIndex 4.003174603174604
# AvgIndex2 4.8937775698168755
#
# MG Johnson
# Wickets :  14 	Matches :  14 	Balls :  327
# MatchStats :  ['2/37-5', '0/28-3', '1/43-5', '1/23-5', '1/34-5', '1/31-5', '2/28-5', '4/31-4', '1/30-4', '1/30-4', '0/42-4', '0/39-4', '0/51-4', '0/26-4']
# MatchIndex :  [2.466666666666667, 9.333333333333334, 4.3, 2.3, 3.4, 3.1, 1.8666666666666667, 1.55, 3.75, 3.75, 10.5, 9.75, 12.75, 6.5]
# AvgIndex 5.379761904761905
# AvgIndex2 5.407209669582119
#
# MM Sharma
# Wickets :  38 	Matches :  39 	Balls :  810
# MatchStats :  ['0/24-3', '0/11-3', '4/24-4', '0/29-4', '2/20-4', '3/38-5', '3/32-4', '1/39-4', '0/21-4', '0/33-4', '2/26-5', '0/41-4', '0/33-3', '1/39-5', '0/34-4', '0/47-4', '0/30-3', '1/37-5', '2/25-4', '1/29-3', '1/27-5', '1/34-3', '1/3-2', '2/24-4', '0/35-4', '2/24-3', '2/57-4', '0/6-1', '1/27-3', '2/34-4', '0/45-4', '1/47-5', '2/52-5', '0/29-4', '1/40-5', '0/15-1', '0/38-4', '1/28-4', '1/45-5']
# MatchIndex :  [8.0, 3.6666666666666665, 1.2, 7.25, 1.6666666666666667, 1.9, 2.0, 4.875, 5.25, 8.25, 1.7333333333333334, 10.25, 11.0, 3.9, 8.5, 11.75, 10.0, 3.7, 2.0833333333333335, 4.833333333333333, 2.7, 5.666666666666667, 0.75, 2.0, 8.75, 2.6666666666666665, 4.75, 6.0, 4.5, 2.8333333333333335, 11.25, 4.7, 3.466666666666667, 7.25, 4.0, 15.0, 9.5, 3.5, 4.5]
# AvgIndex 5.527991452991453
# AvgIndex2 5.38988252780166
#
# MP Stoinis
# Wickets :  29 	Matches :  37 	Balls :  562
# MatchStats :  ['1/27-2', '1/24-4', '0/26-3', '3/42-5', '0/35-3', '4/21-4', '0/28-4', '1/28-4', '0/28-4', '0/15-2', '1/28-3', '0/12-2', '0/28-3', '0/28-2', '0/7-1', '1/37-3', '0/6-1', '1/15-2', '0/13-1', '1/43-3', '1/32-5', '0/22-4', '1/13-2', '0/24-3', '2/30-3', '0/23-3', '1/47-5', '2/17-3', '1/31-3', '0/10-1', '0/14-2', '2/42-5', '0/15-2', '0/4-1', '1/5-1', '3/26-4', '1/23-2']
# MatchIndex :  [6.75, 3.0, 8.666666666666666, 2.1, 11.666666666666666, 1.05, 7.0, 3.5, 7.0, 7.5, 4.666666666666667, 6.0, 9.333333333333334, 14.0, 7.0, 6.166666666666667, 6.0, 3.75, 13.0, 7.166666666666667, 3.2, 5.5, 3.25, 8.0, 3.3333333333333335, 7.666666666666667, 4.7, 1.8888888888888888, 5.166666666666667, 10.0, 7.0, 2.8, 7.5, 4.0, 2.5, 1.625, 5.75]
# AvgIndex 5.924249249249248
# AvgIndex2 4.647657920886554
#
# AR Patel
# Wickets :  54 	Matches :  65 	Balls :  1361
# MatchStats :  ['0/17-3', '1/26-3', '0/27-3', '2/19-3', '0/11-2', '1/42-4', '4/21-5', '0/26-4', '0/33-4', '1/27-4', '1/30-4', '1/27-4', '1/46-4', '1/43-5', '1/28-5', '1/12-4', '1/36-4', '1/34-4', '2/33-5', '0/21-3', '2/37-4', '0/34-3', '2/22-5', '3/11-3', '0/29-3', '0/28-4', '1/28-3', '1/13-2', '1/42-3', '0/16-4', '1/22-5', '1/22-4', '0/30-4', '0/23-2', '1/35-3', '1/26-4', '0/9-1', '1/22-4', '0/24-3', '0/52-5', '0/24-4', '0/29-4', '2/17-4', '2/22-3', '1/39-4', '1/26-4', '1/31-3', '1/16-4', '0/30-4', '1/32-4', '1/14-4', '2/18-4', '0/14-3', '2/19-4', '1/8-2', '1/24-3', '2/32-4', '0/23-4', '1/27-4', '0/7-1', '0/37-5', '0/30-4', '0/27-3', '1/33-4', '0/16-4']
# MatchIndex :  [5.666666666666667, 4.333333333333333, 9.0, 2.111111111111111, 5.5, 5.25, 0.84, 6.5, 8.25, 3.375, 3.75, 3.375, 5.75, 4.3, 2.8, 1.5, 4.5, 4.25, 2.2, 7.0, 3.0833333333333335, 11.333333333333334, 1.4666666666666666, 0.9166666666666666, 9.666666666666666, 7.0, 4.666666666666667, 3.25, 7.0, 4.0, 2.2, 2.75, 7.5, 11.5, 5.833333333333333, 3.25, 9.0, 2.75, 8.0, 10.4, 6.0, 7.25, 1.4166666666666667, 2.4444444444444446, 4.875, 3.25, 5.166666666666667, 2.0, 7.5, 4.0, 1.75, 1.5, 4.666666666666667, 1.5833333333333333, 2.0, 4.0, 2.6666666666666665, 5.75, 3.375, 7.0, 7.4, 7.5, 9.0, 4.125, 4.0]
# AvgIndex 4.862111111111111
# AvgIndex2 4.040443103221564
#
# P Sahu
# Wickets :  3 	Matches :  5 	Balls :  107
# MatchStats :  ['1/36-4', '0/31-3', '0/32-5', '2/18-4', '0/35-3']
# MatchIndex :  [4.5, 10.333333333333334, 6.4, 1.5, 11.666666666666666]
# AvgIndex 6.88
# AvgIndex2 4.4032
#
# A Nehra
# Wickets :  21 	Matches :  14 	Balls :  293
# MatchStats :  ['0/21-3', '1/22-4', '1/32-4', '0/23-4', '3/15-3', '5/29-4', '1/23-3', '0/35-3', '2/42-5', '2/28-4', '1/46-4', '1/35-5', '3/42-4', '1/5-2']
# MatchIndex :  [7.0, 2.75, 4.0, 5.75, 1.25, 1.2083333333333333, 3.8333333333333335, 11.666666666666666, 2.8, 2.3333333333333335, 5.75, 3.5, 2.625, 1.25]
# AvgIndex 3.9797619047619044
# AvgIndex2 5.989947764820213
#
# B Kumar
# Wickets :  81 	Matches :  62 	Balls :  1479
# MatchStats :  ['2/55-5', '0/29-5', '1/17-4', '4/30-5', '1/38-4', '1/17-4', '1/36-5', '2/28-4', '1/23-4', '1/21-5', '0/32-5', '2/33-4', '0/37-5', '2/31-4', '3/20-4', '2/27-5', '1/29-5', '2/28-5', '2/23-4', '3/23-4', '3/21-4', '5/20-5', '0/31-5', '1/39-5', '2/29-4', '2/30-4', '1/33-4', '1/39-5', '2/31-5', '2/26-4', '2/11-1', '0/37-4', '0/55-5', '0/25-3', '2/27-5', '1/34-5', '0/25-4', '2/34-5', '0/22-4', '2/30-5', '3/26-5', '1/25-5', '1/22-3', '0/33-4', '1/28-4', '1/52-5', '0/38-4', '0/33-5', '1/14-4', '0/39-4', '0/17-4', '2/35-5', '2/19-4', '0/23-5', '0/34-5', '1/29-5', '2/25-5', '2/42-5', '2/25-5', '0/29-4', '2/26-5', '1/20-4']
# MatchIndex :  [3.6666666666666665, 5.8, 2.125, 1.2, 4.75, 2.125, 3.6, 2.3333333333333335, 2.875, 2.1, 6.4, 2.75, 7.4, 2.5833333333333335, 1.25, 1.8, 2.9, 1.8666666666666667, 1.9166666666666667, 1.4375, 1.3125, 0.6666666666666666, 6.2, 3.9, 2.4166666666666665, 2.5, 4.125, 3.9, 2.066666666666667, 2.1666666666666665, 3.6666666666666665, 9.25, 11.0, 8.333333333333334, 1.8, 3.4, 6.25, 2.2666666666666666, 5.5, 2.0, 1.3, 2.5, 3.6666666666666665, 8.25, 3.5, 5.2, 9.5, 6.6, 1.75, 9.75, 4.25, 2.3333333333333335, 1.5833333333333333, 4.6, 6.8, 2.9, 1.6666666666666667, 2.8, 1.6666666666666667, 7.25, 1.7333333333333334, 2.5]
# AvgIndex 3.8016129032258066
# AvgIndex2 4.967612282232889
#
# Mustafizur Rahman
# Wickets :  28 	Matches :  24 	Balls :  560
# MatchStats :  ['2/26-4', '1/29-5', '1/33-5', '1/19-4', '3/9-4', '0/22-3', '1/35-4', '2/17-4', '3/16-4', '0/26-4', '0/39-5', '1/32-4', '1/24-5', '1/32-5', '0/30-4', '2/38-4', '0/34-3', '1/40-4', '3/24-4', '1/26-4', '0/55-5', '1/35-5', '2/18-4', '1/34-4']
# MatchIndex :  [2.1666666666666665, 2.9, 3.3, 2.375, 0.5625, 7.333333333333333, 4.375, 1.4166666666666667, 1.0, 6.5, 7.8, 4.0, 2.4, 3.2, 7.5, 3.1666666666666665, 11.333333333333334, 5.0, 1.5, 3.25, 11.0, 3.5, 1.5, 4.25]
# AvgIndex 4.222048611111111
# AvgIndex2 4.933053325135031
#
# MC Henriques
# Wickets :  16 	Matches :  29 	Balls :  466
# MatchStats :  ['0/41-4', '0/19-3', '0/23-5', '0/18-4', '2/33-5', '1/16-2', '2/40-4', '1/24-4', '1/20-4', '1/20-3', '2/19-3', '1/29-3', '0/18-2', '0/14-2', '3/17-3', '0/27-3', '0/40-3', '1/20-3', '0/12-1', '0/26-3', '1/6-2', '0/32-4', '0/4-1', '0/39-3', '0/31-3', '0/36-3', '0/15-3', '0/15-1', '0/12-1']
# MatchIndex :  [10.25, 6.333333333333333, 4.6, 4.5, 2.2, 4.0, 3.3333333333333335, 3.0, 2.5, 3.3333333333333335, 2.111111111111111, 4.833333333333333, 9.0, 7.0, 1.4166666666666667, 9.0, 13.333333333333334, 3.3333333333333335, 12.0, 8.666666666666666, 1.5, 8.0, 4.0, 13.0, 10.333333333333334, 12.0, 5.0, 15.0, 12.0]
# AvgIndex 6.744061302681993
# AvgIndex2 3.7288805062391517
#
# KV Sharma
# Wickets :  24 	Matches :  25 	Balls :  482
# MatchStats :  ['0/58-5', '0/24-3', '0/28-4', '1/25-3', '0/39-4', '2/39-4', '1/23-4', '3/12-4', '0/20-2', '1/32-3', '1/26-3', '1/30-4', '4/17-5', '0/18-5', '1/33-3', '2/13-2', '1/30-3', '0/11-1', '0/11-1', '1/25-4', '2/25-4', '0/34-5', '2/37-5', '0/34-3', '1/35-4']
# MatchIndex :  [11.6, 8.0, 7.0, 4.166666666666667, 9.75, 3.25, 2.875, 0.75, 10.0, 5.333333333333333, 4.333333333333333, 3.75, 0.68, 3.6, 5.5, 2.1666666666666665, 5.0, 11.0, 11.0, 3.125, 2.0833333333333335, 6.8, 2.466666666666667, 11.333333333333334, 4.375]
# AvgIndex 5.597533333333334
# AvgIndex2 5.3825880533333335
#
# A Ashish Reddy
# Wickets :  1 	Matches :  2 	Balls :  23
# MatchStats :  ['0/26-2', '1/14-2']
# MatchIndex :  [13.0, 3.5]
# AvgIndex 8.25
# AvgIndex2 6.1875
#
# AF Milne
# Wickets :  5 	Matches :  5 	Balls :  115
# MatchStats :  ['1/44-5', '3/32-4', '1/45-5', '0/35-5', '0/29-3']
# MatchIndex :  [4.4, 2.0, 4.5, 7.0, 9.666666666666666]
# AvgIndex 5.513333333333333
# AvgIndex2 5.733866666666667
#
# SR Watson
# Wickets :  35 	Matches :  35 	Balls :  701
# MatchStats :  ['2/30-5', '2/28-5', '0/40-5', '2/31-5', '1/31-4', '2/33-5', '1/38-3', '3/25-5', '2/22-4', '0/38-4', '0/4-2', '0/46-5', '2/7-3', '1/27-4', '4/29-5', '1/61-5', '0/41-3', '1/21-4', '0/29-2', '1/44-5', '0/24-2', '1/28-4', '1/43-5', '1/16-4', '2/29-5', '3/39-5', '1/15-2', '1/13-4', '0/23-2', '0/21-3', '0/41-5', '0/27-2', '0/19-3', '0/9-1', '0/16-3']
# MatchIndex :  [2.0, 1.8666666666666667, 8.0, 2.066666666666667, 3.875, 2.2, 6.333333333333333, 1.25, 1.8333333333333333, 9.5, 2.0, 9.2, 0.7777777777777778, 3.375, 1.16, 6.1, 13.666666666666666, 2.625, 14.5, 4.4, 12.0, 3.5, 4.3, 2.0, 1.9333333333333333, 1.95, 3.75, 1.625, 11.5, 7.0, 8.2, 13.5, 6.333333333333333, 9.0, 5.333333333333333]
# AvgIndex 5.390126984126985
# AvgIndex2 5.394527087787497
#
# Parvez Rasool
# Wickets :  1 	Matches :  4 	Balls :  84
# MatchStats :  ['1/31-4', '0/28-3', '0/34-4', '0/37-3']
# MatchIndex :  [3.875, 9.333333333333334, 8.5, 12.333333333333334]
# AvgIndex 8.510416666666668
# AvgIndex2 2.6595052083333335
#
# HV Patel
# Wickets :  18 	Matches :  18 	Balls :  374
# MatchStats :  ['0/33-5', '0/32-3', '0/20-2', '2/46-5', '0/16-2', '3/43-5', '2/40-5', '1/37-5', '1/34-3', '1/32-4', '1/51-5', '1/24-4', '3/28-3', '2/34-5', '0/44-5', '1/29-5', '0/20-2', '0/8-2']
# MatchIndex :  [6.6, 10.666666666666666, 10.0, 3.066666666666667, 8.0, 2.15, 2.6666666666666665, 3.7, 5.666666666666667, 4.0, 5.1, 3.0, 2.3333333333333335, 2.2666666666666666, 8.8, 2.9, 10.0, 4.0]
# AvgIndex 5.273148148148148
# AvgIndex2 5.289423296753544
#
# YS Chahal
# Wickets :  88 	Matches :  69 	Balls :  1548
# MatchStats :  ['2/44-5', '0/23-3', '1/33-5', '2/31-5', '1/38-5', '2/32-4', '1/16-4', '3/19-4', '1/38-5', '4/25-3', '3/32-5', '1/42-4', '1/36-4', '1/22-4', '1/20-4', '1/29-4', '1/34-3', '0/11-2', '3/31-5', '3/16-5', '0/30-4', '0/25-2', '1/36-5', '2/29-5', '1/40-5', '0/28-4', '1/6-4', '4/42-5', '1/44-5', '2/17-5', '1/25-4', '0/36-5', '2/35-5', '2/27-4', '0/29-4', '1/39-4', '2/27-5', '0/32-3', '2/23-4', '2/27-5', '0/29-4', '0/25-5', '0/29-4', '1/25-5', '2/28-4', '1/7-2', '1/28-5', '0/26-4', '0/45-4', '1/24-4', '0/27-2', '2/41-4', '1/1-1', '1/24-5', '3/22-4', '1/25-4', '1/48-4', '3/25-4', '0/29-3', '1/35-5', '1/14-4', '2/35-4', '2/35-5', '2/15-4', '1/22-4', '2/37-4', '2/19-4', '0/29-4', '1/24-4']
# MatchIndex :  [2.933333333333333, 7.666666666666667, 3.3, 2.066666666666667, 3.8, 2.6666666666666665, 2.0, 1.1875, 3.8, 1.6666666666666667, 1.6, 5.25, 4.5, 2.75, 2.5, 3.625, 5.666666666666667, 5.5, 1.55, 0.8, 7.5, 12.5, 3.6, 1.9333333333333333, 4.0, 7.0, 0.75, 1.68, 4.4, 1.1333333333333333, 3.125, 7.2, 2.3333333333333335, 2.25, 7.25, 4.875, 1.8, 10.666666666666666, 1.9166666666666667, 1.8, 7.25, 5.0, 7.25, 2.5, 2.3333333333333335, 1.75, 2.8, 6.5, 11.25, 3.0, 13.5, 3.4166666666666665, 0.5, 2.4, 1.375, 3.125, 6.0, 1.5625, 9.666666666666666, 3.5, 1.75, 2.9166666666666665, 2.3333333333333335, 1.25, 2.75, 3.0833333333333335, 1.5833333333333333, 7.25, 3.0]
# AvgIndex 3.958526570048309
# AvgIndex2 5.049387074123793
#
# TG Southee
# Wickets :  21 	Matches :  25 	Balls :  575
# MatchStats :  ['0/44-5', '0/31-4', '3/25-5', '0/25-4', '0/22-4', '2/28-4', '2/38-4', '0/35-5', '0/36-4', '1/27-5', '1/22-5', '1/34-5', '0/23-3', '2/40-5', '0/62-5', '1/28-3', '0/34-5', '2/25-5', '0/30-3', '5/31-5', '0/41-5', '0/20-2', '0/45-5', '1/37-5', '0/33-4']
# MatchIndex :  [8.8, 7.75, 1.25, 6.25, 5.5, 2.3333333333333335, 3.1666666666666665, 7.0, 9.0, 2.7, 2.2, 3.4, 7.666666666666667, 2.6666666666666665, 12.4, 4.666666666666667, 6.8, 1.6666666666666667, 10.0, 1.0333333333333334, 8.2, 10.0, 9.0, 3.7, 8.25]
# AvgIndex 5.816
# AvgIndex2 4.8947456
#
# J Suchith
# Wickets :  2 	Matches :  2 	Balls :  38
# MatchStats :  ['0/31-3', '2/28-4']
# MatchIndex :  [10.333333333333334, 2.3333333333333335]
# AvgIndex 6.333333333333334
# AvgIndex2 7.916666666666667
#
# Kuldeep Yadav
# Wickets :  43 	Matches :  43 	Balls :  913
# MatchStats :  ['1/37-5', '3/29-5', '3/36-4', '2/25-4', '1/35-5', '1/23-4', '0/29-3', '2/33-4', '2/31-4', '0/27-4', '0/43-5', '1/35-4', '2/35-4', '1/29-3', '0/18-2', '0/32-5', '3/41-4', '1/31-4', '0/33-4', '0/16-4', '0/28-5', '0/28-3', '0/33-4', '1/29-4', '1/23-4', '3/32-4', '1/24-4', '0/13-1', '0/22-2', '1/22-4', '1/34-5', '0/17-2', '0/43-3', '1/29-3', '4/20-4', '1/35-4', '1/18-4', '3/29-4', '1/59-5', '0/40-5', '0/15-2', '1/21-3', '0/19-4']
# MatchIndex :  [3.7, 1.45, 2.25, 2.0833333333333335, 3.5, 2.875, 9.666666666666666, 2.75, 2.5833333333333335, 6.75, 8.6, 4.375, 2.9166666666666665, 4.833333333333333, 9.0, 6.4, 2.5625, 3.875, 8.25, 4.0, 5.6, 9.333333333333334, 8.25, 3.625, 2.875, 2.0, 3.0, 13.0, 11.0, 2.75, 3.4, 8.5, 14.333333333333334, 4.833333333333333, 1.0, 4.375, 2.25, 1.8125, 5.9, 8.0, 7.5, 3.5, 4.75]
# AvgIndex 5.209496124031009
# AvgIndex2 5.2123135908368665
#
# SB Jakati
# Wickets :  2 	Matches :  8 	Balls :  155
# MatchStats :  ['0/41-4', '1/13-4', '0/28-3', '1/24-4', '0/30-3', '0/45-4', '0/30-4', '0/22-2']
# MatchIndex :  [10.25, 1.625, 9.333333333333334, 3.0, 10.0, 11.25, 7.5, 11.0]
# AvgIndex 7.994791666666667
# AvgIndex2 2.1236165364583335
#
# PV Tambe
# Wickets :  5 	Matches :  7 	Balls :  97
# MatchStats :  ['2/33-4', '2/12-2', '0/17-3', '1/24-3', '0/17-1', '0/15-2', '0/25-2']
# MatchIndex :  [2.75, 2.0, 5.666666666666667, 4.0, 17.0, 7.5, 12.5]
# AvgIndex 7.345238095238096
# AvgIndex2 5.3965014577259485
#
# P Negi
# Wickets :  23 	Matches :  23 	Balls :  348
# MatchStats :  ['1/10-1', '0/26-3', '0/19-1', '0/10-1', '1/19-3', '2/3-1', '0/8-1', '0/29-3', '1/13-4', '1/21-5', '2/15-4', '1/24-3', '1/18-5', '3/18-4', '1/22-3', '2/21-4', '3/10-2', '2/21-4', '1/28-4', '0/47-5', '0/13-1', '1/36-3', '0/7-1']
# MatchIndex :  [5.0, 8.666666666666666, 19.0, 10.0, 3.1666666666666665, 1.0, 8.0, 9.666666666666666, 1.625, 2.1, 1.25, 4.0, 1.8, 1.125, 3.6666666666666665, 1.75, 1.25, 1.75, 3.5, 9.4, 13.0, 6.0, 7.0]
# AvgIndex 5.378985507246377
# AvgIndex2 5.38915372181584
#
# J Yadav
# Wickets :  4 	Matches :  11 	Balls :  226
# MatchStats :  ['1/23-5', '0/25-4', '1/32-5', '0/37-4', '0/8-1', '0/16-3', '0/27-4', '0/25-4', '1/25-4', '0/18-3', '1/25-4']
# MatchIndex :  [2.3, 6.25, 3.2, 9.25, 8.0, 5.333333333333333, 6.75, 6.25, 3.125, 6.0, 3.125]
# AvgIndex 5.416666666666667
# AvgIndex2 2.0144628099173554
#
# GJ Maxwell
# Wickets :  15 	Matches :  32 	Balls :  394
# MatchStats :  ['0/11-2', '0/3-1', '0/18-2', '0/16-2', '0/11-1', '0/11-1', '0/11-1', '0/18-1', '0/7-1', '2/29-4', '1/12-4', '2/15-4', '1/21-2', '1/9-2', '0/15-2', '0/21-4', '1/13-3', '0/4-1', '2/22-2', '1/5-1', '1/21-1', '0/4-1', '0/9-1', '0/14-2', '0/19-2', '1/10-2', '0/31-3', '0/26-2', '0/28-4', '0/24-4', '1/31-4', '1/21-2']
# MatchIndex :  [5.5, 3.0, 9.0, 8.0, 11.0, 11.0, 11.0, 18.0, 7.0, 2.4166666666666665, 1.5, 1.25, 5.25, 2.25, 7.5, 5.25, 2.1666666666666665, 4.0, 3.6666666666666665, 2.5, 10.5, 4.0, 9.0, 7.0, 9.5, 2.5, 10.333333333333334, 13.0, 7.0, 6.0, 3.875, 5.25]
# AvgIndex 6.537760416666667
# AvgIndex2 3.070959726969401
#
# M Morkel
# Wickets :  10 	Matches :  10 	Balls :  220
# MatchStats :  ['2/35-5', '2/27-4', '0/30-3', '2/28-4', '1/28-5', '0/38-4', '0/22-4', '0/20-2', '1/39-4', '2/32-4']
# MatchIndex :  [2.3333333333333335, 2.25, 10.0, 2.3333333333333335, 2.8, 9.5, 5.5, 10.0, 4.875, 2.6666666666666665]
# AvgIndex 5.225833333333333
# AvgIndex2 5.278091666666667
#
# Shakib Al Hasan
# Wickets :  23 	Matches :  30 	Balls :  619
# MatchStats :  ['0/19-3', '0/29-5', '1/14-3', '1/30-4', '0/21-3', '1/38-3', '1/21-3', '0/39-5', '1/36-5', '0/34-3', '1/42-4', '2/24-4', '1/34-5', '2/22-5', '0/28-2', '0/32-5', '1/16-3', '2/18-3', '0/30-4', '0/34-4', '2/36-4', '2/27-4', '1/41-4', '0/35-4', '1/30-3', '0/20-2', '2/16-3', '0/15-1', '0/27-4', '1/26-4']
# MatchIndex :  [6.333333333333333, 5.8, 2.3333333333333335, 3.75, 7.0, 6.333333333333333, 3.5, 7.8, 3.6, 11.333333333333334, 5.25, 2.0, 3.4, 1.4666666666666666, 14.0, 6.4, 2.6666666666666665, 2.0, 7.5, 8.5, 3.0, 2.25, 5.125, 8.75, 5.0, 10.0, 1.7777777777777777, 15.0, 6.75, 3.25]
# AvgIndex 5.728981481481482
# AvgIndex2 4.398584670781894
#
# SP Narine
# Wickets :  59 	Matches :  64 	Balls :  1498
# MatchStats :  ['0/26-4', '2/23-5', '1/33-4', '2/22-4', '1/22-4', '0/45-4', '1/12-4', '1/34-4', '2/30-5', '3/28-4', '0/35-5', '0/33-4', '1/22-4', '1/19-5', '1/18-4', '2/20-5', '0/42-4', '1/34-5', '2/25-5', '0/37-4', '1/28-4', '2/29-4', '1/27-4', '0/37-5', '0/20-4', '0/21-4', '0/29-3', '0/26-2', '1/30-5', '0/26-5', '2/24-4', '2/19-5', '1/31-4', '1/18-4', '2/17-5', '3/18-3', '0/48-4', '1/23-3', '0/36-3', '0/39-4', '2/20-4', '2/35-4', '1/28-4', '1/44-4', '1/29-5', '1/24-5', '0/39-5', '1/24-4', '1/32-5', '0/36-4', '2/25-4', '2/44-4', '1/29-4', '0/33-5', '2/22-4', '0/32-4', '1/42-5', '0/26-2', '1/32-4', '2/30-4', '0/37-5', '0/27-4', '0/23-4', '0/37-4']
# MatchIndex :  [6.5, 1.5333333333333334, 4.125, 1.8333333333333333, 2.75, 11.25, 1.5, 4.25, 2.0, 1.75, 7.0, 8.25, 2.75, 1.9, 2.25, 1.3333333333333333, 10.5, 3.4, 1.6666666666666667, 9.25, 3.5, 2.4166666666666665, 3.375, 7.4, 5.0, 5.25, 9.666666666666666, 13.0, 3.0, 5.2, 2.0, 1.2666666666666666, 3.875, 2.25, 1.1333333333333333, 1.5, 12.0, 3.8333333333333335, 12.0, 9.75, 1.6666666666666667, 2.9166666666666665, 3.5, 5.5, 2.9, 2.4, 7.8, 3.0, 3.2, 9.0, 2.0833333333333335, 3.6666666666666665, 3.625, 6.6, 1.8333333333333333, 8.0, 4.2, 13.0, 4.0, 2.5, 7.4, 6.75, 5.75, 9.25]
# AvgIndex 4.90234375
# AvgIndex2 4.52054500579834
#
# BB Sran
# Wickets :  20 	Matches :  23 	Balls :  496
# MatchStats :  ['0/31-5', '3/29-5', '1/36-4', '0/33-4', '1/36-5', '1/21-4', '2/18-4', '1/27-4', '0/21-2', '2/34-5', '1/32-5', '1/33-3', '0/28-4', '1/41-4', '0/29-3', '1/38-5', '1/22-5', '2/50-5', '1/45-5', '0/28-4', '1/48-3', '0/27-2', '0/24-3']
# MatchIndex :  [6.2, 1.45, 4.5, 8.25, 3.6, 2.625, 1.5, 3.375, 10.5, 2.2666666666666666, 3.2, 5.5, 7.0, 5.125, 9.666666666666666, 3.8, 2.2, 3.3333333333333335, 4.5, 7.0, 8.0, 13.5, 8.0]
# AvgIndex 5.438768115942029
# AvgIndex2 4.739644804251938
#
# DS Kulkarni
# Wickets :  33 	Matches :  39 	Balls :  780
# MatchStats :  ['2/19-4', '0/9-1', '1/39-4', '3/19-4', '0/25-4', '1/28-4', '0/24-2', '2/17-4', '1/30-5', '1/33-3', '2/34-5', '2/41-4', '4/15-4', '1/32-4', '0/42-4', '0/17-2', '1/37-5', '0/23-2', '1/24-5', '1/30-4', '1/30-5', '0/40-4', '1/37-5', '0/26-4', '0/31-4', '1/14-3', '1/38-4', '1/38-4', '0/18-3', '0/5-2', '0/14-1', '0/20-2', '2/32-5', '0/20-2', '1/37-4', '1/43-4', '0/31-4', '1/51-4', '0/22-4']
# MatchIndex :  [1.5833333333333333, 9.0, 4.875, 1.1875, 6.25, 3.5, 12.0, 1.4166666666666667, 3.0, 5.5, 2.2666666666666666, 3.4166666666666665, 0.75, 4.0, 10.5, 8.5, 3.7, 11.5, 2.4, 3.75, 3.0, 10.0, 3.7, 6.5, 7.75, 2.3333333333333335, 4.75, 4.75, 6.0, 2.5, 14.0, 10.0, 2.1333333333333333, 10.0, 4.625, 5.375, 7.75, 6.375, 5.5]
# AvgIndex 5.54198717948718
# AvgIndex2 4.693017414319191
#
# KH Pandya
# Wickets :  49 	Matches :  69 	Balls :  1283
# MatchStats :  ['1/21-4', '2/27-5', '0/25-5', '0/21-2', '0/21-2', '0/28-3', '0/5-1', '1/15-4', '0/32-4', '3/15-3', '0/28-2', '0/21-2', '3/24-4', '0/12-2', '1/25-4', '0/18-3', '1/31-5', '0/8-1', '3/15-5', '2/34-5', '0/14-2', '0/22-4', '0/25-3', '0/31-4', '0/21-2', '0/28-4', '2/44-5', '0/13-3', '0/9-2', '0/17-2', '3/34-5', '0/10-1', '0/10-2', '2/21-3', '3/28-5', '1/33-5', '0/14-3', '2/32-5', '0/25-4', '1/10-1', '1/29-3', '3/12-4', '0/24-4', '0/37-4', '1/13-2', '1/7-2', '0/24-2', '2/7-3', '0/27-3', '2/22-5', '0/14-5', '1/21-4', '1/39-3', '1/37-5', '0/10-1', '0/23-4', '1/27-5', '1/37-5', '0/22-2', '2/26-4', '0/24-4', '0/12-2', '0/16-4', '0/21-2', '0/27-4', '0/16-4', '0/37-4', '1/22-5', '0/30-4']
# MatchIndex :  [2.625, 1.8, 5.0, 10.5, 10.5, 9.333333333333334, 5.0, 1.875, 8.0, 1.25, 14.0, 10.5, 1.5, 6.0, 3.125, 6.0, 3.1, 8.0, 0.75, 2.2666666666666666, 7.0, 5.5, 8.333333333333334, 7.75, 10.5, 7.0, 2.933333333333333, 4.333333333333333, 4.5, 8.5, 1.7, 10.0, 5.0, 2.3333333333333335, 1.4, 3.3, 4.666666666666667, 2.1333333333333333, 6.25, 5.0, 4.833333333333333, 0.75, 6.0, 9.25, 3.25, 1.75, 12.0, 0.7777777777777778, 9.0, 1.4666666666666666, 2.8, 2.625, 6.5, 3.7, 10.0, 5.75, 2.7, 3.7, 11.0, 2.1666666666666665, 6.0, 6.0, 4.0, 10.5, 6.75, 4.0, 9.25, 2.2, 7.5]
# AvgIndex 5.4417069243156195
# AvgIndex2 3.865543545061001
#
# KJ Abbott
# Wickets :  2 	Matches :  5 	Balls :  102
# MatchStats :  ['1/42-5', '0/32-4', '0/34-3', '1/48-4', '0/26-3']
# MatchIndex :  [4.2, 8.0, 11.333333333333334, 6.0, 8.666666666666666]
# AvgIndex 7.639999999999999
# AvgIndex2 3.3615999999999997
#
# Ankit Sharma
# Wickets :  1 	Matches :  5 	Balls :  82
# MatchStats :  ['1/27-5', '0/31-5', '0/26-4', '0/16-1', '0/11-1']
# MatchIndex :  [2.7, 6.2, 6.5, 16.0, 11.0]
# AvgIndex 8.48
# AvgIndex2 2.0352
#
# IK Pathan
# Wickets :  2 	Matches :  4 	Balls :  60
# MatchStats :  ['0/7-1', '0/17-3', '0/37-4', '2/26-2']
# MatchIndex :  [7.0, 5.666666666666667, 9.25, 4.333333333333333]
# AvgIndex 6.5625
# AvgIndex2 3.69140625
#
# NLTC Perera
# Wickets :  10 	Matches :  11 	Balls :  202
# MatchStats :  ['0/30-3', '3/34-5', '2/28-4', '1/32-4', '3/41-5', '0/35-4', '0/9-1', '0/40-3', '0/26-2', '0/27-3', '1/24-2']
# MatchIndex :  [10.0, 1.7, 2.3333333333333335, 4.0, 2.05, 8.75, 9.0, 13.333333333333334, 13.0, 9.0, 6.0]
# AvgIndex 7.196969696969696
# AvgIndex2 6.602178812922614
#
# Mohammed Shami
# Wickets :  63 	Matches :  48 	Balls :  1070
# MatchStats :  ['3/36-5', '1/24-3', '0/34-5', '2/33-4', '0/50-4', '1/34-4', '1/28-3', '0/13-1', '0/28-4', '0/19-3', '2/40-5', '1/40-3', '0/16-2', '2/37-5', '2/37-5', '1/31-5', '1/33-4', '1/44-5', '2/43-5', '3/27-4', '0/41-5', '1/30-4', '3/21-5', '1/43-4', '2/46-4', '0/26-2', '1/29-4', '1/36-4', '1/53-5', '2/22-4', '1/57-5', '2/36-5', '1/16-3', '2/18-3', '4/16-5', '1/15-3', '3/53-5', '1/36-5', '0/35-4', '1/40-4', '2/32-4', '2/49-4', '2/30-4', '2/28-5', '1/34-5', '3/36-4', '0/37-3', '0/33-5']
# MatchIndex :  [1.8, 4.0, 6.8, 2.75, 12.5, 4.25, 4.666666666666667, 13.0, 7.0, 6.333333333333333, 2.6666666666666665, 6.666666666666667, 8.0, 2.466666666666667, 2.466666666666667, 3.1, 4.125, 4.4, 2.8666666666666667, 1.6875, 8.2, 3.75, 1.05, 5.375, 3.8333333333333335, 13.0, 3.625, 4.5, 5.3, 1.8333333333333333, 5.7, 2.4, 2.6666666666666665, 2.0, 0.64, 2.5, 2.65, 3.6, 8.75, 5.0, 2.6666666666666665, 4.083333333333333, 2.5, 1.8666666666666667, 3.4, 2.25, 12.333333333333334, 6.6]
# AvgIndex 4.658732638888889
# AvgIndex2 6.116608607916185
#
# S Aravind
# Wickets :  16 	Matches :  19 	Balls :  372
# MatchStats :  ['1/32-4', '1/16-3', '1/23-4', '1/16-3', '2/45-4', '2/18-3', '1/28-4', '0/14-3', '2/30-4', '0/36-3', '0/21-5', '2/29-5', '1/53-5', '1/27-4', '0/20-4', '0/31-4', '0/22-2', '1/13-2', '0/26-2']
# MatchIndex :  [4.0, 2.6666666666666665, 2.875, 2.6666666666666665, 3.75, 2.0, 3.5, 4.666666666666667, 2.5, 12.0, 4.2, 1.9333333333333333, 5.3, 3.375, 5.0, 7.75, 11.0, 3.25, 13.0]
# AvgIndex 5.02280701754386
# AvgIndex2 4.243645818146475
#
# D Wiese
# Wickets :  0 	Matches :  1 	Balls :  27
# MatchStats :  ['0/49-5']
# MatchIndex :  [9.8]
# AvgIndex 9.8
# AvgIndex2 9.8
#
# Bipul Sharma
# Wickets :  8 	Matches :  13 	Balls :  184
# MatchStats :  ['1/40-4', '1/10-2', '0/17-1', '0/18-2', '2/21-3', '1/17-2', '1/4-1', '0/24-4', '0/20-3', '1/31-4', '0/10-2', '1/40-4', '0/2-1']
# MatchIndex :  [5.0, 2.5, 17.0, 9.0, 2.3333333333333335, 4.25, 2.0, 6.0, 6.666666666666667, 3.875, 5.0, 5.0, 2.0]
# AvgIndex 5.4326923076923075
# AvgIndex2 3.3753413746017293
#
# YK Pathan
# Wickets :  3 	Matches :  10 	Balls :  80
# MatchStats :  ['1/6-2', '0/6-1', '0/4-1', '0/17-3', '0/15-1', '1/2-1', '0/17-1', '0/7-1', '0/8-1', '1/14-2']
# MatchIndex :  [1.5, 6.0, 4.0, 5.666666666666667, 15.0, 1.0, 17.0, 7.0, 8.0, 3.5]
# AvgIndex 6.866666666666667
# AvgIndex2 2.128666666666667
#
# VR Aaron
# Wickets :  13 	Matches :  22 	Balls :  412
# MatchStats :  ['0/37-5', '0/27-4', '0/35-5', '0/31-3', '0/25-3', '2/37-5', '0/20-3', '0/17-2', '2/22-4', '1/23-3', '2/46-5', '2/3-2', '0/32-5', '0/44-4', '0/16-1', '2/24-4', '2/40-5', '0/23-1', '0/25-3', '0/25-3', '0/47-5', '0/24-2']
# MatchIndex :  [7.4, 6.75, 7.0, 10.333333333333334, 8.333333333333334, 2.466666666666667, 6.666666666666667, 8.5, 1.8333333333333333, 3.8333333333333335, 3.066666666666667, 0.5, 6.4, 11.0, 16.0, 2.0, 2.6666666666666665, 23.0, 8.333333333333334, 8.333333333333334, 9.4, 12.0]
# AvgIndex 7.537121212121213
# AvgIndex2 4.469326008014025
#
# KW Richardson
# Wickets :  8 	Matches :  4 	Balls :  86
# MatchStats :  ['1/26-3', '4/13-3', '1/54-5', '2/45-4']
# MatchIndex :  [4.333333333333333, 0.8666666666666667, 5.4, 3.75]
# AvgIndex 3.5875
# AvgIndex2 7.399218749999999
#
# Iqbal Abdulla
# Wickets :  9 	Matches :  10 	Balls :  189
# MatchStats :  ['3/40-5', '0/22-4', '0/41-5', '0/27-3', '2/24-5', '0/14-2', '2/38-5', '0/10-1', '2/36-4', '0/19-3']
# MatchIndex :  [2.0, 5.5, 8.2, 9.0, 1.6, 7.0, 2.533333333333333, 10.0, 3.0, 6.333333333333333]
# AvgIndex 5.516666666666667
# AvgIndex2 5.020166666666666
#
# STR Binny
# Wickets :  6 	Matches :  21 	Balls :  198
# MatchStats :  ['0/8-1', '0/23-2', '1/17-2', '0/17-2', '0/16-3', '0/2-1', '0/13-2', '0/8-1', '0/11-1', '0/15-3', '0/4-1', '1/10-1', '1/14-3', '1/9-1', '1/17-2', '0/6-1', '0/33-3', '1/19-3', '0/3-1', '0/10-2', '0/6-1']
# MatchIndex :  [8.0, 11.5, 4.25, 8.5, 5.333333333333333, 2.0, 6.5, 8.0, 11.0, 5.0, 4.0, 5.0, 2.3333333333333335, 4.5, 4.25, 6.0, 11.0, 3.1666666666666665, 3.0, 5.0, 6.0]
# AvgIndex 5.920634920634921
# AvgIndex2 1.7050354533347731
#
# DJ Hooda
# Wickets :  6 	Matches :  14 	Balls :  142
# MatchStats :  ['1/22-3', '0/30-5', '0/5-1', '0/16-2', '2/16-2', '0/8-1', '1/7-1', '1/18-2', '0/17-1', '0/8-1', '0/17-3', '0/8-1', '1/13-2', '0/10-1']
# MatchIndex :  [3.6666666666666665, 6.0, 5.0, 8.0, 2.6666666666666665, 8.0, 3.5, 4.5, 17.0, 8.0, 5.666666666666667, 8.0, 3.25, 10.0]
# AvgIndex 6.660714285714286
# AvgIndex2 2.888575072886297
#
# DW Steyn
# Wickets :  5 	Matches :  6 	Balls :  136
# MatchStats :  ['0/17-3', '2/44-4', '2/30-4', '1/33-4', '0/57-5', '0/44-5']
# MatchIndex :  [5.666666666666667, 3.6666666666666665, 2.5, 4.125, 11.4, 8.8]
# AvgIndex 6.026388888888889
# AvgIndex2 5.189390432098766
#
# SK Raina
# Wickets :  1 	Matches :  11 	Balls :  139
# MatchStats :  ['0/16-3', '0/18-2', '0/35-4', '0/15-2', '0/24-2', '0/9-1', '1/11-2', '0/6-1', '0/28-4', '0/24-2', '0/6-1']
# MatchIndex :  [5.333333333333333, 9.0, 8.75, 7.5, 12.0, 9.0, 2.75, 6.0, 7.0, 12.0, 6.0]
# AvgIndex 7.757575757575757
# AvgIndex2 0.7693463561232156
#
# T Shamsi
# Wickets :  3 	Matches :  4 	Balls :  96
# ...
# MatchIndex :  [4.25, 8.4, 1.4166666666666667, 4.9, 5.0, 2.875, 2.0, 1.1, 1.4375, 1.6875, 3.875, 5.375, 4.0, 2.8, 1.1333333333333333, 10.75, 7.6, 2.2, 2.75, 7.75, 2.8, 2.6, 9.2, 1.5, 2.375, 3.8, 1.2, 2.5, 1.05, 9.5, 2.5, 1.4, 2.066666666666667, 2.1666666666666665, 2.5]
# AvgIndex 3.6702380952380946
# AvgIndex2 4.931601554907677
#
# SM Curran
# Wickets :  25 	Matches :  22 	Balls :  472
# MatchStats :  ['2/52-5', '4/13-3', '0/35-5', '0/30-4', '2/54-5', '0/31-3', '0/34-4', '0/41-5', '3/35-5', '1/29-4', '3/33-5', '1/28-5', '0/37-4', '0/31-3', '2/27-4', '1/48-5', '2/18-3', '1/35-5', '0/7-1', '3/19-4', '0/21-3', '0/15-2']
# MatchIndex :  [3.466666666666667, 0.8666666666666667, 7.0, 7.5, 3.6, 10.333333333333334, 8.5, 8.2, 1.75, 3.625, 1.65, 2.8, 9.25, 10.333333333333334, 2.25, 4.8, 2.0, 3.5, 7.0, 1.1875, 7.0, 7.5]
# AvgIndex 5.186931818181818
# AvgIndex2 5.904957503756574
#
# Mujeeb Ur Rahman
# Wickets :  18 	Matches :  18 	Balls :  426
# MatchStats :  ['2/31-5', '0/36-5', '1/36-5', '0/24-4', '2/28-5', '1/30-4', '0/18-3', '0/27-5', '2/32-5', '2/25-4', '1/17-5', '2/37-5', '3/28-5', '2/22-4', '0/28-3', '0/66-5', '0/39-4', '0/44-5']
# MatchIndex :  [2.066666666666667, 7.2, 3.6, 6.0, 1.8666666666666667, 3.75, 6.0, 5.4, 2.1333333333333333, 2.0833333333333335, 1.7, 2.466666666666667, 1.4, 1.8333333333333333, 9.333333333333334, 13.2, 9.75, 8.8]
# AvgIndex 4.921296296296297
# AvgIndex2 4.936485482395978
#
# CV Varun
# Wickets :  18 	Matches :  14 	Balls :  331
# MatchStats :  ['1/35-3', '1/25-4', '2/25-4', '1/49-4', '1/28-4', '0/27-4', '0/26-4', '1/23-4', '1/32-4', '0/28-4', '5/20-5', '1/34-4', '2/20-4', '2/20-4']
# MatchIndex :  [5.833333333333333, 3.125, 2.0833333333333335, 6.125, 3.5, 6.75, 6.5, 2.875, 4.0, 7.0, 0.6666666666666666, 4.25, 1.6666666666666667, 1.6666666666666667]
# AvgIndex 4.00297619047619
# AvgIndex2 5.16710702137998
#
# GC Viljoen
# Wickets :  8 	Matches :  6 	Balls :  146
# MatchStats :  ['1/37-5', '2/41-4', '1/26-3', '0/34-5', '3/39-5', '1/52-5']
# MatchIndex :  [3.7, 3.4166666666666665, 4.333333333333333, 6.8, 1.95, 5.2]
# AvgIndex 4.233333333333333
# AvgIndex2 5.762037037037037
#
# Mandeep Singh
# Wickets :  0 	Matches :  2 	Balls :  12
# MatchStats :  ['0/18-1', '0/8-1']
# MatchIndex :  [18.0, 8.0]
# AvgIndex 13.0
# AvgIndex2 3.25
#
# M Markande
# Wickets :  16 	Matches :  17 	Balls :  305
# MatchStats :  ['1/23-3', '0/12-2', '3/24-4', '4/25-4', '0/42-3', '1/27-5', '0/15-2', '2/15-3', '0/31-4', '1/29-3', '1/29-4', '1/25-3', '1/27-4', '0/32-3', '0/34-4', '1/21-2', '0/24-2']
# MatchIndex :  [3.8333333333333335, 6.0, 1.5, 1.25, 14.0, 2.7, 7.5, 1.6666666666666667, 7.75, 4.833333333333333, 3.625, 4.166666666666667, 3.375, 10.666666666666666, 8.5, 5.25, 12.0]
# AvgIndex 5.800980392156863
# AvgIndex2 5.479818847954406
#
# V Shankar
# Wickets :  7 	Matches :  14 	Balls :  170
# MatchStats :  ['0/13-1', '1/13-3', '0/17-2', '1/11-2', '0/12-1', '0/10-1', '1/22-3', '0/14-2', '0/16-2', '1/14-2', '0/22-4', '1/20-4', '1/15-3', '1/11-2']
# MatchIndex :  [13.0, 2.1666666666666665, 8.5, 2.75, 12.0, 10.0, 3.6666666666666665, 7.0, 8.0, 3.5, 5.5, 2.5, 2.5, 2.75]
# AvgIndex 5.988095238095238
# AvgIndex2 3.0245991253644315
#
# S Lamichhane
# Wickets :  14 	Matches :  9 	Balls :  211
# MatchStats :  ['2/29-4', '2/28-4', '1/32-4', '1/46-4', '1/29-4', '1/21-4', '3/36-5', '3/40-4', '0/36-3']
# MatchIndex :  [2.4166666666666665, 2.3333333333333335, 4.0, 5.75, 3.625, 2.625, 1.8, 2.5, 12.0]
# AvgIndex 4.116666666666666
# AvgIndex2 6.454526748971193
#
# P Ray Barman
# Wickets :  0 	Matches :  1 	Balls :  24
# MatchStats :  ['0/56-4']
# MatchIndex :  [14.0]
# AvgIndex 14.0
# AvgIndex2 14.0
#
# MJ Santner
# Wickets :  6 	Matches :  6 	Balls :  130
# MatchStats :  ['0/26-3', '1/25-5', '1/30-5', '2/13-4', '1/23-4', '1/30-3']
# MatchIndex :  [8.666666666666666, 2.5, 3.0, 1.0833333333333333, 2.875, 5.0]
# AvgIndex 3.8541666666666665
# AvgIndex2 3.961226851851852
#
# GH Vihari
# Wickets :  0 	Matches :  1 	Balls :  6
# MatchStats :  ['0/9-1']
# MatchIndex :  [9.0]
# AvgIndex 9.0
# AvgIndex2 9.0
#
# JP Behrendorff
# Wickets :  5 	Matches :  5 	Balls :  117
# MatchStats :  ['2/23-5', '1/28-4', '1/35-4', '0/31-4', '1/51-5']
# MatchIndex :  [1.5333333333333334, 3.5, 4.375, 7.75, 5.1]
# AvgIndex 4.451666666666666
# AvgIndex2 4.629733333333333
#
# SC Kuggeleijn
# Wickets :  2 	Matches :  2 	Balls :  50
# MatchStats :  ['2/37-5', '0/34-5']
# MatchIndex :  [2.466666666666667, 6.8]
# AvgIndex 4.633333333333333
# AvgIndex2 5.791666666666666
#
# AS Joseph
# Wickets :  6 	Matches :  3 	Balls :  55
# MatchStats :  ['6/14-4', '0/22-3', '0/53-3']
# MatchIndex :  [0.5, 7.333333333333333, 17.666666666666668]
# AvgIndex 8.5
# AvgIndex2 17.944444444444443
#
# HF Gurney
# Wickets :  7 	Matches :  8 	Balls :  169
# MatchStats :  ['2/25-5', '0/20-3', '1/37-4', '1/42-5', '0/16-3', '2/37-4', '1/42-4', '0/20-4']
# MatchIndex :  [1.6666666666666667, 6.666666666666667, 4.625, 4.2, 5.333333333333333, 3.0833333333333335, 5.25, 5.0]
# AvgIndex 4.478125
# AvgIndex2 3.9883300781250006
#
# S Midhun
# Wickets :  0 	Matches :  1 	Balls :  13
# MatchStats :  ['0/29-3']
# MatchIndex :  [9.666666666666666]
# AvgIndex 9.666666666666666
# AvgIndex2 9.666666666666666
#
# R Parag
# Wickets :  2 	Matches :  9 	Balls :  97
# MatchStats :  ['0/24-3', '0/17-2', '1/25-3', '0/7-1', '0/24-3', '1/10-1', '0/14-1', '0/14-1', '0/13-2']
# MatchIndex :  [8.0, 8.5, 4.166666666666667, 7.0, 8.0, 5.0, 14.0, 14.0, 6.5]
# AvgIndex 8.351851851851853
# AvgIndex2 1.9590763603109287
#
# LS Livingstone
# Wickets :  0 	Matches :  1 	Balls :  6
# MatchStats :  ['0/13-1']
# MatchIndex :  [13.0]
# AvgIndex 13.0
# AvgIndex2 13.0
#
# SN Khan
# Wickets :  0 	Matches :  1 	Balls :  2
# MatchStats :  ['0/6-1']
# MatchIndex :  [6.0]
# AvgIndex 6.0
# AvgIndex2 6.0
#
# KK Ahmed
# Wickets :  30 	Matches :  17 	Balls :  399
# MatchStats :  ['3/31-5', '1/25-5', '0/39-4', '3/33-5', '0/27-4', '1/33-4', '3/40-5', '3/42-4', '3/37-5', '3/24-3', '1/29-3', '1/43-5', '0/34-5', '3/24-3', '2/37-4', '2/47-5', '1/31-4']
# MatchIndex :  [1.55, 2.5, 9.75, 1.65, 6.75, 4.125, 2.0, 2.625, 1.85, 2.0, 4.833333333333333, 4.3, 6.8, 2.0, 3.0833333333333335, 3.1333333333333333, 3.875]
# AvgIndex 3.695588235294118
# AvgIndex2 6.534413800122125
#
# Abhishek Sharma
# Wickets :  3 	Matches :  8 	Balls :  74
# MatchStats :  ['1/10-1', '0/11-2', '1/16-2', '0/11-1', '0/34-5', '0/4-1', '1/16-1', '0/11-1']
# MatchIndex :  [5.0, 5.5, 4.0, 11.0, 6.8, 4.0, 8.0, 11.0]
# AvgIndex 6.9125
# AvgIndex2 2.7001953125
#
# IS Sodhi
# Wickets :  9 	Matches :  8 	Balls :  182
# MatchStats :  ['1/41-5', '1/25-3', '1/15-4', '1/30-4', '1/21-4', '1/31-4', '0/15-4', '3/26-4']
# MatchIndex :  [4.1, 4.166666666666667, 1.875, 3.75, 2.625, 3.875, 3.75, 1.625]
# AvgIndex 3.220833333333333
# AvgIndex2 3.6737630208333334
#
# Arshdeep Singh
# Wickets :  14 	Matches :  11 	Balls :  223
# MatchStats :  ['2/44-5', '1/48-5', '0/25-2', '2/33-5', '2/25-5', '1/20-3', '2/36-4', '0/30-3', '4/23-4', '0/18-3', '0/34-3']
# MatchIndex :  [2.933333333333333, 4.8, 12.5, 2.2, 1.6666666666666667, 3.3333333333333335, 3.0, 10.0, 1.15, 6.0, 11.333333333333334]
# AvgIndex 5.356060606060606
# AvgIndex2 6.86106937139995
#
# MA Wood
# Wickets :  0 	Matches :  1 	Balls :  25
# MatchStats :  ['0/50-5']
# MatchIndex :  [10.0]
# AvgIndex 10.0
# AvgIndex2 10.0
#
# K Khejroliya
# Wickets :  3 	Matches :  5 	Balls :  101
# MatchStats :  ['0/36-5', '2/34-4', '0/40-4', '0/18-1', '1/29-5']
# MatchIndex :  [7.2, 2.8333333333333335, 10.0, 18.0, 2.9]
# AvgIndex 8.186666666666666
# AvgIndex2 5.239466666666666
#
# B Laughlin
# Wickets :  9 	Matches :  7 	Balls :  134
# MatchStats :  ['0/20-3', '2/21-2', '1/46-5', '0/37-4', '2/38-5', '2/15-2', '2/35-4']
# MatchIndex :  [6.666666666666667, 3.5, 4.6, 9.25, 2.533333333333333, 2.5, 2.9166666666666665]
# AvgIndex 4.566666666666666
# AvgIndex2 5.964625850340136
#
# DJM Short
# Wickets :  1 	Matches :  2 	Balls :  18
# MatchStats :  ['0/13-2', '1/10-1']
# MatchIndex :  [6.5, 5.0]
# AvgIndex 5.75
# AvgIndex2 4.3125
#
# TK Curran
# Wickets :  9 	Matches :  10 	Balls :  180
# MatchStats :  ['2/39-3', '1/21-2', '2/19-3', '0/6-1', '1/33-4', '1/55-5', '1/44-5', '1/37-5', '0/40-4', '0/34-4']
# MatchIndex :  [4.333333333333333, 5.25, 2.111111111111111, 6.0, 4.125, 5.5, 4.4, 3.7, 10.0, 8.5]
# AvgIndex 5.391944444444444
# AvgIndex2 4.906669444444444
#
# A Dananjaya
# Wickets :  0 	Matches :  1 	Balls :  25
# MatchStats :  ['0/47-5']
# MatchIndex :  [9.4]
# AvgIndex 9.4
# AvgIndex2 9.4
#
# Shivam Mavi
# Wickets :  16 	Matches :  17 	Balls :  341
# MatchStats :  ['0/10-1', '1/16-3', '2/40-5', '0/29-4', '2/58-5', '0/22-4', '0/21-4', '1/44-4', '1/33-5', '2/33-5', '0/15-3', '2/21-4', '0/40-3', '1/32-3', '1/24-3', '1/34-4', '2/15-5']
# MatchIndex :  [10.0, 2.6666666666666665, 2.6666666666666665, 7.25, 3.8666666666666667, 5.5, 5.25, 5.5, 3.3, 2.2, 5.0, 1.75, 13.333333333333334, 5.333333333333333, 4.0, 4.25, 1.0]
# AvgIndex 4.874509803921568
# AvgIndex2 4.604640749033177
#
# LE Plunkett
# Wickets :  4 	Matches :  7 	Balls :  154
# MatchStats :  ['3/19-5', '0/24-4', '0/52-3', '0/37-3', '1/27-5', '0/42-4', '0/27-4']
# MatchIndex :  [0.95, 6.0, 17.333333333333332, 12.333333333333334, 2.7, 10.5, 6.75]
# AvgIndex 8.08095238095238
# AvgIndex2 4.782604470359573
#
# MK Tiwary
# Wickets :  0 	Matches :  1 	Balls :  7
# MatchStats :  ['0/10-2']
# MatchIndex :  [5.0]
# AvgIndex 5.0
# AvgIndex2 5.0
#
# MK Lomror
# Wickets :  0 	Matches :  2 	Balls :  18
# MatchStats :  ['0/8-1', '0/19-2']
# MatchIndex :  [8.0, 9.5]
# AvgIndex 8.75
# AvgIndex2 2.1875
#
# L Ngidi
# Wickets :  23 	Matches :  11 	Balls :  267
# MatchStats :  ['1/27-5', '1/36-4', '2/26-5', '2/16-4', '4/11-5', '1/20-4', '2/26-4', '3/38-5', '2/56-5', '2/35-5', '3/40-5']
# MatchIndex :  [2.7, 4.5, 1.7333333333333334, 1.3333333333333333, 0.44, 2.5, 2.1666666666666665, 1.9, 3.7333333333333334, 2.3333333333333335, 2.0]
# AvgIndex 2.3036363636363637
# AvgIndex2 4.835732531930879
#
# KM Asif
# Wickets :  3 	Matches :  2 	Balls :  38
# MatchStats :  ['2/43-4', '1/32-4']
# MatchIndex :  [3.5833333333333335, 4.0]
# AvgIndex 3.791666666666667
# AvgIndex2 6.635416666666668
#
# DJ Willey
# Wickets :  2 	Matches :  3 	Balls :  61
# MatchStats :  ['1/25-4', '1/47-5', '0/24-2']
# MatchIndex :  [3.125, 4.7, 12.0]
# AvgIndex 6.608333333333333
# AvgIndex2 5.139814814814815
#
# JPR Scantlebury-Searles
# Wickets :  2 	Matches :  3 	Balls :  45
# MatchStats :  ['1/52-5', '1/24-2', '0/13-1']
# MatchIndex :  [5.2, 6.0, 13.0]
# AvgIndex 8.066666666666666
# AvgIndex2 6.274074074074075
#
# CJ Dala
# Wickets :  0 	Matches :  1 	Balls :  19
# MatchStats :  ['0/34-4']
# MatchIndex :  [8.5]
# AvgIndex 8.5
# AvgIndex2 8.5
#
# SE Rutherford
# Wickets :  1 	Matches :  6 	Balls :  46
# MatchStats :  ['0/5-1', '0/16-2', '1/6-1', '0/20-3', '0/2-1', '0/11-2']
# MatchIndex :  [5.0, 8.0, 3.0, 6.666666666666667, 2.0, 5.5]
# AvgIndex 5.027777777777778
# AvgIndex2 0.9776234567901235
#
# Harpreet Brar
# Wickets :  0 	Matches :  3 	Balls :  55
# MatchStats :  ['0/24-2', '0/24-3', '0/41-5']
# MatchIndex :  [12.0, 8.0, 8.2]
# AvgIndex 9.4
# AvgIndex2 1.0444444444444445
#
# Y Prithvi Raj
# Wickets :  1 	Matches :  2 	Balls :  33
# MatchStats :  ['1/29-4', '0/28-3']
# MatchIndex :  [3.625, 9.333333333333334]
# AvgIndex 6.479166666666667
# AvgIndex2 4.859375000000001
#
# O Thomas
# Wickets :  5 	Matches :  4 	Balls :  63
# MatchStats :  ['1/34-5', '2/30-5', '2/8-2', '0/13-1']
# MatchIndex :  [3.4, 2.0, 1.3333333333333333, 13.0]
# AvgIndex 4.933333333333334
# AvgIndex2 6.4750000000000005
#
# AS Roy
# Wickets :  1 	Matches :  1 	Balls :  15
# MatchStats :  ['1/11-3']
# MatchIndex :  [1.8333333333333333]
# AvgIndex 1.8333333333333333
# AvgIndex2 3.6666666666666665
#
# S Sandeep Warrier
# Wickets :  2 	Matches :  4 	Balls :  94
# MatchStats :  ['0/30-4', '2/31-4', '0/25-5', '0/34-4']
# MatchIndex :  [7.5, 2.5833333333333335, 5.0, 8.5]
# AvgIndex 5.895833333333334
# AvgIndex2 3.3164062500000004
#
# JL Pattinson
# Wickets :  11 	Matches :  10 	Balls :  222
# MatchStats :  ['1/27-5', '2/25-5', '0/51-4', '2/28-5', '2/29-5', '2/20-4', '0/37-4', '2/40-4', '0/35-3', '0/29-3']
# MatchIndex :  [2.7, 1.6666666666666667, 12.75, 1.8666666666666667, 1.9333333333333333, 1.6666666666666667, 9.25, 3.3333333333333335, 11.666666666666666, 9.666666666666666]
# AvgIndex 5.65
# AvgIndex2 6.2715000000000005
#
# SS Cottrell
# Wickets :  6 	Matches :  6 	Balls :  131
# MatchStats :  ['2/24-5', '2/17-4', '1/52-4', '1/20-5', '0/30-4', '0/34-4']
# MatchIndex :  [1.6, 1.4166666666666667, 6.5, 2.0, 7.5, 8.5]
# AvgIndex 4.586111111111111
# AvgIndex2 4.713503086419753
#
# Ravi Bishnoi
# Wickets :  14 	Matches :  14 	Balls :  318
# MatchStats :  ['1/22-5', '3/32-5', '0/34-5', '1/37-5', '0/33-5', '3/29-3', '1/25-4', '0/30-4', '1/12-2', '0/25-3', '1/13-4', '2/20-4', '1/27-5', '0/42-5']
# MatchIndex :  [2.2, 1.6, 6.8, 3.7, 6.6, 2.4166666666666665, 3.125, 7.5, 3.0, 8.333333333333334, 1.625, 1.6666666666666667, 2.7, 8.4]
# AvgIndex 4.261904761904762
# AvgIndex2 4.283649173955296
#
# A Nortje
# Wickets :  23 	Matches :  16 	Balls :  376
# MatchStats :  ['0/37-4', '2/21-5', '0/41-4', '3/38-4', '2/24-5', '1/26-5', '0/28-5', '2/34-4', '2/44-4', '2/27-4', '1/38-5', '4/34-4', '1/25-3', '1/51-4', '0/36-4', '2/25-3']
# MatchIndex :  [9.25, 1.4, 10.25, 2.375, 1.6, 2.6, 5.6, 2.8333333333333335, 3.6666666666666665, 2.25, 3.8, 1.7, 4.166666666666667, 6.375, 9.0, 2.7777777777777777]
# AvgIndex 4.352777777777778
# AvgIndex2 6.27412109375
#
# JR Hazlewood
# Wickets :  1 	Matches :  3 	Balls :  61
# MatchStats :  ['0/32-5', '1/23-4', '0/17-2']
# MatchIndex :  [6.4, 2.875, 8.5]
# AvgIndex 5.925
# AvgIndex2 2.6333333333333333
#
# JDS Neesham
# Wickets :  2 	Matches :  5 	Balls :  93
# MatchStats :  ['0/13-3', '1/40-4', '0/53-5', '1/17-2', '0/26-4']
# MatchIndex :  [4.333333333333333, 5.0, 10.6, 4.25, 6.5]
# AvgIndex 6.136666666666666
# AvgIndex2 2.700133333333333
#
# KL Nagarkoti
# Wickets :  5 	Matches :  9 	Balls :  160
# MatchStats :  ['0/18-3', '2/13-2', '1/35-4', '1/21-3', '0/40-3', '0/36-4', '0/11-2', '0/34-3', '1/25-5']
# MatchIndex :  [6.0, 2.1666666666666665, 4.375, 3.5, 13.333333333333334, 9.0, 5.5, 11.333333333333334, 2.5]
# AvgIndex 6.412037037037037
# AvgIndex2 3.6414037494284406
#
# I Udana
# Wickets :  8 	Matches :  10 	Balls :  182
# MatchStats :  ['2/45-5', '2/41-5', '1/43-5', '1/30-4', '1/19-2', '0/15-3', '0/43-4', '0/6-1', '1/20-3', '0/24-2']
# MatchIndex :  [3.0, 2.7333333333333334, 4.3, 3.75, 4.75, 5.0, 10.75, 6.0, 3.3333333333333335, 12.0]
# AvgIndex 5.5616666666666665
# AvgIndex2 4.504949999999999
#
# Abdul Samad
# Wickets :  1 	Matches :  3 	Balls :  43
# MatchStats :  ['1/41-5', '0/27-2', '0/28-1']
# MatchIndex :  [4.1, 13.5, 28.0]
# AvgIndex 15.200000000000001
# AvgIndex2 6.755555555555556
#
# Kartik Tyagi
# Wickets :  10 	Matches :  10 	Balls :  241
# MatchStats :  ['1/37-5', '1/37-5', '1/29-3', '1/30-5', '1/32-5', '2/36-5', '0/42-4', '1/45-4', '0/47-5', '2/37-4']
# MatchIndex :  [3.7, 3.7, 4.833333333333333, 3.0, 3.2, 2.4, 10.5, 5.625, 9.4, 3.0833333333333335]
# AvgIndex 4.944166666666666
# AvgIndex2 4.9936083333333325
#
# TU Deshpande
# Wickets :  3 	Matches :  5 	Balls :  110
# MatchStats :  ['2/37-5', '1/39-5', '0/41-3', '0/40-5', '0/36-3']
# MatchIndex :  [2.466666666666667, 3.9, 13.666666666666666, 8.0, 12.0]
# AvgIndex 8.006666666666666
# AvgIndex2 5.124266666666666
#
# CJ Green
# Wickets :  0 	Matches :  1 	Balls :  17
# MatchStats :  ['0/24-3']
# MatchIndex :  [8.0]
# AvgIndex 8.0
# AvgIndex2 8.0
#
# Shahbaz Ahmed
# Wickets :  2 	Matches :  2 	Balls :  37
# MatchStats :  ['0/18-2', '2/27-5']
# MatchIndex :  [9.0, 1.8]
# AvgIndex 5.4
# AvgIndex2 6.75
#
# DR Sams
# Wickets :  0 	Matches :  3 	Balls :  77
# MatchStats :  ['0/30-5', '0/40-5', '0/44-4']
# MatchIndex :  [6.0, 8.0, 11.0]
# AvgIndex 8.333333333333334
# AvgIndex2 0.925925925925926
#
# Monu Kumar
# Wickets :  0 	Matches :  1 	Balls :  16
# MatchStats :  ['0/20-3']
# MatchIndex :  [6.666666666666667]
# AvgIndex 6.666666666666667
# AvgIndex2 6.666666666666667
#
# DA Warner
# Wickets :  0 	Matches :  1 	Balls :  2
# MatchStats :  ['0/2-1']
# MatchIndex :  [2.0]
# AvgIndex 2.0
# AvgIndex2 2.0
#
# P Dubey
# Wickets :  0 	Matches :  3 	Balls :  48
# MatchStats :  ['0/29-3', '0/14-2', '0/29-3']
# MatchIndex :  [9.666666666666666, 7.0, 9.666666666666666]
# AvgIndex 8.777777777777777
# AvgIndex2 0.9753086419753085

# %% [markdown]
# # Model

# %%
finaldata3 = finaldata

# %%
finaldata3
# Out:
#     match_id  ... bowling_index
# 0     980901  ...      5.126246
# 299   980901  ...      4.766088
# 1     980903  ...      5.643511
# 300   980903  ...      4.651841
# 2     980905  ...      6.769435
# ..       ...  ...           ...
# 595  1237178  ...      4.847504
# 297  1237180  ...      4.310060
# 596  1237180  ...      5.348082
# 298  1237181  ...      5.175729
# 597  1237181  ...      5.348082
#
# [598 rows x 15 columns]

# %%
finaldata3['venue_index'] = 0
for i in range(len(finaldata3)):
  venue_index = venuedata[venuedata['venue']==finaldata3.loc[i]['venue']]['index1'].unique()[0]
  venue_index2 = venuedata[venuedata['venue']==finaldata3.loc[i]['venue']]['index2'].unique()[0]
  if(finaldata3.loc[i]['innings']==1):
    #print('1',finaldata.loc[i]['venue'],venue_index)
    finaldata3.loc[i,'venue_index'] = venue_index
  else:
    #print('2',finaldata.loc[i]['venue'],venue_index2)
    finaldata3.loc[i,'venue_index'] = venue_index2

# %%
finaldata3['batting_team_index'] = 0
for i in range(len(finaldata3)):
  batting_team_index = teamdata[teamdata['team']==finaldata3.loc[i]['batting_team']]['batindex_1'].unique()[0]
  batting_team_index2 = teamdata[teamdata['team']==finaldata3.loc[i]['batting_team']]['batindex_2'].unique()[0]
  if(finaldata3.loc[i]['innings']==1):
    #print('1',finaldata.loc[i]['venue'],venue_index)
    finaldata3.loc[i,'batting_team_index'] = batting_team_index
  else:
    #print('2',finaldata.loc[i]['venue'],venue_index2)
    finaldata3.loc[i,'batting_team_index'] = batting_team_index2

# %%
finaldata3['bowling_team_index'] = 0
for i in range(len(finaldata3)):
  bowling_team_index = teamdata[teamdata['team']==finaldata3.loc[i]['bowling_team']]['bowlindex_1'].unique()[0]
  bowling_team_index2 = teamdata[teamdata['team']==finaldata3.loc[i]['bowling_team']]['bowlindex_1'].unique()[0]
  if(finaldata3.loc[i]['innings']==1):
    #print('1',finaldata.loc[i]['venue'],venue_index)
    finaldata3.loc[i,'bowling_team_index'] = bowling_team_index
  else:
    #print('2',finaldata.loc[i]['venue'],venue_index2)
    finaldata3.loc[i,'bowling_team_index'] = bowling_team_index2

# %%
finaldata3['batting_index'] = 0
for i in range(len(finaldata3)):
  batting_index=0
  batting_index2=0
  batsmen_list = finaldata3.loc[i]['batsmen'].split(',')
  for batsman in batsmen_list:
    batting_index = batting_index + batsmandata[batsmandata['batsman']==batsman]['index_1'].unique()[0]
    batting_index2 = batting_index2 + batsmandata[batsmandata['batsman']==batsman]['index_2'].unique()[0]
  if(finaldata3.loc[i]['innings']==1):
    #print('1',finaldata.loc[i]['venue'],venue_index)
    finaldata3.loc[i,'batting_index'] = batting_index
  else:
    #print('2',finaldata.loc[i]['venue'],venue_index2)
    finaldata3.loc[i,'batting_index'] = batting_index2

# %%
finaldata3['batting_strike'] = 0
for i in range(len(finaldata3)):
  batting_strike=0
  batting_strike2=0
  batsmen_list = finaldata3.loc[i]['batsmen'].split(',')
  for batsman in batsmen_list:
    batting_strike = batting_strike + batsmandata[batsmandata['batsman']==batsman]['strike_1'].unique()[0]
    batting_strike2 = batting_strike2 + batsmandata[batsmandata['batsman']==batsman]['strike_2'].unique()[0]
  if(finaldata3.loc[i]['innings']==1):
    #print('1',finaldata.loc[i]['venue'],venue_index)
    finaldata3.loc[i,'batting_strike'] = batting_strike/len(batsmen_list)
  else:
    #print('2',finaldata.loc[i]['venue'],venue_index2)
    finaldata3.loc[i,'batting_strike'] = batting_strike2/len(batsmen_list)

# %%
finaldata3['bowling_index'] = 0
for i in range(len(finaldata3)):
  bowling_index=0
  bowler_list = finaldata3.loc[i]['bowlers'].split(',')
  #print(bowler_list)
  for bowler in bowler_list:
    #print(bowler)
    bowling_index = bowling_index + bowlerdata[bowlerdata['bowler']==bowler]['A1index'].unique()[0]
  finaldata3.loc[i,'bowling_index'] = bowling_index/len(bowler_list)

# %%
finaldata3.columns
# Out:
# Index(['match_id', 'venue', 'innings', 'batting_team', 'bowling_team',
#        'batsmen', 'bowlers', 'ppruns', 'ppwickets', 'venue_index',
#        'batting_team_index', 'bowling_team_index', 'batting_index',
#        'batting_strike', 'bowling_index'],
#       dtype='object')

# %%
finaldata4 = finaldata3[['innings', 'venue_index','batting_team_index', 'bowling_team_index', 'batting_index','bowling_index','ppwickets','ppruns']]

# %%
finaldata4
# Out:
#     innings  venue_index  batting_team_index  ...  bowling_index  ppwickets  ppruns
# 0         1   169.577778          177.560976  ...       5.126246        8.0   121.0
# 299       2   160.933333          147.066667  ...       4.766088        1.0   126.0
# 1         1   171.566667          172.289474  ...       5.643511       10.0    98.0
# 300       2   155.200000          163.729730  ...       4.651841        1.0    99.0
# 2         1   169.571429          172.583333  ...       6.769435        6.0   161.0
# ..      ...          ...                 ...  ...            ...        ...     ...
# 595       2   152.000000          160.500000  ...       4.847504        4.0   132.0
# 297       1   162.500000          172.289474  ...       4.310060        3.0   189.0
# 596       2   152.000000          160.500000  ...       5.348082        8.0   172.0
# 298       1   171.538462          172.289474  ...       5.175729        7.0   156.0
# 597       2   149.153846          168.722222  ...       5.348082        5.0   157.0
#
# [598 rows x 8 columns]

# %%
finaldata4.corr()
# Out:
#                     venue_index  batting_team_index  ...  ppwickets    ppruns
# venue_index            1.000000            0.616908  ...   0.015580  0.303693
# batting_team_index     0.616908            1.000000  ...   0.096210  0.225979
# bowling_team_index    -0.071634            0.061683  ...   0.101035 -0.076692
# batting_index          0.114962            0.238048  ...   0.737630  0.018685
# bowling_index          0.080486           -0.042281  ...  -0.168586  0.166549
# ppwickets              0.015580            0.096210  ...   1.000000 -0.265295
# ppruns                 0.303693            0.225979  ...  -0.265295  1.000000
#
# [7 rows x 7 columns]

# %%
X = finaldata4.iloc[:,:-2].values
y = finaldata4.iloc[:,-2:].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)

# %%
X_train
# Out:
# array([[1, 169.57142857142858, 172.58333333333334, 18.733067729083665,
#         170.11879811010243, 5.345813916483074],
#        [2, 146.26666666666668, 160.5, 18.733067729083665,
#         112.09169278996865, 5.5391935461127035],
#        [2, 146.26666666666668, 163.72972972972974, 21.752136752136753,
#         99.36585454019664, 5.675670711049045],
#        ...,
#        [2, 134.22222222222223, 158.83870967741936, 21.497925311203318,
#         108.3497113997114, 4.927118597342319],
#        [1, 169.57777777777778, 173.46511627906978, 20.10236220472441,
#         169.43010017733388, 4.9402615755755255],
#        [2, 152.0, 160.1891891891892, 21.752136752136753,
#         177.0638199807659, 4.526354939336439]], dtype=object)

# %% [markdown]
# ### Linear Regression

# %%
classifier = LinearRegression()
classifier.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.28036028803210755
# 519.9844570781667

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 200, max_depth=5,random_state = 0)

# %%
regressor.fit(X_train, y_train)
y_pred2 = regressor.predict(X_test)

# %%
y_pred2
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred2))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred2))
# Out:
# 0.14615205169046502
# 561.7856518059505

# %% [markdown]
# ### Dummy Classifier

# %%
from sklearn.dummy import DummyClassifier
clf = DummyClassifier(strategy= 'most_frequent').fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# -0.07277800914227295
# 507.3611111111111

# %% [markdown]
# ### Prediction Time

# %%
#['innings', 'venue_index','batting_team_index', 'batting_team_index' 'batting_team_index', 'batting_index','bowling_index','ppruns', 'ppwickets']
inputdf = pd.DataFrame(columns = ['innings', 'venue_index','batting_team_index', 'bowling_team_index', 'batting_index','bowling_index','ppwickets'])
inputdf = inputdf.append({'innings':1,'venue_index':'MA Chidambaram Stadium','batting_team_index':'Sunrisers Hyderabad','bowling_team_index':'Chennai Super Kings','batting_index':'DA Warner,JM Bairstow,MK Pandey,KS Williamson,KM Jadhav','bowling_index':'SM Curran,DL Chahar,RA Jadeja,MM Ali,SN Thakur,L Ngidi'},ignore_index=True)

# %%
inputdf
# Out:
#   innings  ... ppwickets
# 0       1  ...       NaN
#
# [1 rows x 7 columns]

# %%
inputdf['venue_index'].loc[0] = venuedata[venuedata['venue'] == inputdf['venue_index'].loc[0]]['index1'].unique()[0]
inputdf['batting_team_index'].loc[0] = teamdata[teamdata['team'] == inputdf['batting_team_index'].loc[0]]['batindex_1'].unique()[0]
inputdf['bowling_team_index'].loc[0] = teamdata[teamdata['team'] == inputdf['bowling_team_index'].loc[0]]['bowlindex_1'].unique()[0]
inputdf['batting_strike']=0
batting_index=0
batting_strike=0
bowling_index=0
print(inputdf)
batsmen_list = inputdf.loc[0]['batting_index'].split(',')
#print(batsmen_list)
for batsman in batsmen_list:
    print(batsman)
    batting_index = batting_index + batsmandata[batsmandata['batsman']==batsman]['index_1'].unique()[0]

inputdf['batting_index'].loc[0] = batting_index

for batsman in batsmen_list:
    print(batsman,batting_strike)
    batting_strike = batting_strike + batsmandata[batsmandata['batsman']==batsman]['strike_1'].unique()[0]

inputdf['batting_strike'].loc[0] = batting_strike/len(batsmen_list)

bowler_list = inputdf.loc[0]['bowling_index'].split(',')
#print(bowler_list)
for bowler in bowler_list:
    #print(bowler)
    bowling_index = bowling_index + bowlerdata[bowlerdata['bowler']==bowler]['A1index'].unique()[0]
inputdf['bowling_index'].loc[0] = bowling_index/len(bowler_list)

inputdf['ppwickets'].loc[0] = len(batsmen_list)-2
# Out:
#   innings venue_index  ... ppwickets batting_strike
# 0       1     150.556  ...       NaN              0
#
# [1 rows x 8 columns]
# DA Warner
# JM Bairstow
# MK Pandey
# KS Williamson
# KM Jadhav
# DA Warner 0
# JM Bairstow 138.69485294117646
# MK Pandey 272.9923736023335
# KS Williamson 400.04955630805176
# KM Jadhav 535.7961626428934
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
inputdf
# Out:
#   innings venue_index  ... ppwickets batting_strike
# 0       1     150.556  ...         3     136.133592
#
# [1 rows x 8 columns]

# %%
venuedata
# Out:
#                                                 venue  ...      index2
# 0                                    Wankhede Stadium  ...  160.933333
# 1                                        Eden Gardens  ...  155.200000
# 2          Punjab Cricket Association Stadium, Mohali  ...  164.761905
# 3                               M Chinnaswamy Stadium  ...  156.870968
# 4              Saurashtra Cricket Association Stadium  ...  162.700000
# 5                                Arun Jaitley Stadium  ...  154.392857
# 6                  Rajiv Gandhi International Stadium  ...  146.266667
# 7   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  ...  130.375000
# 8                                          Green Park  ...  163.250000
# 9    Shaheed Veer Narayan Singh International Stadium  ...  150.000000
# 10                             Holkar Cricket Stadium  ...  164.285714
# 11                             MA Chidambaram Stadium  ...  134.222222
# 12                             Sawai Mansingh Stadium  ...  152.142857
# 13                               Sheikh Zayed Stadium  ...  152.000000
# 14                Dubai International Cricket Stadium  ...  149.153846
# 15                            Sharjah Cricket Stadium  ...  163.333333
#
# [16 rows x 7 columns]

# %%
inputdata = np.array(inputdf[['innings', 'venue_index', 'batting_team_index', 'bowling_team_index',
       'batting_index','bowling_index']])

# %%
inputdata
# Out:
# array([[1, 150.55555555555554, 175.46341463414635, 26.17105263157895,
#         165.06349206349205, 4.801693905054655]], dtype=object)

# %%
regressor.predict(inputdata)
# Out:
# array([[  6.6142891 , 147.44917962]])

# %%
clf.predict(inputdf)
# Out:
# array([[  5., 162.]])

# %%
y_test
# Out:
# array([164., 195., 151., 155., 164., 218., 169., 154., 131., 149., 160.,
#        149., 170., 156.,  84.,  88., 208., 167., 202., 114., 111., 206.,
#        154., 185., 151., 174., 142., 194., 158., 179.])

# %%
import pickle 
print(pickle.format_version)
# Out:
# 4.0

# %%
import pickle
pickle.dump(regressor, open('model.xyz','wb'))

# %%
pickle.dump(classifier, open('model2.xyz','wb'))

# %%
venuedata.to_csv('venuedata.csv')
teamdata.to_csv('teamdata.csv')
batsmandata.to_csv('batsmandata.csv')
bowlerdata.to_csv('bowlerdata.csv')
